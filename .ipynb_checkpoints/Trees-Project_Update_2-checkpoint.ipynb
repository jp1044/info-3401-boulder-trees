# %%
import pandas as pd
import numpy as np
import operator

# %% [markdown]
# Questions for Christy:
# 1.) EAB column
# 2.) Disease Def column: differences between values
# 3.) What makes a street diverse?

# %%
df = pd.read_csv("Trees_Public.csv")
df.head()
# Out:
#    FID       ID                     UNIQUEID  ADDRESS SUFFIX   STREET  \
# 0    0  59084.0            JS 20150203131235      601         10TH ST
# 1    1  59085.0            JS 20150203131431      601         10TH ST
# 2    2  86480.0  DROID 201607141607903829845      601         10TH ST
# 3    3  59087.0            JS 20150203131448      601         10TH ST
# 4    4  59088.0            JS 20150203131959      690         10TH ST
#
#      ONSTR      FROMSTR        TOSTR   SIDE  ...       GUARDSZ         EAB  \
# 0  10TH ST  BASELINE RD   CUL-DE-SAC  Front  ...    Unassigned  Unassigned
# 1  10TH ST  BASELINE RD   CUL-DE-SAC  Front  ...    Unassigned  Unassigned
# 2  10TH ST  BASELINE RD   CUL-DE-SAC  Front  ...    Unassigned  Unassigned
# 3  10TH ST  BASELINE RD   CUL-DE-SAC  Front  ...    Unassigned  Unassigned
# 4  10TH ST   CUL-DE-SAC  BASELINE RD  Front  ...    Unassigned  Unassigned
#
#               INV_DATE INV_TIME           INSPECT_DT INSPECT_TM   NOTES  \
# 0  2015-02-03 00:00:00           2015-07-10 00:00:00   11:40:29
# 1  2015-02-03 00:00:00           2015-07-10 00:00:00   11:40:29
# 2  2016-07-14 00:00:00           2017-03-09 00:00:00   12:46:32  TC np.
# 3  2015-02-03 00:00:00           2015-07-10 00:00:00   11:40:30
# 4  2015-02-03 00:00:00           2015-07-10 00:00:00   11:40:30
#
#   ACTIVE    COMMONNAME  GENUS
# 0    1.0   Blue Spruce  Picea
# 1    1.0   Blue Spruce  Picea
# 2    1.0  Siberian Elm  Ulmus
# 3    1.0  Norway Maple   Acer
# 4    1.0  Norway Maple   Acer
#
# [5 rows x 39 columns]

# %%
df.columns
# Out:
# Index(['FID', 'ID', 'UNIQUEID', 'ADDRESS', 'SUFFIX', 'STREET', 'ONSTR',
#        'FROMSTR', 'TOSTR', 'SIDE', 'SITE', 'SPP', 'DBH', 'CULTIVAR',
#        'CONDITION', 'INSPECT', 'MT', 'MT2', 'TTYPE', 'MEMTREE', 'DISEASEDEF',
#        'STRUTDEFEC', 'LOCTYPE', 'SITECAT', 'HOOD', 'LOCATION', 'JURISDIC',
#        'TSIP', 'GRATESZ', 'GUARDSZ', 'EAB', 'INV_DATE', 'INV_TIME',
#        'INSPECT_DT', 'INSPECT_TM', 'NOTES', 'ACTIVE', 'COMMONNAME', 'GENUS'],
#       dtype='object')

# %%
def dic(c):
    d = {}
    for i in c:
        try:
            d[i]+=1
        except:
            d[i]=1
    import operator
    d = sorted(d.items(), key=operator.itemgetter(1),reverse = True)
    return d
def dic2(c):
    a = {}
    for i in c:
        try:
            a[i]+=1
        except:
            a[i]=1
    import operator
    a = sorted(a.items(), key=operator.itemgetter(1),reverse = True)
    t=0
    for i in a:
        t+=i[1]
    d = []
    for i in a:
        d.append([i[0],float(i[1])/t])
    return d
def dic3(c):
    d={}
    for i in c:
        try:
            d[df[df['STREET']==i[0]]['HOOD'].iloc[0]]+=i[1]
        except:
            d[df[df['STREET']==i[0]]['HOOD'].iloc[0]]=i[1]
    for i in df['HOOD']:
        try:
            d[i]
        except:
            if i == i:
                d[i]=0
    d = sorted(d.items(), key=operator.itemgetter(1),reverse = True)
    return d

# %%
ash = df[df['COMMONNAME']=='Green Ash'].append(df[df['COMMONNAME']=='White Ash']) #Subset of tree dataset that only has ash trees
mt_dic = dic(ash['MT'])  #dictionary of sorted values of Maintenance columns
strs = df['STREET'].append(df['TOSTR']).append(df['FROMSTR']).append(df['ONSTR']).unique()

strs_tree_counts={}
for i in df['STREET'].unique():
    e={}
    for j in df[df['STREET']==i]['COMMONNAME']:
        #e['Ash']=0
        if j !="White Ash" and j!="Green Ash":
            try:
                e[j]+=1
            except:
                e[j]=1
        else:
            try:
                e['Ash']+=1
            except:
                e['Ash']=1
    strs_tree_counts[i]=[np.sum([values for key,values in e.items()]),e]
for key,value in strs_tree_counts.items():
    for a,b in value[1].items():
        strs_tree_counts[key][1][a] = [b,float(b)/value[0]]

bad_ash = ash[ash['MT']!='No Specific Maintenance Need']
good_ash = ash[ash['MT']=='No Specific Maintenance Need']

boulder_trees = dic(df['COMMONNAME'])

bad_ash_strs =  [i for i in bad_ash['STREET'].unique()]
bad_ash_strs_counts = sorted([[i,len(bad_ash[bad_ash['STREET'] ==i])] for i in bad_ash_strs], key = lambda num:num[1], reverse = True)
good_ash_strs = [i for i in good_ash['STREET'].unique()]
only_good_ash_strs = [i for i in good_ash['STREET'].unique() if i not in bad_ash_strs]
only_bad_ash_strs = [i for i in bad_ash['STREET'].unique() if i not in good_ash_strs]
both_ash_strs = [i for i in good_ash['STREET'].unique() if i in bad_ash['STREET'].unique()]
both_ash_strs_percent = len(both_ash_strs)/len(strs)

bad_strs_percent = len(bad_ash_strs)/len(strs)
good_strs_percent = len(good_ash_strs)/len(strs)

bad_ash_tofro_strs = bad_ash['TOSTR'].append(bad_ash['FROMSTR']).unique()


at_risk_strs = [i for i in only_good_ash_strs if i in bad_ash_tofro_strs]

at_risk_strs_counts = []
for i in at_risk_strs:
    at_risk_strs_counts.append([i,len(ash[ash['STREET']==i])])
    
at_risk_strs_sorted = sorted(at_risk_strs_counts, key=lambda num:num[1], reverse = True)

at_risk_strs_d = {}
for i in at_risk_strs_sorted:
    at_risk_strs_d[i[0]]=i[1]
    
at_risk_strs_ash_dic = {}
for i in at_risk_strs_sorted:
    at_risk_strs_ash_dic[i[0]]=strs_tree_counts[i[0]][1]['Ash']
    
at_risk_hoods=dic3(at_risk_strs_sorted)
bad_ash_hoods_counts = dic3(bad_ash_strs_counts)


strs_trees_percent_dic = {}
for i in df['COMMONNAME'].unique():
    strs_trees_percent_dic[i]=np.mean([value[1][i][1] for key,value in strs_tree_counts.items() if i in value[1]])
t=[value[1]['Ash'][1] for key,value in strs_tree_counts.items() if 'Ash'in value[1]]
strs_trees_percent_dic['Ash']=np.mean(t)
strs_trees_percent_dic_sorted = sorted(strs_trees_percent_dic.items(), key=operator.itemgetter(1),reverse = True)

strs_trees_percent_dic_2 = {}
for i in df['COMMONNAME'].unique():
    t = []
    for key,value in strs_tree_counts.items():
        if i in value[1]:
            t.append(np.mean(value[1][i][1]))
        else:
            t.append(0)
    strs_trees_percent_dic_2[i]=np.mean(t)
t=[]
for key,value in strs_tree_counts.items():
    if 'Ash' in value[1]:
        t.append(value[1]['Ash'][1])
    else:
        t.append(0)
strs_trees_percent_dic_2['Ash']=np.mean(t)
strs_trees_percent_dic_sorted_2 = sorted(strs_trees_percent_dic_2.items(), key=operator.itemgetter(1),reverse = True)
# Out:
# /Users/jacobpaul/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:2957: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/jacobpaul/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
help_vars = {'ash': 'filtered Data frame that only includes ash trees',
'mt_dic': 'sorted list of maintenance values for ash trees',
'boulder_trees': 'quantities of each tree in boulder',
'strs': 'list of all streets in boulder',

'bad_ash': 'data frame of all ash trees that need maintenance',
'bad_ash_strs': 'list of streets that have ash trees that need maintenance',
'only_bad_ash_strs': 'list of streets that have ash trees and all of those trees need maintenance',
'bad_ash_strs_counts': 'sorted list of streets and the amounts of bad ash trees they have',
'bad_strs_percent': 'percent of streets in Boulder that have bad trees',
'bad_ash_tofro_strs': 'list of streets that have another street touching it that have bad ash trees on it',
'bad_ash_hoods_counts': 'sorted list of hoods and the amount of bad ash trees that it has',

'good_ash': 'data frame of all ash trees that dont need maintenance',
'good_ash_strs': 'list of all streets that have good ash trees on it',
'only_good_ash_strs': 'list of streets that have ash trees and none of those trees need maintenance',
'good_strs_percent': 'percent of streets in Boulder that have good ash trees',

'both_ash_strs': 'list of streets that have some ash trees that need maintenance and some that dont',
'both_ash_strs_percent': 'percent of streets in boulder that have both good & bad ash trees',

'at_risk_strs': 'streets that have an ajoining street that has a tree that needs maintenance',
'at_risk_strs_d': 'alphabetized dictionary of streets that have no bad trees and the amount of bad trees on ajoining streets',
'at_risk_strs_sorted': 'list of streets that have no bad trees, sorted by how many bad trees are on ajoining streets',
'at_risk_strs_ash_dic': 'dictionary of streets that have neighboring streets with bad ash trees, and the amount of ash trees and the percentage of ash tree makeup of that street',
'at_risk_hoods': 'list of hoods, sorted by the amount of at risk streets they have',

'strs_trees_percent_dic': 'alphabetized dictionary of each tree, and the average percentage that the tree makes up for streets that have that tree',
'strs_trees_percent_dic_sorted': 'list of each tree, sorted by the average percentage that the tree makes up for streets that have that tree',

'strs_trees_percent_dic_2': 'alphabetized dictionary of each tree, and the average percentage of trees that that tree makes up for every street',
'strs_trees_percent_dic_sorted_2': 'list of each tree, sorted by average percentage of trees that that tree makes up for every street',

'strs_tree_counts': 'Dictionary of each street. values are counts of trees on that street, and another dictionary that has each type of tree on that street, and the count of that tree and the percentage makeup of that tree on that street'}

# %%
ash_weighted_streets = {}
for i in strs:
    try:
        ash_weighted_streets[i]=strs_tree_counts[i][0]*strs_tree_counts[i][1]['Ash'][1]
    except:
        pass
ash_weighted_streets = sorted(ash_weighted_streets.items(),key=operator.itemgetter(1),reverse=True)
ash_weighted_streets #### Artificially weighted streets. Took number of total trees on street * percentage of ash
# Out:
# [('9TH ST', 245.0),
#  ('PEARL ST', 156.0),
#  ('LINDEN PARK DR', 149.0),
#  ('BROADWAY', 148.0),
#  ('ARAPAHOE  AV', 122.00000000000001),
#  ('ARAPAHOE AV', 122.0),
#  ('MAPLETON AV', 114.00000000000001),
#  ('SPRUCE ST', 105.0),
#  ('KALMIA AV', 98.0),
#  ('BASELINE RD', 95.0),
#  ('WALNUT ST', 93.0),
#  ('POPLAR AV', 76.0),
#  ('19TH ST', 71.0),
#  ('28TH ST', 70.0),
#  ('13TH ST', 67.0),
#  ('CANYON BV', 67.0),
#  ('PINE ST', 66.0),
#  ('55TH ST', 58.0),
#  ('VALMONT RD', 56.0),
#  ('17TH ST', 55.0),
#  ('30TH ST', 51.0),
#  ('SIOUX DR', 51.0),
#  ('BLUFF ST', 49.0),
#  ('CENTRAL AV', 49.0),
#  ('LINDEN AV', 48.99999999999999),
#  ('S BROADWAY', 48.0),
#  ('JUNIPER AV', 47.0),
#  ('16TH ST', 46.0),
#  ('PENNSYLVANIA AV', 45.0),
#  ('11TH ST', 43.00000000000001),
#  ('4TH ST', 43.0),
#  ('KINGS RIDGE BV', 41.0),
#  ('MOHAWK DR', 40.0),
#  ('8TH ST', 38.0),
#  ('18TH ST', 37.0),
#  ('75TH ST', 37.0),
#  ('GROVE ST', 35.0),
#  ('WHITE PL', 35.0),
#  ('26TH ST', 34.0),
#  ('IRIS AV', 34.0),
#  ('6TH ST', 33.0),
#  ('DAKOTA BV', 33.0),
#  ('FRANKLIN DR', 33.0),
#  ('PLEASANT ST', 33.0),
#  ('34TH ST', 32.0),
#  ('LINCOLN PL', 31.0),
#  ('TABLE MESA DR', 31.0),
#  ('MARINE ST', 30.000000000000004),
#  ('5TH ST', 29.999999999999996),
#  ('UNIVERSITY AV', 29.0),
#  ('47TH ST', 28.0),
#  ('3RD ST', 27.000000000000004),
#  ('FOLSOM ST', 27.0),
#  ('GREENBRIAR BV', 27.0),
#  ('MOORHEAD AV', 27.0),
#  ('TANTRA PARK CR', 27.0),
#  ('7TH ST', 26.0),
#  ('COLLEGE AV', 26.0),
#  ('FLATIRON PY', 26.0),
#  ('ROXWOOD LN', 26.0),
#  ('10TH ST', 25.0),
#  ('MAXWELL AV', 25.0),
#  ('S 36TH ST', 25.0),
#  ('HAWTHORN AV', 23.0),
#  ('QUINCE AV', 23.0),
#  ('15TH ST', 22.0),
#  ('FOOTHILLS PY', 22.0),
#  ('MEADOW GLEN DR', 22.0),
#  ('NORWOOD AV', 22.0),
#  ('SPINE RD', 22.0),
#  ('14TH ST', 21.0),
#  ('ALPINE AV', 21.0),
#  ('BUTTE MILL RD', 21.0),
#  ('LODGE CT', 21.0),
#  ('LODGE LN', 21.0),
#  ('RESERVOIR RD', 21.0),
#  ('WONDERLAND HILL AV', 21.0),
#  ('CHERRY AV', 20.0),
#  ('GIBBS AV', 20.0),
#  ('22ND ST', 19.0),
#  ('GLENWOOD DR', 19.0),
#  ('POPLAR PL', 19.0),
#  ('WRIGHT AV', 19.0),
#  ('CHAUTAUQUA', 18.0),
#  ('MANHATTAN DR', 18.0),
#  ('WINCHESTER CR', 18.0),
#  ('33RD ST', 17.0),
#  ('BLUEBELL AV', 17.0),
#  ('GILLASPIE DR', 17.0),
#  ('ORCHARD AV', 17.0),
#  ('ST. CROIX ST', 17.0),
#  ('63RD ST', 16.0),
#  ('GUNPARK DR', 16.0),
#  ('LEHIGH ST', 16.0),
#  ('NOBLE CT', 16.0),
#  ('SUMAC AV', 16.0),
#  ('TOPAZ DR', 16.0),
#  ('GAPTOR RD', 15.000000000000002),
#  ('20TH ST', 15.0),
#  ('COLORADO AV', 15.0),
#  ('OLD TALE RD', 14.0),
#  ('RACQUET LN', 14.0),
#  ('STERLING CR W', 14.0),
#  ('COMMERCE ST', 13.0),
#  ('OAKLEAF CR', 13.0),
#  ('PENNSYLVANIA PL', 13.0),
#  ('TAMARACK AV', 13.0),
#  ('23RD ST', 12.0),
#  ('CASCADE AV', 12.0),
#  ('CEDAR AV', 12.0),
#  ('GLENDALE GULCH CR', 12.0),
#  ('GOSS ST', 12.0),
#  ('GRANT PL', 12.0),
#  ('MANHATTAN CR', 12.0),
#  ('MEREDITH WAY', 12.0),
#  ('NAUTILUS CT N', 12.0),
#  ('PORTLAND PL', 12.0),
#  ('S BOULDER CR', 12.0),
#  ('STREAMSIDE LN', 12.0),
#  ('21ST ST', 11.0),
#  ('49TH  ST', 11.0),
#  ('CENTENNIAL TR', 11.0),
#  ('EUCLID AV', 11.0),
#  ('GRAPE AV', 11.0),
#  ('OSAGE DR', 11.0),
#  ('REDWOOD AV', 11.0),
#  ('STERLING DR', 11.0),
#  ('29TH ST', 10.0),
#  ('BRIARWOOD DR', 10.0),
#  ('DIAGONAL HY', 10.0),
#  ('E AURORA AV', 10.0),
#  ('HIGHLAND AV', 10.0),
#  ('PONCA PL', 10.0),
#  ('THUNDERBIRD CT E', 10.0),
#  ('WINDING TRAIL DR', 10.0),
#  ('BEAR MOUNTAIN DR', 9.0),
#  ('BROOKLAWN DR', 9.0),
#  ('CHAMBERS DR', 9.0),
#  ('CONCORD AV', 9.0),
#  ('HARTFORD DR', 9.0),
#  ('IRIS CT', 9.0),
#  ('MOUNTAIN VIEW RD', 9.0),
#  ('QUALLA DR', 9.0),
#  ('RIVERBEND RD', 9.0),
#  ('TABLE MESA CT', 9.0),
#  ('ZAMIA AV', 9.0),
#  ('BEAN MOUNTAIN LN', 8.0),
#  ('BELLEVUE DR', 8.0),
#  ('COLUMBINE AV', 8.0),
#  ('EISENHOWER DR', 8.0),
#  ('FAIRWAY CT', 8.0),
#  ('GALENA WY', 8.0),
#  ('LEFT HAND CR', 8.0),
#  ('MACARTHUR LN', 8.0),
#  ('N 63RD ST', 8.0),
#  ('NEVIS ST', 8.0),
#  ('PERIWINKLE DR', 8.0),
#  ('REDSTONE LN', 8.0),
#  ('AURORA AV', 7.0),
#  ('AURORA PL', 7.0),
#  ('CLOVERLEAF DR', 7.0),
#  ('FLORAL DR', 7.0),
#  ('JEWEL CREEK CT', 7.0),
#  ('LASHLEY LN', 7.0),
#  ('LEE CR', 7.0),
#  ('LONE EAGLE CT', 7.0),
#  ('LOOKOUT RD', 7.0),
#  ('MITCHELL LN', 7.0),
#  ('PAWNEE DR', 7.0),
#  ('PENROSE PL', 7.0),
#  ('VALLEY VIEW DR', 7.0),
#  ('REGENT DR', 6.999999999999999),
#  ('CLOUD CT', 6.0),
#  ('CORRIENTE DR', 6.0),
#  ('DELLWOOD AV', 6.0),
#  ('EAGLE WY', 6.0),
#  ('FOXTAIL CT', 6.0),
#  ('GILBERT ST', 6.0),
#  ('JORDAN PL', 6.0),
#  ('LAGUNA PL', 6.0),
#  ('LODGE PL', 6.0),
#  ('LONGBOW DR', 6.0),
#  ('OAK AV', 6.0),
#  ('OAKTREE CT', 6.0),
#  ('ORCHARD CT', 6.0),
#  ('TABLE TOP CT', 6.0),
#  ('VISTA DR', 6.0),
#  ('YELLOW PINE AV', 6.0),
#  ('MARIPOSA AV', 5.999999999999999),
#  ('SUNDOWN LN', 5.999999999999999),
#  ('APACHE RD', 5.0),
#  ('ARNETT ST', 5.0),
#  ('ARROWWOOD LN', 5.0),
#  ('ASH AV', 5.0),
#  ('BALSAM AV', 5.0),
#  ('CENTER GREEN DR', 5.0),
#  ('EVERGREEN AV', 5.0),
#  ('GARNET LN', 5.0),
#  ('HILLSDALE WY', 5.0),
#  ('INDIAN SUMMER CT', 5.0),
#  ('JUNIPER CT', 5.0),
#  ('KOHLER DR', 5.0),
#  ('LARAMIE BL', 5.0),
#  ('LINDEN DR', 5.0),
#  ('LONGBOW CT', 5.0),
#  ('LUDLOW ST', 5.0),
#  ('MINEOLA CT', 5.0),
#  ('MORGAN DR', 5.0),
#  ('NORTH ST', 5.0),
#  ('NORWOOD CT', 5.0),
#  ('PINE VALLEY CT', 5.0),
#  ('ROSEWOOD AV', 5.0),
#  ('STERLING CT', 5.0),
#  ('UPLAND AV', 5.0),
#  ('UTICA CR', 5.0),
#  ('VINEYARD LN', 5.0),
#  ('WELLINGTON RD', 5.0),
#  ('12TH ST', 4.0),
#  ('57TH CT', 4.0),
#  ('BUCKINGHAM RD', 4.0),
#  ('CAYMAN PL', 4.0),
#  ('CORDRY CT', 4.0),
#  ('GUNBARREL AV', 4.0),
#  ('HARDSCRABBLE DR', 4.0),
#  ('HARRISON AV', 4.0),
#  ('HIGH ST', 4.0),
#  ('HURON CT', 4.0),
#  ('INCA PK', 4.0),
#  ('ISLAND DR', 4.0),
#  ('JAY RD', 4.0),
#  ('MEADOW AV', 4.0),
#  ('MORNING GLORY DR', 4.0),
#  ('MULBERRY CT', 4.0),
#  ('NAUTILUS CT S', 4.0),
#  ('NORTH FORK CT', 4.0),
#  ('NORTHBROOK PL', 4.0),
#  ('ODELL PL', 4.0),
#  ('ONEAL PY', 4.0),
#  ('PIMA CT', 4.0),
#  ('PREMIER PL', 4.0),
#  ('REDSTONE RD', 4.0),
#  ('RIM ROCK CT', 4.0),
#  ('SEMINOLE DR', 4.0),
#  ('SHADOW CREEK DR', 4.0),
#  ('STEPHENS RD', 4.0),
#  ('STERLING CR E', 4.0),
#  ('TANTRA DR', 4.0),
#  ('TELLURIDE CR', 4.0),
#  ('VIVIAN CR', 4.0),
#  ('WILDERNESS PL', 4.0),
#  ('27TH  WY', 3.0),
#  ('35TH ST', 3.0),
#  ('48TH  CT', 3.0),
#  ('AIRPORT RD', 3.0),
#  ('ALPINE DR', 3.0),
#  ('BATES AV', 3.0),
#  ('BERKLEY CT', 3.0),
#  ('BLACK HAWK RD', 3.0),
#  ('BROOKFIELD DR', 3.0),
#  ('CASCADE PL', 3.0),
#  ('CHERRYVALE RD', 3.0),
#  ('CLEMATIS DR', 3.0),
#  ('COLLEGE PL', 3.0),
#  ('CONESTOGA CT', 3.0),
#  ('CRESCENT DR', 3.0),
#  ('CRIPPLE CREEK TR', 3.0),
#  ('DEER VALLEY RD', 3.0),
#  ('EDISON AV', 3.0),
#  ('FOREST AV', 3.0),
#  ('FULTON CR', 3.0),
#  ('FURMAN WY', 3.0),
#  ('GENESEE CT', 3.0),
#  ('GRANDVIEW AV', 3.0),
#  ('ILLINI WY', 3.0),
#  ('ITHACA DR', 3.0),
#  ('KENYON CR', 3.0),
#  ('KING AV', 3.0),
#  ('LARAMIE BV', 3.0),
#  ('LINKS DR', 3.0),
#  ('LONGVIEW LN', 3.0),
#  ('MEADOWBROOK DR', 3.0),
#  ('PAMPAS CT', 3.0),
#  ('S 42ND ST', 3.0),
#  ('S 44TH ST', 3.0),
#  ('SILVER LAKE AV', 3.0),
#  ('SLICK ROCK CT', 3.0),
#  ('SPRING VALLEY DR', 3.0),
#  ('SQUIRES CR', 3.0),
#  ('STONEWALL PL', 3.0),
#  ('SYCAMORE AV', 3.0),
#  ('TABRIZ PL', 3.0),
#  ('TELLURIDE PL', 3.0),
#  ('TESLA CIR', 3.0),
#  ('TINCUP CR', 3.0),
#  ('TWIN LAKES RD', 3.0),
#  ('UTICA AV', 3.0),
#  ('WESTERN AV', 3.0),
#  ('WILD PLUM CT', 3.0),
#  ('YARMOUTH AV', 3.0),
#  ('24TH ST', 2.0),
#  ('25TH ST', 2.0),
#  ('31ST ST', 2.0),
#  ('36TH ST', 2.0),
#  ('48TH ST', 2.0),
#  ('ABBEY PL', 2.0),
#  ('AIKINS WY', 2.0),
#  ('ALBION WY', 2.0),
#  ('ARBOR GLEN PL', 2.0),
#  ('BALSAM DR', 2.0),
#  ('BEAR MOUNTAIN CT', 2.0),
#  ('BLUE SAGE CT', 2.0),
#  ('BRANDON CREEK DR', 2.0),
#  ('BURR PL', 2.0),
#  ('BUTTE ST', 2.0),
#  ('CADDO PY', 2.0),
#  ('CIMMARON WY', 2.0),
#  ('DALLAS PL', 2.0),
#  ('DARLEY AV', 2.0),
#  ('DARTMOUTH AV', 2.0),
#  ('DOVER DR', 2.0),
#  ('EDGEWOOD DR', 2.0),
#  ('EUCLID PL', 2.0),
#  ('FAIR PL', 2.0),
#  ('GODDARD PL', 2.0),
#  ('GUADELOUPE ST', 2.0),
#  ('HAMILTON CT', 2.0),
#  ('HANOVER AV', 2.0),
#  ('HAPGOOD ST', 2.0),
#  ('HERMOSA DR', 2.0),
#  ('HIGH COUNTRY CT', 2.0),
#  ('HOLLYBERRY LN', 2.0),
#  ('JAPONICA WY', 2.0),
#  ('JEFFERSON ST', 2.0),
#  ('JIMSON CT', 2.0),
#  ('JUILLIARD ST', 2.0),
#  ('KNOX DR', 2.0),
#  ('LANDIS CT', 2.0),
#  ('LAUREL AV', 2.0),
#  ('LOCUST AV', 2.0),
#  ('LOCUST PL', 2.0),
#  ('LONETREE CT', 2.0),
#  ('LOVE CT', 2.0),
#  ('MADISON AV', 2.0),
#  ('MARTIN DR', 2.0),
#  ('MCKINLEY DR', 2.0),
#  ('MEADOW PL', 2.0),
#  ('MESA DR', 2.0),
#  ('MESA TOP CT', 2.0),
#  ('NEBRINA PL', 2.0),
#  ('NORTH STAR CT', 2.0),
#  ('OAK CR', 2.0),
#  ('ONEAL CR', 2.0),
#  ('ONEAL CR SW', 2.0),
#  ('OTTAWA PL', 2.0),
#  ('PATTON DR', 2.0),
#  ('PINEHURST DR', 2.0),
#  ('PINON DR', 2.0),
#  ('QUAIL CR', 2.0),
#  ('QUARRY CT', 2.0),
#  ('QUINCE CR', 2.0),
#  ('S 31ST ST', 2.0),
#  ('S 32ND ST', 2.0),
#  ('S ORCHARD CREEK CR', 2.0),
#  ('SIERRA DR', 2.0),
#  ('SILVER PLUME LN', 2.0),
#  ('SMUGGLER CR', 2.0),
#  ('SMUGGLER PL', 2.0),
#  ('SPRINGDALE LN', 2.0),
#  ('UNION AV', 2.0),
#  ('UTICA CT', 2.0),
#  ('VIOLET AV', 2.0),
#  ('YALE RD', 2.0),
#  ('YAUPON AV', 2.0),
#  ('DEWEY AV', 1.9999999999999998),
#  ('38TH ST', 1.0),
#  ('AGATE LN', 1.0),
#  ('AMBER ST', 1.0),
#  ('ARMER AV', 1.0),
#  ('ASTOR LN', 1.0),
#  ('ATHENS ST', 1.0),
#  ('AVACADO RD', 1.0),
#  ('AVOCADO RD', 1.0),
#  ('BARBADOS PL', 1.0),
#  ('BEREA DR', 1.0),
#  ('BRANDYWINE CT', 1.0),
#  ('CHASE CT', 1.0),
#  ('CHINLE AV', 1.0),
#  ('CHRISTMAS TREE DR', 1.0),
#  ('CIRCLE DR', 1.0),
#  ('CLEVELAND PL', 1.0),
#  ('COMANCHE DR', 1.0),
#  ('CORONA TR', 1.0),
#  ('CRAGMOOR RD', 1.0),
#  ('CRIPPLE CREEK SQ', 1.0),
#  ('DAKOTA PL', 1.0),
#  ('DEL ROSA CT', 1.0),
#  ('DREW RANCH LN', 1.0),
#  ('E EUCLID AV', 1.0),
#  ('EDISON CT', 1.0),
#  ('ELLSWORTH PL', 1.0),
#  ('ELM AV', 1.0),
#  ('ERIE DR', 1.0),
#  ('EVANS DR', 1.0),
#  ('FERN PL', 1.0),
#  ('FREMONT AV', 1.0),
#  ('FULLER CT', 1.0),
#  ('GALLATIN PL', 1.0),
#  ('GILPIN DR', 1.0),
#  ('GORDON DR', 1.0),
#  ('GUNBARREL CR', 1.0),
#  ('HANCOCK DR', 1.0),
#  ('HARVARD LN', 1.0),
#  ('HAWTHORN PL', 1.0),
#  ('HAZELWOOD CT', 1.0),
#  ('HEIDELBERG DR', 1.0),
#  ('HOLMES PL', 1.0),
#  ('ILIFF ST', 1.0),
#  ('INCA PY', 1.0),
#  ('IROQUOIS DR', 1.0),
#  ('JASMINE CR', 1.0),
#  ('JONATHAN PL', 1.0),
#  ('JUDSON DR', 1.0),
#  ('KALMIA CR', 1.0),
#  ('KELLOGG CR', 1.0),
#  ('KENNEDY CT', 1.0),
#  ('KENWOOD DR', 1.0),
#  ('KINGSTOWN PL', 1.0),
#  ('KINNIKINIC RD', 1.0),
#  ('LAKEBRIAR DR', 1.0),
#  ('LARKWOOD CT', 1.0),
#  ('MACKY WY', 1.0),
#  ('MERRITT DR', 1.0),
#  ('MOFFIT CT', 1.0),
#  ('MOSS ROCK PL', 1.0),
#  ('MOUNTAIN LAUREL PL', 1.0),
#  ('N 55TH ST', 1.0),
#  ('N TERRACE CR', 1.0),
#  ('NEHER LN', 1.0),
#  ('NORTH RIDGE CT', 1.0),
#  ('NORTON ST', 1.0),
#  ('OAKDALE PL', 1.0),
#  ('OAKWOOD PL', 1.0),
#  ('ONEIDA ST', 1.0),
#  ('ONTARIO CT', 1.0),
#  ('OUTBACK CT', 1.0),
#  ('PARK LN', 1.0),
#  ('PARK SADDLE CT', 1.0),
#  ('PAWNEE PL', 1.0),
#  ('PEMBROKE GARDENS', 1.0),
#  ('POPLAR LN', 1.0),
#  ('PROMINTORY CT', 1.0),
#  ('RACQUET CT', 1.0),
#  ('RALSTON ST', 1.0),
#  ('RAMP', 1.0),
#  ('REGIS DR', 1.0),
#  ('ROSE HILL DR', 1.0),
#  ('S 43RD ST', 1.0),
#  ('SCRUB OAK CR', 1.0),
#  ('SENECA PL', 1.0),
#  ('SHERWOOD CR', 1.0),
#  ('SNOWBERRY CT', 1.0),
#  ('SOUTH ST', 1.0),
#  ('SUNNYSIDE LN', 1.0),
#  ('SUNSET BV', 1.0),
#  ('TESLA CT', 1.0),
#  ('TINCUP CT', 1.0),
#  ('TOEDTLI DR', 1.0),
#  ('WHITE ROCK CR', 1.0),
#  ('WILDWOOD RD', 1.0),
#  ('WINGATE AV', 1.0),
#  ('SUNSHINE CANYON DR', 0.9999999999999999)]

# %%
ash_weighted_streets_trees = {}
for i in ash_weighted_streets:
    if strs_tree_counts[i[0]][1]['Ash'][1]>.08: #### grab all streets that have ash percentages of over .08
        ash_weighted_streets_trees[i[0]]=[i[1],sorted(strs_tree_counts[i[0]][1].items(),key=operator.itemgetter(1),reverse=True)[:10]]
ash_weighted_streets_trees #this is a dictionary that has the grabbed streets, weighted value calculated above, and top 10 tree percentages on that street
# Out:
# {'9TH ST': [245.0,
#   [('Ash', [245, 0.22940074906367042]),
#    ('Willow species', [79, 0.07397003745318352]),
#    ('Flowering Crabapple', [60, 0.056179775280898875]),
#    ('Common Honeylocust', [43, 0.040262172284644196]),
#    ('Boxelder', [43, 0.040262172284644196]),
#    ('Siberian Elm', [38, 0.035580524344569285]),
#    ('Native Cottonwood', [33, 0.03089887640449438]),
#    ('Eastern Redcedar', [30, 0.028089887640449437]),
#    ('Western Catalpa', [29, 0.027153558052434457]),
#    ('Blue Spruce', [29, 0.027153558052434457])]],
#  'PEARL ST': [156.0,
#   [('Common Honeylocust', [210, 0.21428571428571427]),
#    ('Ash', [156, 0.15918367346938775]),
#    ('Swamp White Oak', [51, 0.05204081632653061]),
#    ('Northern Hackberry', [50, 0.05102040816326531]),
#    ('American Linden', [31, 0.03163265306122449]),
#    ('Austrian Pine', [31, 0.03163265306122449]),
#    ('Flowering Crabapple', [30, 0.030612244897959183]),
#    ('London Planetree', [30, 0.030612244897959183]),
#    ('Kentucky Coffeetree', [27, 0.027551020408163266]),
#    ('Norway Maple', [22, 0.022448979591836733])]],
#  'LINDEN PARK DR': [149.0,
#   [('Ash', [149, 0.6394849785407726]),
#    ('Plains Cottonwood', [16, 0.06866952789699571]),
#    ('Siberian Elm', [8, 0.034334763948497854]),
#    ('Native Cottonwood', [7, 0.030042918454935622]),
#    ('Austrian Pine', [7, 0.030042918454935622]),
#    ('Crack Willow', [7, 0.030042918454935622]),
#    ('Ponderosa Pine', [5, 0.02145922746781116]),
#    ('Quaking Aspen', [4, 0.017167381974248927]),
#    ('Willow species', [4, 0.017167381974248927]),
#    ('Rocky Mountain Juniper', [4, 0.017167381974248927])]],
#  'BROADWAY': [148.0,
#   [('Common Honeylocust', [153, 0.1047945205479452]),
#    ('Ash', [148, 0.10136986301369863]),
#    ('Flowering Crabapple', [91, 0.06232876712328767]),
#    ('American Linden', [68, 0.04657534246575343]),
#    ('Swamp White Oak', [60, 0.0410958904109589]),
#    ('Siberian Elm', [52, 0.03561643835616438]),
#    ('Northern Hackberry', [49, 0.03356164383561644]),
#    ('Native Cottonwood', [47, 0.03219178082191781]),
#    ('Willow species', [43, 0.02945205479452055]),
#    ('Flowering Pear', [41, 0.028082191780821917])]],
#  'ARAPAHOE  AV': [122.00000000000001,
#   [('Ash', [122, 0.13232104121475055]),
#    ('Crack Willow', [62, 0.06724511930585683]),
#    ('Boxelder', [53, 0.057483731019522775]),
#    ('Common Honeylocust', [52, 0.05639913232104121]),
#    ('Siberian Elm', [50, 0.05422993492407809]),
#    ('Silver Maple', [45, 0.04880694143167028]),
#    ('Swamp White Oak', [45, 0.04880694143167028]),
#    ('Plains Cottonwood', [39, 0.04229934924078091]),
#    ('Flowering Crabapple', [27, 0.02928416485900217]),
#    ('Norway Maple', [26, 0.028199566160520606])]],
#  'ARAPAHOE AV': [122.0,
#   [('Native Cottonwood', [287, 0.2]),
#    ('Blue Spruce', [166, 0.1156794425087108]),
#    ('Austrian Pine', [138, 0.09616724738675958]),
#    ('Ash', [122, 0.08501742160278745]),
#    ('Siberian Elm', [96, 0.06689895470383275]),
#    ('Common Honeylocust', [59, 0.04111498257839721]),
#    ('White Poplar', [58, 0.04041811846689895]),
#    ('Willow species', [54, 0.037630662020905925]),
#    ('White Fir', [38, 0.0264808362369338]),
#    ('Flowering Crabapple', [36, 0.025087108013937282])]],
#  'MAPLETON AV': [114.00000000000001,
#   [('Silver Maple', [129, 0.14429530201342283]),
#    ('Sugar Maple', [115, 0.12863534675615212]),
#    ('Ash', [114, 0.12751677852348994]),
#    ('Norway Maple', [64, 0.07158836689038031]),
#    ('Common Honeylocust', [49, 0.05480984340044743]),
#    ('Flowering Crabapple', [31, 0.03467561521252797]),
#    ('Siberian Elm', [29, 0.03243847874720358]),
#    ('Flowering Pear', [27, 0.030201342281879196]),
#    ('American Linden', [22, 0.024608501118568233]),
#    ('Blue Spruce', [22, 0.024608501118568233])]],
#  'SPRUCE ST': [105.0,
#   [('Ash', [105, 0.14957264957264957]),
#    ('Common Honeylocust', [63, 0.08974358974358974]),
#    ('Siberian Elm', [57, 0.0811965811965812]),
#    ('Silver Maple', [56, 0.07977207977207977]),
#    ('Flowering Crabapple', [36, 0.05128205128205128]),
#    ('American Linden', [25, 0.03561253561253561]),
#    ('Norway Maple', [23, 0.03276353276353276]),
#    ('Western Catalpa', [22, 0.03133903133903134]),
#    ('Tree of Heaven', [21, 0.029914529914529916]),
#    ('Swamp White Oak', [18, 0.02564102564102564])]],
#  'KALMIA AV': [98.0,
#   [('Ash', [98, 0.17915904936014626]),
#    ('Siberian Elm', [50, 0.09140767824497258]),
#    ('Russian-olive', [46, 0.08409506398537477]),
#    ('Austrian Pine', [30, 0.054844606946983544]),
#    ('Blue Spruce', [23, 0.04204753199268738]),
#    ('Flowering Crabapple', [22, 0.04021937842778794]),
#    ('Common Honeylocust', [21, 0.038391224862888484]),
#    ('Willow species', [21, 0.038391224862888484]),
#    ('Littleleaf Linden', [19, 0.03473491773308958]),
#    ('American Linden', [17, 0.031078610603290677])]],
#  'BASELINE RD': [95.0,
#   [('Ash', [95, 0.1074660633484163]),
#    ('Siberian Elm', [72, 0.08144796380090498]),
#    ('Common Honeylocust', [59, 0.0667420814479638]),
#    ('Blue Spruce', [45, 0.05090497737556561]),
#    ('Flowering Crabapple', [45, 0.05090497737556561]),
#    ('Norway Maple', [37, 0.0418552036199095]),
#    ('Pinon Pine', [32, 0.03619909502262444]),
#    ('Goldenrain Tree', [30, 0.033936651583710405]),
#    ('American Elm', [29, 0.032805429864253395]),
#    ('Russian-olive', [25, 0.02828054298642534])]],
#  'WALNUT ST': [93.0,
#   [('Ash', [93, 0.18562874251497005]),
#    ('Common Honeylocust', [60, 0.11976047904191617]),
#    ('Northern Hackberry', [32, 0.06387225548902195]),
#    ('American Linden', [29, 0.05788423153692615]),
#    ('Flowering Crabapple', [21, 0.041916167664670656]),
#    ('Kentucky Coffeetree', [19, 0.03792415169660679]),
#    ('Silver Maple', [18, 0.03592814371257485]),
#    ('Littleleaf Linden', [15, 0.029940119760479042]),
#    ('Bur Oak', [15, 0.029940119760479042]),
#    ('Western Catalpa', [14, 0.027944111776447105])]],
#  'POPLAR AV': [76.0,
#   [('Ash', [76, 0.11428571428571428]),
#    ('Siberian Elm', [71, 0.10676691729323308]),
#    ('Pinon Pine', [66, 0.09924812030075188]),
#    ('Native Cottonwood', [39, 0.058646616541353384]),
#    ('Common Honeylocust', [39, 0.058646616541353384]),
#    ('Silver Maple', [35, 0.05263157894736842]),
#    ('Russian-olive', [30, 0.045112781954887216]),
#    ('Austrian Pine', [29, 0.04360902255639098]),
#    ('Blue Spruce', [24, 0.03609022556390978]),
#    ('Plum species', [19, 0.02857142857142857])]],
#  '19TH ST': [71.0,
#   [('Siberian Elm', [204, 0.26877470355731226]),
#    ('Plains Cottonwood', [104, 0.1370223978919631]),
#    ('Ash', [71, 0.09354413702239789]),
#    ('Blue Spruce', [31, 0.04084321475625823]),
#    ('Austrian Pine', [29, 0.03820816864295125]),
#    ('Common Honeylocust', [27, 0.03557312252964427]),
#    ('Silver Maple', [27, 0.03557312252964427]),
#    ('Flowering Crabapple', [19, 0.025032938076416336]),
#    ('Western Catalpa', [17, 0.022397891963109356]),
#    ('Boxelder', [14, 0.01844532279314888])]],
#  '28TH ST': [70.0,
#   [('Common Honeylocust', [75, 0.09578544061302682]),
#    ('Northern Hackberry', [71, 0.09067688378033206]),
#    ('Ash', [70, 0.08939974457215837]),
#    ('American Linden', [47, 0.06002554278416347]),
#    ('Swamp White Oak', [43, 0.05491698595146871]),
#    ('Sumac species', [42, 0.05363984674329502]),
#    ('Siberian Elm', [37, 0.04725415070242656]),
#    ('Willow species', [37, 0.04725415070242656]),
#    ('Flowering Crabapple', [37, 0.04725415070242656]),
#    ('Native Cottonwood', [34, 0.04342273307790549])]],
#  '13TH ST': [67.0,
#   [('Ash', [67, 0.11452991452991453]),
#    ('Amur Maple', [67, 0.11452991452991453]),
#    ('Siberian Elm', [61, 0.10427350427350428]),
#    ('Common Honeylocust', [52, 0.08888888888888889]),
#    ('Littleleaf Linden', [31, 0.05299145299145299]),
#    ('Red Maple', [22, 0.037606837606837605]),
#    ('Silver Maple', [17, 0.02905982905982906]),
#    ('Flowering Crabapple', [16, 0.02735042735042735]),
#    ('Swamp White Oak', [16, 0.02735042735042735]),
#    ('Freeman Maple', [14, 0.023931623931623933])]],
#  'CANYON BV': [67.0,
#   [('Native Cottonwood', [71, 0.10056657223796034]),
#    ('Ash', [67, 0.09490084985835694]),
#    ('Common Honeylocust', [67, 0.09490084985835694]),
#    ('Black Locust', [59, 0.08356940509915015]),
#    ('Siberian Elm', [59, 0.08356940509915015]),
#    ('Boxelder', [53, 0.07507082152974505]),
#    ('Willow species', [29, 0.04107648725212465]),
#    ('Swamp White Oak', [20, 0.028328611898016998]),
#    ('Northern Red oak', [17, 0.024079320113314446]),
#    ('Rocky Mountain Juniper', [17, 0.024079320113314446])]],
#  'PINE ST': [66.0,
#   [('Silver Maple', [72, 0.1085972850678733]),
#    ('Common Honeylocust', [69, 0.10407239819004525]),
#    ('Ash', [66, 0.09954751131221719]),
#    ('American Linden', [47, 0.07088989441930618]),
#    ('Western Catalpa', [34, 0.05128205128205128]),
#    ('Siberian Elm', [34, 0.05128205128205128]),
#    ('Northern Hackberry', [32, 0.048265460030165915]),
#    ('Swamp White Oak', [31, 0.04675716440422323]),
#    ('Norway Maple', [30, 0.04524886877828054]),
#    ('Sugar Maple', [23, 0.03469079939668175])]],
#  '55TH ST': [58.0,
#   [('Ash', [58, 0.3118279569892473]),
#    ('Siberian Elm', [14, 0.07526881720430108]),
#    ('Austrian Pine', [12, 0.06451612903225806]),
#    ('Hawthorn species', [11, 0.05913978494623656]),
#    ('Washington Hawthorn', [11, 0.05913978494623656]),
#    ('Littleleaf Linden', [11, 0.05913978494623656]),
#    ('Russian-olive', [8, 0.043010752688172046]),
#    ('Thornless Cockspur Hawthorn', [6, 0.03225806451612903]),
#    ('Chokecherry', [5, 0.026881720430107527]),
#    ('Blue Spruce', [5, 0.026881720430107527])]],
#  '17TH ST': [55.0,
#   [('Ash', [55, 0.14248704663212436]),
#    ('Siberian Elm', [32, 0.08290155440414508]),
#    ('Crack Willow', [32, 0.08290155440414508]),
#    ('Common Honeylocust', [23, 0.05958549222797927]),
#    ('Flowering Crabapple', [22, 0.05699481865284974]),
#    ('Boxelder', [19, 0.04922279792746114]),
#    ('Blue Spruce', [14, 0.03626943005181347]),
#    ('Bur Oak', [14, 0.03626943005181347]),
#    ('Austrian Pine', [12, 0.031088082901554404]),
#    ('Quaking Aspen', [9, 0.023316062176165803])]],
#  '30TH ST': [51.0,
#   [('Ash', [51, 0.10991379310344827]),
#    ('Common Honeylocust', [46, 0.09913793103448276]),
#    ('Flowering Crabapple', [35, 0.07543103448275862]),
#    ('Plains Cottonwood', [32, 0.06896551724137931]),
#    ('Swamp White Oak', [26, 0.05603448275862069]),
#    ('Boxelder', [21, 0.04525862068965517]),
#    ('Littleleaf Linden', [21, 0.04525862068965517]),
#    ('Willow species', [16, 0.034482758620689655]),
#    ('Hawthorn species', [12, 0.02586206896551724]),
#    ('Northern Red oak', [12, 0.02586206896551724])]],
#  'SIOUX DR': [51.0,
#   [('Ash', [51, 0.10472279260780287]),
#    ('Plains Cottonwood', [39, 0.08008213552361396]),
#    ('Austrian Pine', [32, 0.06570841889117043]),
#    ('English Oak', [25, 0.0513347022587269]),
#    ('Swamp White Oak', [24, 0.049281314168377825]),
#    ('Yoshino Flowering Cherry', [23, 0.04722792607802875]),
#    ('Kentucky Coffeetree', [17, 0.03490759753593429]),
#    ('Northern Hackberry', [16, 0.03285420944558522]),
#    ('Washington Hawthorn', [15, 0.030800821355236138]),
#    ('Tatarian Maple', [15, 0.030800821355236138])]],
#  'BLUFF ST': [49.0,
#   [('Ash', [49, 0.16723549488054607]),
#    ('Siberian Elm', [35, 0.11945392491467577]),
#    ('Flowering Crabapple', [24, 0.08191126279863481]),
#    ('Common Honeylocust', [17, 0.05802047781569966]),
#    ('Boxelder', [13, 0.04436860068259386]),
#    ('Rocky Mountain Juniper', [12, 0.040955631399317405]),
#    ('Norway Maple', [10, 0.034129692832764506]),
#    ('Staghorn Sumac', [8, 0.027303754266211604]),
#    ('Prairie Crabapple', [7, 0.023890784982935155]),
#    ('Silver Maple', [7, 0.023890784982935155])]],
#  'CENTRAL AV': [49.0,
#   [('Ash', [49, 0.5104166666666666]),
#    ('Swamp White Oak', [10, 0.10416666666666667]),
#    ('Common Honeylocust', [8, 0.08333333333333333]),
#    ('Austrian Pine', [8, 0.08333333333333333]),
#    ('Flowering Crabapple', [7, 0.07291666666666667]),
#    ('Ponderosa Pine', [3, 0.03125]),
#    ('Blue Spruce', [3, 0.03125]),
#    ('Northern Hackberry', [3, 0.03125]),
#    ('Flowering Pear', [2, 0.020833333333333332]),
#    ('Plains Cottonwood', [2, 0.020833333333333332])]],
#  'LINDEN AV': [48.99999999999999,
#   [('Ash', [49, 0.3161290322580645]),
#    ('Siberian Elm', [23, 0.14838709677419354]),
#    ('Common Honeylocust', [12, 0.07741935483870968]),
#    ('Scotch Pine', [7, 0.04516129032258064]),
#    ('Flowering Crabapple', [7, 0.04516129032258064]),
#    ('Littleleaf Linden', [6, 0.03870967741935484]),
#    ('American Elm', [4, 0.025806451612903226]),
#    ('Silver Maple', [4, 0.025806451612903226]),
#    ('Flowering Pear', [4, 0.025806451612903226]),
#    ('Red Tatarian Maple', [4, 0.025806451612903226])]],
#  'S BROADWAY': [48.0,
#   [('Ash', [48, 0.192]),
#    ('Flowering Crabapple', [27, 0.108]),
#    ('Pinon Pine', [26, 0.104]),
#    ('Western Catalpa', [23, 0.092]),
#    ('Juniper species', [19, 0.076]),
#    ('Common Honeylocust', [16, 0.064]),
#    ('Bur Oak', [15, 0.06]),
#    ('Austrian Pine', [12, 0.048]),
#    ('Swamp White Oak', [11, 0.044]),
#    ('Northern Hackberry', [10, 0.04])]],
#  'JUNIPER AV': [47.0,
#   [('Ash', [47, 0.2611111111111111]),
#    ('Silver Maple', [17, 0.09444444444444444]),
#    ('Siberian Elm', [17, 0.09444444444444444]),
#    ('Blue Spruce', [12, 0.06666666666666667]),
#    ('Western Catalpa', [10, 0.05555555555555555]),
#    ('Flowering Crabapple', [9, 0.05]),
#    ('Freeman Maple', [7, 0.03888888888888889]),
#    ('Juniper species', [6, 0.03333333333333333]),
#    ('Willow species', [6, 0.03333333333333333]),
#    ('Native Cottonwood', [5, 0.027777777777777776])]],
#  '16TH ST': [46.0,
#   [('Ash', [46, 0.1220159151193634]),
#    ('Flowering Crabapple', [32, 0.08488063660477453]),
#    ('Siberian Elm', [30, 0.07957559681697612]),
#    ('Common Honeylocust', [29, 0.07692307692307693]),
#    ('Silver Maple', [24, 0.0636604774535809]),
#    ('Flowering Pear', [17, 0.04509283819628647]),
#    ('Swamp White Oak', [17, 0.04509283819628647]),
#    ('Austrian Pine', [14, 0.03713527851458886]),
#    ('Norway Maple', [13, 0.034482758620689655]),
#    ('Northern Red oak', [13, 0.034482758620689655])]],
#  'PENNSYLVANIA AV': [45.0,
#   [('Ash', [45, 0.2132701421800948]),
#    ('Boxelder', [16, 0.07582938388625593]),
#    ('Siberian Elm', [16, 0.07582938388625593]),
#    ('Black Locust', [16, 0.07582938388625593]),
#    ('Northern Hackberry', [12, 0.05687203791469194]),
#    ('Flowering Crabapple', [9, 0.04265402843601896]),
#    ('Quaking Aspen', [9, 0.04265402843601896]),
#    ('Common Honeylocust', [8, 0.037914691943127965]),
#    ('Silver Maple', [7, 0.03317535545023697]),
#    ('Swamp White Oak', [7, 0.03317535545023697])]],
#  '11TH ST': [43.00000000000001,
#   [('Ash', [43, 0.12721893491124261]),
#    ('Common Honeylocust', [41, 0.12130177514792899]),
#    ('Silver Maple', [40, 0.11834319526627218]),
#    ('Sugar Maple', [19, 0.05621301775147929]),
#    ('American Linden', [15, 0.04437869822485207]),
#    ('Siberian Elm', [14, 0.04142011834319527]),
#    ('Norway Maple', [11, 0.03254437869822485]),
#    ('Flowering Crabapple', [11, 0.03254437869822485]),
#    ('Freeman Maple', [9, 0.026627218934911243]),
#    ('Northern Hackberry', [8, 0.023668639053254437])]],
#  '4TH ST': [43.0,
#   [('Ash', [43, 0.09409190371991247]),
#    ('Flowering Crabapple', [38, 0.08315098468271334]),
#    ('Siberian Elm', [37, 0.08096280087527352]),
#    ('Blue Spruce', [32, 0.0700218818380744]),
#    ('Common Honeylocust', [28, 0.061269146608315096]),
#    ('Norway Maple', [25, 0.05470459518599562]),
#    ('Silver Maple', [24, 0.0525164113785558]),
#    ('Plum species', [17, 0.037199124726477024]),
#    ('Sugar Maple', [13, 0.028446389496717725]),
#    ('Native Cottonwood', [12, 0.0262582056892779])]],
#  'KINGS RIDGE BV': [41.0,
#   [('Ash', [41, 0.24260355029585798]),
#    ('Common Honeylocust', [22, 0.1301775147928994]),
#    ('Flowering Crabapple', [12, 0.07100591715976332]),
#    ('Lanceleaf Cottonwood', [11, 0.0650887573964497]),
#    ('Siberian Elm', [9, 0.05325443786982249]),
#    ('English Oak', [6, 0.03550295857988166]),
#    ('Crack Willow', [6, 0.03550295857988166]),
#    ('Blue Spruce', [5, 0.029585798816568046]),
#    ('Littleleaf Linden', [5, 0.029585798816568046]),
#    ('Accolade Elm', [4, 0.023668639053254437])]],
#  'MOHAWK DR': [40.0,
#   [('Ash', [40, 0.2]),
#    ('American Linden', [21, 0.105]),
#    ('Blue Spruce', [14, 0.07]),
#    ('Flowering Crabapple', [11, 0.055]),
#    ('Siberian Elm', [9, 0.045]),
#    ('Norway Maple', [7, 0.035]),
#    ('Western Catalpa', [7, 0.035]),
#    ('Flowering Pear', [6, 0.03]),
#    ('Common Honeylocust', [5, 0.025]),
#    ('Austrian Pine', [5, 0.025])]],
#  '8TH ST': [38.0,
#   [('Ash', [38, 0.11912225705329153]),
#    ('Silver Maple', [27, 0.08463949843260188]),
#    ('Siberian Elm', [19, 0.05956112852664577]),
#    ('Flowering Crabapple', [17, 0.05329153605015674]),
#    ('Austrian Pine', [14, 0.0438871473354232]),
#    ('Sugar Maple', [13, 0.04075235109717868]),
#    ('Common Honeylocust', [13, 0.04075235109717868]),
#    ('Blue Spruce', [13, 0.04075235109717868]),
#    ('Northern Hackberry', [10, 0.03134796238244514]),
#    ('Northern Red oak', [9, 0.02821316614420063])]],
#  '18TH ST': [37.0,
#   [('Ash', [37, 0.13805970149253732]),
#    ('Siberian Elm', [22, 0.08208955223880597]),
#    ('Silver Maple', [17, 0.06343283582089553]),
#    ('Tree of Heaven', [17, 0.06343283582089553]),
#    ('Flowering Crabapple', [16, 0.05970149253731343]),
#    ('Common Honeylocust', [14, 0.05223880597014925]),
#    ('Blue Spruce', [13, 0.048507462686567165]),
#    ('Boxelder', [11, 0.041044776119402986]),
#    ('Quaking Aspen', [9, 0.033582089552238806]),
#    ('Northern Red oak', [7, 0.026119402985074626])]],
#  '75TH ST': [37.0,
#   [('Austrian Pine', [51, 0.2328767123287671]),
#    ('Ash', [37, 0.1689497716894977]),
#    ('Blue Spruce', [23, 0.1050228310502283]),
#    ('Pinon Pine', [17, 0.0776255707762557]),
#    ('Northern Hackberry', [15, 0.0684931506849315]),
#    ('Common Honeylocust', [10, 0.045662100456621]),
#    ('Ponderosa Pine', [9, 0.0410958904109589]),
#    ('Cockspur hawthorn', [7, 0.0319634703196347]),
#    ('Flowering Crabapple', [7, 0.0319634703196347]),
#    ('English Oak', [5, 0.0228310502283105])]],
#  'GROVE ST': [35.0,
#   [('Ash', [35, 0.2]),
#    ('Common Honeylocust', [16, 0.09142857142857143]),
#    ('Silver Maple', [13, 0.07428571428571429]),
#    ('Tree of Heaven', [10, 0.05714285714285714]),
#    ('Western Catalpa', [10, 0.05714285714285714]),
#    ('Siberian Elm', [9, 0.05142857142857143]),
#    ('Bur Oak', [6, 0.03428571428571429]),
#    ('Swamp White Oak', [6, 0.03428571428571429]),
#    ('Littleleaf Linden', [5, 0.02857142857142857]),
#    ('Norway Maple', [5, 0.02857142857142857])]],
#  'WHITE PL': [35.0,
#   [('Ash', [35, 0.7954545454545454]),
#    ('Flowering Crabapple', [2, 0.045454545454545456]),
#    ('White Fir', [2, 0.045454545454545456]),
#    ('Common Honeylocust', [2, 0.045454545454545456]),
#    ('Red Tatarian Maple', [2, 0.045454545454545456]),
#    ('Blue Spruce', [1, 0.022727272727272728])]],
#  '26TH ST': [34.0,
#   [('Siberian Elm', [99, 0.44]),
#    ('Ash', [34, 0.1511111111111111]),
#    ('Tree of Heaven', [12, 0.05333333333333334]),
#    ('Flowering Crabapple', [9, 0.04]),
#    ('Common Honeylocust', [8, 0.035555555555555556]),
#    ('Blue Spruce', [7, 0.03111111111111111]),
#    ('Austrian Pine', [6, 0.02666666666666667]),
#    ('Mugo Pine', [6, 0.02666666666666667]),
#    ('Native Cottonwood', [5, 0.022222222222222223]),
#    ('Boxelder', [4, 0.017777777777777778])]],
#  'IRIS AV': [34.0,
#   [('Ash', [34, 0.11295681063122924]),
#    ('Siberian Elm', [27, 0.08970099667774087]),
#    ('Common Honeylocust', [21, 0.06976744186046512]),
#    ('Pinon Pine', [21, 0.06976744186046512]),
#    ('Northern Hackberry', [17, 0.05647840531561462]),
#    ('Swamp White Oak', [14, 0.046511627906976744]),
#    ('Native Cottonwood', [13, 0.04318936877076412]),
#    ('Thornless Cockspur Hawthorn', [11, 0.036544850498338874]),
#    ('Hybrid Cottonwood', [10, 0.03322259136212625]),
#    ('Rocky Mountain Juniper', [10, 0.03322259136212625])]],
#  'DAKOTA BV': [33.0,
#   [('Flowering Crabapple', [35, 0.13358778625954199]),
#    ('Ash', [33, 0.12595419847328243]),
#    ('Northern Hackberry', [19, 0.07251908396946564]),
#    ('Pinon Pine', [18, 0.06870229007633588]),
#    ('Flowering Pear', [17, 0.0648854961832061]),
#    ('Bur Oak', [16, 0.061068702290076333]),
#    ('Western Catalpa', [14, 0.05343511450381679]),
#    ('Kentucky Coffeetree', [14, 0.05343511450381679]),
#    ('American Linden', [12, 0.04580152671755725]),
#    ('Common Honeylocust', [11, 0.04198473282442748])]],
#  'FRANKLIN DR': [33.0,
#   [('Ash', [33, 0.3055555555555556]),
#    ('Common Honeylocust', [22, 0.2037037037037037]),
#    ('Red Tatarian Maple', [8, 0.07407407407407407]),
#    ('Kentucky Coffeetree', [6, 0.05555555555555555]),
#    ('Sugar Maple', [5, 0.046296296296296294]),
#    ('Swamp White Oak', [4, 0.037037037037037035]),
#    ('Upright English Oak', [4, 0.037037037037037035]),
#    ('English Oak', [3, 0.027777777777777776]),
#    ('Western Catalpa', [2, 0.018518518518518517]),
#    ('Red Maple', [2, 0.018518518518518517])]],
#  'PLEASANT ST': [33.0,
#   [('Ash', [33, 0.12890625]),
#    ('Siberian Elm', [30, 0.1171875]),
#    ('Boxelder', [28, 0.109375]),
#    ('Black Locust', [21, 0.08203125]),
#    ('Northern Hackberry', [17, 0.06640625]),
#    ('Silver Maple', [14, 0.0546875]),
#    ('Flowering Crabapple', [13, 0.05078125]),
#    ('Common Honeylocust', [9, 0.03515625]),
#    ('American Elm', [9, 0.03515625]),
#    ('Austrian Pine', [6, 0.0234375])]],
#  '34TH ST': [32.0,
#   [('Ash', [32, 0.1787709497206704]),
#    ('Siberian Elm', [25, 0.13966480446927373]),
#    ('Boxelder', [17, 0.09497206703910614]),
#    ('Willow species', [17, 0.09497206703910614]),
#    ('Flowering Crabapple', [12, 0.0670391061452514]),
#    ('Native Cottonwood', [10, 0.055865921787709494]),
#    ('Littleleaf Linden', [7, 0.03910614525139665]),
#    ('Common Honeylocust', [6, 0.0335195530726257]),
#    ('Plains Cottonwood', [5, 0.027932960893854747]),
#    ('Bur Oak', [4, 0.0223463687150838])]],
#  'LINCOLN PL': [31.0,
#   [('Common Honeylocust', [36, 0.15584415584415584]),
#    ('Ash', [31, 0.1341991341991342]),
#    ('Silver Maple', [23, 0.09956709956709957]),
#    ('American Linden', [12, 0.05194805194805195]),
#    ('Pinon Pine', [12, 0.05194805194805195]),
#    ('Sugar Maple', [11, 0.047619047619047616]),
#    ('Flowering Crabapple', [10, 0.04329004329004329]),
#    ('English Oak', [9, 0.03896103896103896]),
#    ('Siberian Elm', [9, 0.03896103896103896]),
#    ('Blue Spruce', [8, 0.03463203463203463])]],
#  'TABLE MESA DR': [31.0,
#   [('Ash', [31, 0.16145833333333334]),
#    ('Common Honeylocust', [21, 0.109375]),
#    ('Flowering Crabapple', [16, 0.08333333333333333]),
#    ('Flowering Pear', [14, 0.07291666666666667]),
#    ('Swamp White Oak', [10, 0.052083333333333336]),
#    ('Blue Spruce', [8, 0.041666666666666664]),
#    ('Tatarian Maple', [8, 0.041666666666666664]),
#    ('Siberian Elm', [7, 0.036458333333333336]),
#    ('Native Cottonwood', [7, 0.036458333333333336]),
#    ('Common Hawthorn', [6, 0.03125])]],
#  'MARINE ST': [30.000000000000004,
#   [('Ash', [30, 0.1382488479262673]),
#    ('Silver Maple', [24, 0.11059907834101383]),
#    ('Tree of Heaven', [22, 0.10138248847926268]),
#    ('Common Honeylocust', [20, 0.09216589861751152]),
#    ('Norway Maple', [14, 0.06451612903225806]),
#    ('Northern Hackberry', [9, 0.041474654377880185]),
#    ('Littleleaf Linden', [8, 0.03686635944700461]),
#    ('Flowering Crabapple', [8, 0.03686635944700461]),
#    ('Blue Spruce', [7, 0.03225806451612903]),
#    ('Siberian Elm', [7, 0.03225806451612903])]],
#  'UNIVERSITY AV': [29.0,
#   [('Ash', [29, 0.11788617886178862]),
#    ('American Elm', [29, 0.11788617886178862]),
#    ('Silver Maple', [20, 0.08130081300813008]),
#    ('Flowering Crabapple', [16, 0.06504065040650407]),
#    ('Siberian Elm', [14, 0.056910569105691054]),
#    ('Common Honeylocust', [12, 0.04878048780487805]),
#    ('Pin Oak', [8, 0.032520325203252036]),
#    ('Boxelder', [7, 0.028455284552845527]),
#    ('Northern Hackberry', [7, 0.028455284552845527]),
#    ('Black Locust', [6, 0.024390243902439025])]],
#  '47TH ST': [28.0,
#   [('Crack Willow', [32, 0.1693121693121693]),
#    ('Ash', [28, 0.14814814814814814]),
#    ('Flowering Crabapple', [17, 0.08994708994708994]),
#    ('American Linden', [12, 0.06349206349206349]),
#    ('Siberian Elm', [12, 0.06349206349206349]),
#    ('Accolade Elm', [10, 0.05291005291005291]),
#    ('Northern Hackberry', [8, 0.042328042328042326]),
#    ('Boxelder', [7, 0.037037037037037035]),
#    ('Chinkapin Oak', [7, 0.037037037037037035]),
#    ('Kentucky Coffeetree', [6, 0.031746031746031744])]],
#  '3RD ST': [27.000000000000004,
#   [('Ash', [27, 0.12558139534883722]),
#    ('Siberian Elm', [26, 0.12093023255813953]),
#    ('Blue Spruce', [23, 0.10697674418604651]),
#    ('Juniper species', [18, 0.08372093023255814]),
#    ('Native Cottonwood', [14, 0.06511627906976744]),
#    ('Pinon Pine', [13, 0.06046511627906977]),
#    ('Ponderosa Pine', [13, 0.06046511627906977]),
#    ('Common Honeylocust', [9, 0.04186046511627907]),
#    ('Black Walnut', [9, 0.04186046511627907]),
#    ('Russian-olive', [6, 0.027906976744186046])]],
#  'FOLSOM ST': [27.0,
#   [('Ash', [27, 0.2621359223300971]),
#    ('Siberian Elm', [19, 0.18446601941747573]),
#    ('Common Honeylocust', [10, 0.0970873786407767]),
#    ('Flowering Crabapple', [8, 0.07766990291262135]),
#    ('American Linden', [8, 0.07766990291262135]),
#    ('Western Catalpa', [4, 0.038834951456310676]),
#    ('Northern Hackberry', [3, 0.02912621359223301]),
#    ('American Elm', [2, 0.019417475728155338]),
#    ('Pinon Pine', [2, 0.019417475728155338]),
#    ('Silver Maple', [2, 0.019417475728155338])]],
#  'GREENBRIAR BV': [27.0,
#   [('Flowering Crabapple', [29, 0.3020833333333333]),
#    ('Ash', [27, 0.28125]),
#    ('Common Honeylocust', [12, 0.125]),
#    ('Austrian Pine', [12, 0.125]),
#    ('Western Catalpa', [4, 0.041666666666666664]),
#    ('Silver Maple', [4, 0.041666666666666664]),
#    ('Pinon Pine', [4, 0.041666666666666664]),
#    ('Ponderosa Pine', [2, 0.020833333333333332]),
#    ('Kentucky Coffeetree', [1, 0.010416666666666666]),
#    ('Serviceberry species', [1, 0.010416666666666666])]],
#  'MOORHEAD AV': [27.0,
#   [('Ash', [27, 0.2109375]),
#    ('Siberian Elm', [22, 0.171875]),
#    ('Common Honeylocust', [10, 0.078125]),
#    ('Juniper species', [10, 0.078125]),
#    ('Russian-olive', [10, 0.078125]),
#    ('Northern Red oak', [9, 0.0703125]),
#    ('Austrian Pine', [5, 0.0390625]),
#    ('Flowering Crabapple', [4, 0.03125]),
#    ('Douglas-fir', [3, 0.0234375]),
#    ('Blue Spruce', [3, 0.0234375])]],
#  'TANTRA PARK CR': [27.0,
#   [('Ash', [27, 0.11297071129707113]),
#    ('Austrian Pine', [25, 0.10460251046025104]),
#    ('Blue Spruce', [24, 0.100418410041841]),
#    ('Common Honeylocust', [23, 0.09623430962343096]),
#    ('Plains Cottonwood', [19, 0.0794979079497908]),
#    ('Hawthorn species', [15, 0.06276150627615062]),
#    ('Pinon Pine', [13, 0.05439330543933055]),
#    ('Crack Willow', [11, 0.04602510460251046]),
#    ('Flowering Crabapple', [8, 0.03347280334728033]),
#    ('Ponderosa Pine', [8, 0.03347280334728033])]],
#  '7TH ST': [26.0,
#   [('Silver Maple', [28, 0.09271523178807947]),
#    ('Flowering Crabapple', [27, 0.08940397350993377]),
#    ('Ash', [26, 0.08609271523178808]),
#    ('Siberian Elm', [16, 0.052980132450331126]),
#    ('Blue Spruce', [16, 0.052980132450331126]),
#    ('Northern Hackberry', [16, 0.052980132450331126]),
#    ('Flowering Pear', [14, 0.046357615894039736]),
#    ('Plum species', [12, 0.039735099337748346]),
#    ('Sugar Maple', [11, 0.03642384105960265]),
#    ('Norway Maple', [11, 0.03642384105960265])]],
#  'COLLEGE AV': [26.0,
#   [('Ash', [26, 0.12206572769953052]),
#    ('Rocky Mountain Juniper', [22, 0.10328638497652583]),
#    ('Siberian Elm', [20, 0.09389671361502347]),
#    ('Flowering Crabapple', [19, 0.0892018779342723]),
#    ('Blue Spruce', [16, 0.07511737089201878]),
#    ('Common Honeylocust', [12, 0.056338028169014086]),
#    ('Austrian Pine', [11, 0.051643192488262914]),
#    ('Silver Maple', [9, 0.04225352112676056]),
#    ('Ponderosa Pine', [9, 0.04225352112676056]),
#    ('Pinon Pine', [6, 0.028169014084507043])]],
#  'FLATIRON PY': [26.0,
#   [('Ash', [26, 0.6341463414634146]),
#    ('Pin Oak', [8, 0.1951219512195122]),
#    ('Littleleaf Linden', [4, 0.0975609756097561]),
#    ('Red Maple', [2, 0.04878048780487805]),
#    ('Common Honeylocust', [1, 0.024390243902439025])]],
#  'ROXWOOD LN': [26.0,
#   [('Siberian Elm', [92, 0.4052863436123348]),
#    ('Ash', [26, 0.1145374449339207]),
#    ('Native Cottonwood', [23, 0.1013215859030837]),
#    ('Juniper species', [22, 0.09691629955947137]),
#    ('Russian-olive', [21, 0.09251101321585903]),
#    ('Willow species', [15, 0.06607929515418502]),
#    ('Flowering Crabapple', [6, 0.02643171806167401]),
#    ('American Elm', [4, 0.01762114537444934]),
#    ('Common Honeylocust', [3, 0.013215859030837005]),
#    ('Boxelder', [3, 0.013215859030837005])]],
#  'MAXWELL AV': [25.0,
#   [('Ash', [25, 0.1488095238095238]),
#    ('Silver Maple', [22, 0.13095238095238096]),
#    ('Norway Maple', [15, 0.08928571428571429]),
#    ('Western Catalpa', [11, 0.06547619047619048]),
#    ('Flowering Crabapple', [11, 0.06547619047619048]),
#    ('Swamp White Oak', [7, 0.041666666666666664]),
#    ('Northern Red oak', [6, 0.03571428571428571]),
#    ('American Linden', [5, 0.02976190476190476]),
#    ('Common Honeylocust', [4, 0.023809523809523808]),
#    ('Sugar Maple', [3, 0.017857142857142856])]],
#  'S 36TH ST': [25.0,
#   [('Willow species', [38, 0.15384615384615385]),
#    ('Plains Cottonwood', [33, 0.13360323886639677]),
#    ('Ash', [25, 0.10121457489878542]),
#    ('Flowering Crabapple', [17, 0.06882591093117409]),
#    ('Native Cottonwood', [13, 0.05263157894736842]),
#    ('Blue Spruce', [11, 0.044534412955465584]),
#    ('Common Honeylocust', [10, 0.04048582995951417]),
#    ('Siberian Elm', [8, 0.032388663967611336]),
#    ('English Oak', [7, 0.02834008097165992]),
#    ('Northern Hackberry', [7, 0.02834008097165992])]],
#  'HAWTHORN AV': [23.0,
#   [('Flowering Crabapple', [25, 0.1497005988023952]),
#    ('Ash', [23, 0.1377245508982036]),
#    ('Siberian Elm', [21, 0.12574850299401197]),
#    ('Plum species', [12, 0.0718562874251497]),
#    ('Northern Hackberry', [9, 0.05389221556886228]),
#    ('Austrian Pine', [6, 0.03592814371257485]),
#    ('Norway Maple', [5, 0.029940119760479042]),
#    ('Western Catalpa', [5, 0.029940119760479042]),
#    ('Quaking Aspen', [5, 0.029940119760479042]),
#    ('Black Locust', [5, 0.029940119760479042])]],
#  'QUINCE AV': [23.0,
#   [('Siberian Elm', [92, 0.3333333333333333]),
#    ('Norway Maple', [24, 0.08695652173913043]),
#    ('Ash', [23, 0.08333333333333333]),
#    ('Russian-olive', [16, 0.057971014492753624]),
#    ('Austrian Pine', [13, 0.04710144927536232]),
#    ('Flowering Crabapple', [12, 0.043478260869565216]),
#    ('Quaking Aspen', [12, 0.043478260869565216]),
#    ('Common Honeylocust', [8, 0.028985507246376812]),
#    ('Mugo Pine', [6, 0.021739130434782608]),
#    ('White Oak', [6, 0.021739130434782608])]],
#  'MEADOW GLEN DR': [22.0,
#   [('Ash', [22, 0.34375]),
#    ('Silver Maple', [6, 0.09375]),
#    ('Littleleaf Linden', [5, 0.078125]),
#    ('Red Maple', [4, 0.0625]),
#    ('Northern Red oak', [4, 0.0625]),
#    ('Norway Maple', [4, 0.0625]),
#    ('Freeman Maple', [3, 0.046875]),
#    ('Plum species', [3, 0.046875]),
#    ('European Ash', [3, 0.046875]),
#    ('Sugar Maple', [2, 0.03125])]],
#  'NORWOOD AV': [22.0,
#   [('Siberian Elm', [49, 0.23902439024390243]),
#    ('Flowering Crabapple', [38, 0.18536585365853658]),
#    ('Ash', [22, 0.1073170731707317]),
#    ('Quaking Aspen', [11, 0.05365853658536585]),
#    ('Common Honeylocust', [10, 0.04878048780487805]),
#    ('Western Catalpa', [8, 0.03902439024390244]),
#    ('Blue Spruce', [6, 0.02926829268292683]),
#    ('Freeman Maple', [6, 0.02926829268292683]),
#    ('Juniper species', [5, 0.024390243902439025]),
#    ('Hawthorn species', [4, 0.01951219512195122])]],
#  'SPINE RD': [22.0,
#   [('Ash', [22, 0.1437908496732026]),
#    ('Northern Hackberry', [18, 0.11764705882352941]),
#    ('Littleleaf Linden', [17, 0.1111111111111111]),
#    ('Swamp White Oak', [14, 0.0915032679738562]),
#    ('Flowering Crabapple', [14, 0.0915032679738562]),
#    ('Bur Oak', [9, 0.058823529411764705]),
#    ('Norway Maple', [9, 0.058823529411764705]),
#    ('Common Honeylocust', [8, 0.05228758169934641]),
#    ('Lanceleaf Cottonwood', [6, 0.0392156862745098]),
#    ('English Oak', [5, 0.032679738562091505])]],
#  'ALPINE AV': [21.0,
#   [('Ash', [21, 0.14685314685314685]),
#    ('Common Honeylocust', [13, 0.09090909090909091]),
#    ('Siberian Elm', [9, 0.06293706293706294]),
#    ('Silver Maple', [8, 0.055944055944055944]),
#    ('Flowering Crabapple', [8, 0.055944055944055944]),
#    ('Blue Spruce', [7, 0.04895104895104895]),
#    ('Sugar Maple', [7, 0.04895104895104895]),
#    ('Boxelder', [6, 0.04195804195804196]),
#    ('Flowering Pear', [5, 0.03496503496503497]),
#    ('Pinon Pine', [5, 0.03496503496503497])]],
#  'BUTTE MILL RD': [21.0,
#   [('Native Cottonwood', [42, 0.28187919463087246]),
#    ('Ash', [21, 0.14093959731543623]),
#    ('White Poplar', [11, 0.0738255033557047]),
#    ('Siberian Elm', [8, 0.053691275167785234]),
#    ('Willow species', [7, 0.04697986577181208]),
#    ('Oak species', [6, 0.040268456375838924]),
#    ('Black Locust', [4, 0.026845637583892617]),
#    ('Boxelder', [4, 0.026845637583892617]),
#    ('Western Catalpa', [3, 0.020134228187919462]),
#    ('English Oak', [3, 0.020134228187919462])]],
#  'LODGE CT': [21.0,
#   [('Ash', [21, 0.6363636363636364]),
#    ('Flowering Crabapple', [5, 0.15151515151515152]),
#    ('Ponderosa Pine', [3, 0.09090909090909091]),
#    ('Common Honeylocust', [3, 0.09090909090909091]),
#    ('Boxelder', [1, 0.030303030303030304])]],
#  'LODGE LN': [21.0,
#   [('Ash', [21, 0.3442622950819672]),
#    ('Austrian Pine', [16, 0.26229508196721313]),
#    ('Flowering Crabapple', [6, 0.09836065573770492]),
#    ('Ponderosa Pine', [6, 0.09836065573770492]),
#    ('Silver Maple', [3, 0.04918032786885246]),
#    ('Common Honeylocust', [2, 0.03278688524590164]),
#    ('Chokecherry', [2, 0.03278688524590164]),
#    ('Native Cottonwood', [1, 0.01639344262295082]),
#    ('Blue Spruce', [1, 0.01639344262295082]),
#    ('Hawthorn species', [1, 0.01639344262295082])]],
#  'RESERVOIR RD': [21.0,
#   [('Plains Cottonwood', [95, 0.38306451612903225]),
#    ('Crack Willow', [21, 0.0846774193548387]),
#    ('Ash', [21, 0.0846774193548387]),
#    ('Northern Hackberry', [15, 0.06048387096774194]),
#    ('Western Catalpa', [11, 0.04435483870967742]),
#    ('Siberian Elm', [10, 0.04032258064516129]),
#    ('Kentucky Coffeetree', [9, 0.036290322580645164]),
#    ('Common Honeylocust', [9, 0.036290322580645164]),
#    ('Lanceleaf Cottonwood', [8, 0.03225806451612903]),
#    ('Russian Hawthorn', [8, 0.03225806451612903])]],
#  'WONDERLAND HILL AV': [21.0,
#   [('Ash', [21, 0.17796610169491525]),
#    ('Austrian Pine', [21, 0.17796610169491525]),
#    ('American Linden', [9, 0.07627118644067797]),
#    ('Silver Maple', [8, 0.06779661016949153]),
#    ('Flowering Crabapple', [8, 0.06779661016949153]),
#    ('Hawthorn species', [7, 0.059322033898305086]),
#    ('Blue Spruce', [5, 0.0423728813559322]),
#    ('Pinon Pine', [5, 0.0423728813559322]),
#    ('Rocky Mountain Juniper', [4, 0.03389830508474576]),
#    ('Siberian Elm', [3, 0.025423728813559324])]],
#  'GIBBS AV': [20.0,
#   [('Ash', [20, 0.425531914893617]),
#    ('Common Honeylocust', [11, 0.23404255319148937]),
#    ('Flowering Pear', [2, 0.0425531914893617]),
#    ('Kentucky Coffeetree', [2, 0.0425531914893617]),
#    ('Sugar Maple', [2, 0.0425531914893617]),
#    ('Freeman Maple', [1, 0.02127659574468085]),
#    ('Silver Maple', [1, 0.02127659574468085]),
#    ('Northern Red oak', [1, 0.02127659574468085]),
#    ('Red Maple', [1, 0.02127659574468085]),
#    ('Yellow Buckeye', [1, 0.02127659574468085])]],
#  '22ND ST': [19.0,
#   [('Ash', [19, 0.1347517730496454]),
#    ('Blue Spruce', [12, 0.0851063829787234]),
#    ('Flowering Crabapple', [12, 0.0851063829787234]),
#    ('Common Honeylocust', [11, 0.07801418439716312]),
#    ('Silver Maple', [9, 0.06382978723404255]),
#    ('Thornless Cockspur Hawthorn', [6, 0.0425531914893617]),
#    ('Quaking Aspen', [6, 0.0425531914893617]),
#    ('Plum species', [5, 0.03546099290780142]),
#    ('Norway Maple', [5, 0.03546099290780142]),
#    ('Flowering Pear', [4, 0.028368794326241134])]],
#  'GLENWOOD DR': [19.0,
#   [('Ash', [19, 0.16379310344827586]),
#    ('Common Honeylocust', [13, 0.11206896551724138]),
#    ('Silver Maple', [12, 0.10344827586206896]),
#    ('Littleleaf Linden', [10, 0.08620689655172414]),
#    ('Flowering Crabapple', [7, 0.0603448275862069]),
#    ('American Linden', [6, 0.05172413793103448]),
#    ('Blue Spruce', [5, 0.04310344827586207]),
#    ('Juniper species', [5, 0.04310344827586207]),
#    ('English Oak', [5, 0.04310344827586207]),
#    ('Plum species', [4, 0.034482758620689655])]],
#  'POPLAR PL': [19.0,
#   [('Ash', [19, 0.475]),
#    ('Common Honeylocust', [6, 0.15]),
#    ('Swamp White Oak', [2, 0.05]),
#    ('Littleleaf Linden', [2, 0.05]),
#    (nan, [1, 0.025]),
#    ('Siberian Elm', [1, 0.025]),
#    ('London Planetree', [1, 0.025]),
#    ('Juniper species', [1, 0.025]),
#    ('White Spruce', [1, 0.025]),
#    ('Baldcypress', [1, 0.025])]],
#  'WRIGHT AV': [19.0,
#   [('Ash', [19, 0.4222222222222222]),
#    ('Common Honeylocust', [5, 0.1111111111111111]),
#    ('Flowering Pear', [3, 0.06666666666666667]),
#    ('English Oak', [3, 0.06666666666666667]),
#    ('Western Catalpa', [2, 0.044444444444444446]),
#    ('Turkish Filbert', [2, 0.044444444444444446]),
#    ('Red Maple', [2, 0.044444444444444446]),
#    ('Upright English Oak', [2, 0.044444444444444446]),
#    ('Sugar Maple', [2, 0.044444444444444446]),
#    ('Northern Hackberry', [1, 0.022222222222222223])]],
#  'CHAUTAUQUA': [18.0, [('Ash', [18, 1.0])]],
#  'MANHATTAN DR': [18.0,
#   [('Ash', [18, 0.13432835820895522]),
#    ('Austrian Pine', [16, 0.11940298507462686]),
#    ('Blue Spruce', [9, 0.06716417910447761]),
#    ('Northern Red oak', [9, 0.06716417910447761]),
#    ('Common Honeylocust', [8, 0.05970149253731343]),
#    ('American Linden', [7, 0.05223880597014925]),
#    ('Flowering Crabapple', [6, 0.04477611940298507]),
#    ('Littleleaf Linden', [6, 0.04477611940298507]),
#    ('Flowering Pear', [5, 0.03731343283582089]),
#    ('Norway Maple', [4, 0.029850746268656716])]],
#  'WINCHESTER CR': [18.0,
#   [('American Linden', [60, 0.5357142857142857]),
#    ('Ash', [18, 0.16071428571428573]),
#    ('Common Honeylocust', [11, 0.09821428571428571]),
#    ('Pinon Pine', [9, 0.08035714285714286]),
#    ('Bur Oak', [4, 0.03571428571428571]),
#    ('Red Maple', [4, 0.03571428571428571]),
#    ('Littleleaf Linden', [3, 0.026785714285714284]),
#    ('Austrian Pine', [1, 0.008928571428571428]),
#    ('Norway Maple', [1, 0.008928571428571428]),
#    ('Siberian Elm', [1, 0.008928571428571428])]],
#  '33RD ST': [17.0,
#   [('Ash', [17, 0.24285714285714285]),
#    ('Austrian Pine', [15, 0.21428571428571427]),
#    ('Swamp White Oak', [6, 0.08571428571428572]),
#    ('Common Honeylocust', [4, 0.05714285714285714]),
#    ('Flowering Pear', [4, 0.05714285714285714]),
#    ('Ponderosa Pine', [4, 0.05714285714285714]),
#    ('Pinon Pine', [3, 0.04285714285714286]),
#    ('Amur Maple', [3, 0.04285714285714286]),
#    ('Serviceberry species', [2, 0.02857142857142857]),
#    ('Northern Hackberry', [2, 0.02857142857142857])]],
#  'BLUEBELL AV': [17.0,
#   [('Ash', [17, 0.096045197740113]),
#    ('Blue Spruce', [14, 0.07909604519774012]),
#    ('Flowering Crabapple', [12, 0.06779661016949153]),
#    ('Norway Maple', [12, 0.06779661016949153]),
#    ('Plum species', [10, 0.05649717514124294]),
#    ('Quaking Aspen', [9, 0.05084745762711865]),
#    ('Common Honeylocust', [7, 0.03954802259887006]),
#    ('Siberian Elm', [7, 0.03954802259887006]),
#    ('Northern Red oak', [6, 0.03389830508474576]),
#    ('Pinon Pine', [5, 0.02824858757062147])]],
#  'ST. CROIX ST': [17.0,
#   [('Washington Hawthorn', [25, 0.5319148936170213]),
#    ('Ash', [17, 0.3617021276595745]),
#    ('Quaking Aspen', [1, 0.02127659574468085]),
#    ('Freeman Maple', [1, 0.02127659574468085]),
#    ('Austrian Pine', [1, 0.02127659574468085]),
#    ('Chokecherry', [1, 0.02127659574468085]),
#    ('Crape Myrtle', [1, 0.02127659574468085])]],
#  'GUNPARK DR': [16.0,
#   [('Ash', [16, 0.22535211267605634]),
#    ('Austrian Pine', [12, 0.16901408450704225]),
#    ('Blue Spruce', [6, 0.08450704225352113]),
#    ('Flowering Crabapple', [5, 0.07042253521126761]),
#    ('Northern Hackberry', [5, 0.07042253521126761]),
#    ('Common Honeylocust', [4, 0.056338028169014086]),
#    ('Norway Maple', [3, 0.04225352112676056]),
#    ('English Oak', [3, 0.04225352112676056]),
#    ('Swamp White Oak', [2, 0.028169014084507043]),
#    ('Chokecherry', [2, 0.028169014084507043])]],
#  'LEHIGH ST': [16.0,
#   [('Native Cottonwood', [46, 0.23232323232323232]),
#    ('Common Honeylocust', [26, 0.13131313131313133]),
#    ('Flowering Crabapple', [17, 0.08585858585858586]),
#    ('Ash', [16, 0.08080808080808081]),
#    ('Blue Spruce', [9, 0.045454545454545456]),
#    ('Quaking Aspen', [8, 0.04040404040404041]),
#    ('Northern Hackberry', [7, 0.03535353535353535]),
#    ('Norway Maple', [5, 0.025252525252525252]),
#    ('Bur Oak', [5, 0.025252525252525252]),
#    ('Pin Oak', [4, 0.020202020202020204])]],
#  'NOBLE CT': [16.0,
#   [('Common Honeylocust', [17, 0.288135593220339]),
#    ('Ash', [16, 0.2711864406779661]),
#    ('Amur Maple', [6, 0.1016949152542373]),
#    ('English Oak', [4, 0.06779661016949153]),
#    ('Red Maple', [2, 0.03389830508474576]),
#    ('Turkish Filbert', [2, 0.03389830508474576]),
#    ('Siberian Elm', [1, 0.01694915254237288]),
#    ('Blue Spruce', [1, 0.01694915254237288]),
#    ('Western Catalpa', [1, 0.01694915254237288]),
#    ('London Planetree', [1, 0.01694915254237288])]],
#  'TOPAZ DR': [16.0,
#   [('Siberian Elm', [49, 0.6363636363636364]),
#    ('Ash', [16, 0.2077922077922078]),
#    ('Staghorn Sumac', [6, 0.07792207792207792]),
#    ('Chokecherry', [4, 0.05194805194805195]),
#    ('Oak species', [1, 0.012987012987012988]),
#    ('Bur Oak', [1, 0.012987012987012988])]],
#  'GAPTOR RD': [15.000000000000002,
#   [('Eastern Cottonwood', [37, 0.21764705882352942]),
#    ('Siberian Elm', [24, 0.1411764705882353]),
#    ('Ash', [15, 0.08823529411764706]),
#    ('Apple species', [15, 0.08823529411764706]),
#    ('Spruce species', [15, 0.08823529411764706]),
#    ('Willow species', [13, 0.07647058823529412]),
#    ('Ponderosa Pine', [12, 0.07058823529411765]),
#    ('Boxelder', [6, 0.03529411764705882]),
#    ('Limber Pine', [4, 0.023529411764705882]),
#    ('Autumn Blaze Maple', [3, 0.01764705882352941])]],
#  '20TH ST': [15.0,
#   [('Siberian Elm', [63, 0.38650306748466257]),
#    ('Ash', [15, 0.09202453987730061]),
#    ('Common Honeylocust', [12, 0.0736196319018405]),
#    ('Northern Hackberry', [9, 0.05521472392638037]),
#    ('Flowering Crabapple', [7, 0.04294478527607362]),
#    ('Amur Maple', [6, 0.03680981595092025]),
#    ('Blue Spruce', [4, 0.024539877300613498]),
#    ('Ponderosa Pine', [4, 0.024539877300613498]),
#    ('English Oak', [4, 0.024539877300613498]),
#    ('Black Walnut', [3, 0.018404907975460124])]],
#  'COLORADO AV': [15.0,
#   [('Ash', [15, 0.22388059701492538]),
#    ('Siberian Elm', [9, 0.13432835820895522]),
#    ('Swamp White Oak', [7, 0.1044776119402985]),
#    ('Lodgepole Pine', [5, 0.07462686567164178]),
#    ('Freeman Maple', [5, 0.07462686567164178]),
#    ('Red Maple', [3, 0.04477611940298507]),
#    ('Northern Hackberry', [3, 0.04477611940298507]),
#    (nan, [3, 0.04477611940298507]),
#    ('Amur Maple', [2, 0.029850746268656716]),
#    ('Native Cottonwood', [1, 0.014925373134328358])]],
#  'OLD TALE RD': [14.0,
#   [('Ash', [14, 0.18421052631578946]),
#    ('Native Cottonwood', [6, 0.07894736842105263]),
#    ('Austrian Pine', [5, 0.06578947368421052]),
#    ('Blue Spruce', [5, 0.06578947368421052]),
#    ('Quaking Aspen', [4, 0.05263157894736842]),
#    ('Douglas-fir', [3, 0.039473684210526314]),
#    ('Eastern Cottonwood', [3, 0.039473684210526314]),
#    ('Common Honeylocust', [3, 0.039473684210526314]),
#    ('Fruiting Plum', [3, 0.039473684210526314]),
#    ('White Fir', [3, 0.039473684210526314])]],
#  'RACQUET LN': [14.0,
#   [('Ash', [14, 0.2692307692307692]),
#    ('Swamp White Oak', [4, 0.07692307692307693]),
#    ('Red Tatarian Maple', [3, 0.057692307692307696]),
#    ('Hawthorn species', [3, 0.057692307692307696]),
#    ('Plum species', [3, 0.057692307692307696]),
#    ('Austrian Pine', [3, 0.057692307692307696]),
#    ('Chokecherry', [2, 0.038461538461538464]),
#    ('Silver Maple', [2, 0.038461538461538464]),
#    ('Silver Linden', [2, 0.038461538461538464]),
#    ('Bristlecone Pine', [2, 0.038461538461538464])]],
#  'STERLING CR W': [14.0,
#   [('Ash', [14, 0.4375]),
#    ('Swamp White Oak', [6, 0.1875]),
#    ('Littleleaf Linden', [5, 0.15625]),
#    ('Bur Oak', [2, 0.0625]),
#    ('Red Maple', [2, 0.0625]),
#    ('Boxelder', [1, 0.03125]),
#    ('Mugo Pine', [1, 0.03125]),
#    ('Flowering Crabapple', [1, 0.03125])]],
#  'COMMERCE ST': [13.0,
#   [('Flowering Pear', [23, 0.4791666666666667]),
#    ('Ash', [13, 0.2708333333333333]),
#    ('Common Honeylocust', [4, 0.08333333333333333]),
#    ('Plains Cottonwood', [3, 0.0625]),
#    ('Northern Hackberry', [2, 0.041666666666666664]),
#    ('Silver Maple', [1, 0.020833333333333332]),
#    ('Freeman Maple', [1, 0.020833333333333332]),
#    ('Siberian Elm', [1, 0.020833333333333332])]],
#  'OAKLEAF CR': [13.0,
#   [('Ash', [13, 0.3333333333333333]),
#    ('Common Honeylocust', [8, 0.20512820512820512]),
#    ('Flowering Crabapple', [5, 0.1282051282051282]),
#    ('Tatarian Maple', [3, 0.07692307692307693]),
#    ('Siberian Elm', [2, 0.05128205128205128]),
#    ('Engelmann Spruce', [2, 0.05128205128205128]),
#    ('Chokecherry', [2, 0.05128205128205128]),
#    ('Ash species', [1, 0.02564102564102564]),
#    ('American Linden', [1, 0.02564102564102564]),
#    ('Hawthorn species', [1, 0.02564102564102564])]],
#  'PENNSYLVANIA PL': [13.0,
#   [('Plains Cottonwood', [29, 0.38666666666666666]),
#    ('Ash', [13, 0.17333333333333334]),
#    ('Austrian Pine', [8, 0.10666666666666667]),
#    ('Blue Spruce', [7, 0.09333333333333334]),
#    ('Swamp White Oak', [6, 0.08]),
#    ('Goldenrain Tree', [2, 0.02666666666666667]),
#    ('London Planetree', [2, 0.02666666666666667]),
#    ('Crack Willow', [2, 0.02666666666666667]),
#    ('Freeman Maple', [2, 0.02666666666666667]),
#    ('Red Maple', [2, 0.02666666666666667])]],
#  '23RD ST': [12.0,
#   [('Siberian Elm', [13, 0.14444444444444443]),
#    ('Ash', [12, 0.13333333333333333]),
#    ('Boxelder', [11, 0.12222222222222222]),
#    ('Western Catalpa', [7, 0.07777777777777778]),
#    ('Douglas-fir', [6, 0.06666666666666667]),
#    ('Blue Spruce', [5, 0.05555555555555555]),
#    ('Silver Maple', [5, 0.05555555555555555]),
#    ('Common Honeylocust', [5, 0.05555555555555555]),
#    ('Rocky Mountain Juniper', [4, 0.044444444444444446]),
#    ('Russian-olive', [3, 0.03333333333333333])]],
#  'CEDAR AV': [12.0,
#   [('Blue Spruce', [13, 0.11607142857142858]),
#    ('Ash', [12, 0.10714285714285714]),
#    ('Flowering Crabapple', [8, 0.07142857142857142]),
#    ('White Spruce', [7, 0.0625]),
#    ('Common Honeylocust', [5, 0.044642857142857144]),
#    ('Littleleaf Linden', [5, 0.044642857142857144]),
#    ('Silver Maple', [5, 0.044642857142857144]),
#    ('Accolade Elm', [5, 0.044642857142857144]),
#    ('Serviceberry species', [5, 0.044642857142857144]),
#    ('Plum species', [4, 0.03571428571428571])]],
#  'GLENDALE GULCH CR': [12.0,
#   [('Ash', [12, 0.3076923076923077]),
#    ('Willow species', [8, 0.20512820512820512]),
#    ('Austrian Pine', [7, 0.1794871794871795]),
#    ('Littleleaf Linden', [5, 0.1282051282051282]),
#    ('Common Honeylocust', [3, 0.07692307692307693]),
#    ('Native Cottonwood', [3, 0.07692307692307693]),
#    ('Quaking Aspen', [1, 0.02564102564102564])]],
#  'GOSS ST': [12.0,
#   [('Flowering Pear', [16, 0.16494845360824742]),
#    ('Ash', [12, 0.12371134020618557]),
#    ('Common Honeylocust', [12, 0.12371134020618557]),
#    ('Siberian Elm', [4, 0.041237113402061855]),
#    ('Silver Maple', [4, 0.041237113402061855]),
#    ('Tree of Heaven', [4, 0.041237113402061855]),
#    ('Swamp White Oak', [4, 0.041237113402061855]),
#    ('Littleleaf Linden', [4, 0.041237113402061855]),
#    ('Kwanzan Cherry', [3, 0.030927835051546393]),
#    ('Western Catalpa', [2, 0.020618556701030927])]],
#  'MANHATTAN CR': [12.0,
#   [('Ash', [12, 0.5454545454545454]),
#    ('Common Honeylocust', [3, 0.13636363636363635]),
#    ('Accolade Elm', [2, 0.09090909090909091]),
#    (nan, [2, 0.09090909090909091]),
#    ('Silver Maple', [2, 0.09090909090909091]),
#    ('Blue Spruce', [1, 0.045454545454545456])]],
#  'MEREDITH WAY': [12.0,
#   [('Ash', [12, 0.631578947368421]),
#    ('Kentucky Coffeetree', [3, 0.15789473684210525]),
#    ('Elm species', [3, 0.15789473684210525]),
#    ('Austrian Pine', [1, 0.05263157894736842])]],
#  'NAUTILUS CT N': [12.0,
#   [('Ash', [12, 0.22641509433962265]),
#    ('Common Honeylocust', [8, 0.1509433962264151]),
# ...
#  'LOVE CT': [2.0, [('Ash', [2, 1.0])]],
#  'MCKINLEY DR': [2.0,
#   [('Bur Oak', [3, 0.17647058823529413]),
#    ('Common Honeylocust', [3, 0.17647058823529413]),
#    ('Sugar Maple', [2, 0.11764705882352941]),
#    ('Ash', [2, 0.11764705882352941]),
#    ('White Spruce', [1, 0.058823529411764705]),
#    ('Swamp White Oak', [1, 0.058823529411764705]),
#    ('Turkish Filbert', [1, 0.058823529411764705]),
#    ('Catalpa species', [1, 0.058823529411764705]),
#    ('Chinkapin Oak', [1, 0.058823529411764705]),
#    ('Quaking Aspen', [1, 0.058823529411764705])]],
#  'MEADOW PL': [2.0,
#   [('Ash', [2, 0.3333333333333333]),
#    ('Northern Hackberry', [2, 0.3333333333333333]),
#    ('Freeman Maple', [1, 0.16666666666666666]),
#    ('Norway Maple', [1, 0.16666666666666666])]],
#  'MESA DR': [2.0,
#   [('Common Honeylocust', [9, 0.42857142857142855]),
#    ('Siberian Elm', [3, 0.14285714285714285]),
#    ('Ash', [2, 0.09523809523809523]),
#    ('Austrian Pine', [2, 0.09523809523809523]),
#    ('Apricot', [1, 0.047619047619047616]),
#    ('Flowering Crabapple', [1, 0.047619047619047616]),
#    ('White Spruce', [1, 0.047619047619047616]),
#    ('Bosnian Pine', [1, 0.047619047619047616]),
#    ('Black Walnut', [1, 0.047619047619047616])]],
#  'MESA TOP CT': [2.0,
#   [('Common Honeylocust', [3, 0.2727272727272727]),
#    ('Littleleaf Linden', [3, 0.2727272727272727]),
#    ('Ash', [2, 0.18181818181818182]),
#    ('Russian-olive', [1, 0.09090909090909091]),
#    ('Amur Maple', [1, 0.09090909090909091]),
#    ('Mugo Pine', [1, 0.09090909090909091])]],
#  'NORTH STAR CT': [2.0,
#   [('Flowering Crabapple', [4, 0.25]),
#    ('American Linden', [3, 0.1875]),
#    ('Sugar Maple', [2, 0.125]),
#    ('Ash', [2, 0.125]),
#    ('Lanceleaf Cottonwood', [1, 0.0625]),
#    ('Norway Maple', [1, 0.0625]),
#    ('Flowering Pear', [1, 0.0625]),
#    ('Ponderosa Pine', [1, 0.0625]),
#    ('Native Cottonwood', [1, 0.0625])]],
#  'OAK CR': [2.0,
#   [('Ash', [2, 0.2]),
#    ('Common Honeylocust', [2, 0.2]),
#    ('Douglas-fir', [2, 0.2]),
#    ('Austrian Pine', [1, 0.1]),
#    ('Rocky Mountain Juniper', [1, 0.1]),
#    ('American Linden', [1, 0.1]),
#    ('Bristlecone Pine', [1, 0.1])]],
#  'ONEAL CR': [2.0,
#   [('Silver Maple', [3, 0.3]),
#    ('Ash', [2, 0.2]),
#    ('Blue Spruce', [2, 0.2]),
#    ('Siberian Elm', [1, 0.1]),
#    ('Northern Hackberry', [1, 0.1]),
#    ('Kentucky Coffeetree', [1, 0.1])]],
#  'ONEAL CR SW': [2.0,
#   [('Ash', [2, 0.6666666666666666]),
#    ('Silver Maple', [1, 0.3333333333333333])]],
#  'PINEHURST DR': [2.0,
#   [('Ash', [2, 0.3333333333333333]),
#    ('Mugo Pine', [1, 0.16666666666666666]),
#    ('Quaking Aspen', [1, 0.16666666666666666]),
#    ('Amur Maple', [1, 0.16666666666666666]),
#    ('Thornless Cockspur Hawthorn', [1, 0.16666666666666666])]],
#  'QUAIL CR': [2.0,
#   [('Austrian Pine', [3, 0.25]),
#    ('Silver Maple', [2, 0.16666666666666666]),
#    ('Blue Spruce', [2, 0.16666666666666666]),
#    ('Ash', [2, 0.16666666666666666]),
#    ('Plum species', [1, 0.08333333333333333]),
#    ('Red Maple', [1, 0.08333333333333333]),
#    ('Flowering Crabapple', [1, 0.08333333333333333])]],
#  'QUARRY CT': [2.0,
#   [('Ash', [2, 0.3333333333333333]),
#    ('Common Honeylocust', [1, 0.16666666666666666]),
#    ('Amur Maple', [1, 0.16666666666666666]),
#    ('Thornless Cockspur Hawthorn', [1, 0.16666666666666666]),
#    ('Siberian Elm', [1, 0.16666666666666666])]],
#  'S 31ST ST': [2.0,
#   [('Ash', [2, 0.6666666666666666]),
#    ('Siberian Elm', [1, 0.3333333333333333])]],
#  'S 32ND ST': [2.0,
#   [('Siberian Elm', [4, 0.4]),
#    ('Ash', [2, 0.2]),
#    ('Ponderosa Pine', [1, 0.1]),
#    ('Juniper species', [1, 0.1]),
#    ('Common Honeylocust', [1, 0.1]),
#    ('Peach', [1, 0.1])]],
#  'S ORCHARD CREEK CR': [2.0,
#   [('Thornless Cockspur Hawthorn', [5, 0.2631578947368421]),
#    ('Flowering Crabapple', [4, 0.21052631578947367]),
#    ('Flowering Pear', [4, 0.21052631578947367]),
#    ('Juniper species', [3, 0.15789473684210525]),
#    ('Ash', [2, 0.10526315789473684]),
#    ('Western Catalpa', [1, 0.05263157894736842])]],
#  'SIERRA DR': [2.0,
#   [('Austrian Pine', [4, 0.17391304347826086]),
#    ('Flowering Crabapple', [2, 0.08695652173913043]),
#    ('Bosnian Pine', [2, 0.08695652173913043]),
#    ('Peach', [2, 0.08695652173913043]),
#    ('Ash', [2, 0.08695652173913043]),
#    ('Blue Spruce', [2, 0.08695652173913043]),
#    ('Ponderosa Pine', [2, 0.08695652173913043]),
#    ('American Linden', [1, 0.043478260869565216]),
#    ('Tuliptree', [1, 0.043478260869565216]),
#    ('Weeping Mulberry', [1, 0.043478260869565216])]],
#  'SMUGGLER CR': [2.0,
#   [('Ash', [2, 0.4]),
#    ('Spruce species', [1, 0.2]),
#    ('Blue Spruce', [1, 0.2]),
#    ('Flowering Crabapple', [1, 0.2])]],
#  'SMUGGLER PL': [2.0,
#   [('Austrian Pine', [3, 0.375]),
#    ('Ash', [2, 0.25]),
#    ('Flowering Crabapple', [1, 0.125]),
#    ('Tree of Heaven', [1, 0.125]),
#    ('White Mulberry', [1, 0.125])]],
#  'SPRINGDALE LN': [2.0,
#   [('American Linden', [3, 0.375]),
#    ('Blue Spruce', [2, 0.25]),
#    ('Ash', [2, 0.25]),
#    ('Russian-olive', [1, 0.125])]],
#  'UTICA CT': [2.0,
#   [('Littleleaf Linden', [5, 0.3333333333333333]),
#    ('Pinon Pine', [4, 0.26666666666666666]),
#    ('Ash', [2, 0.13333333333333333]),
#    ('Lanceleaf Cottonwood', [1, 0.06666666666666667]),
#    ('Native Cottonwood', [1, 0.06666666666666667]),
#    ('Hybrid Elm', [1, 0.06666666666666667]),
#    ('Blue Spruce', [1, 0.06666666666666667])]],
#  'YALE RD': [2.0,
#   [('Flowering Crabapple', [6, 0.4]),
#    ('Siberian Elm', [3, 0.2]),
#    ('Ash', [2, 0.13333333333333333]),
#    ('Northern Hackberry', [2, 0.13333333333333333]),
#    ('Black Walnut', [1, 0.06666666666666667]),
#    ('Apple species', [1, 0.06666666666666667])]],
#  'AGATE LN': [1.0,
#   [('Shumard Oak', [4, 0.3333333333333333]),
#    ('Siberian Elm', [4, 0.3333333333333333]),
#    ('Flowering Plum', [1, 0.08333333333333333]),
#    ('Ash', [1, 0.08333333333333333]),
#    ('Mugo Pine', [1, 0.08333333333333333]),
#    ('Russian-olive', [1, 0.08333333333333333])]],
#  'AMBER ST': [1.0,
#   [('Austrian Pine', [1, 0.1111111111111111]),
#    ('Siberian Elm', [1, 0.1111111111111111]),
#    ('Freeman Maple', [1, 0.1111111111111111]),
#    ('Red Maple', [1, 0.1111111111111111]),
#    ('Northern Red oak', [1, 0.1111111111111111]),
#    ('Ash', [1, 0.1111111111111111]),
#    ('Pine species', [1, 0.1111111111111111]),
#    ('Chokecherry', [1, 0.1111111111111111]),
#    ('English Oak', [1, 0.1111111111111111])]],
#  'ARMER AV': [1.0, [('Ash', [1, 1.0])]],
#  'ASTOR LN': [1.0, [('Ash', [1, 1.0])]],
#  'AVACADO RD': [1.0,
#   [('Common Honeylocust', [2, 0.5]),
#    ('Ash', [1, 0.25]),
#    ('Silver Maple', [1, 0.25])]],
#  'AVOCADO RD': [1.0, [('Ash', [1, 0.5]), ('Common Honeylocust', [1, 0.5])]],
#  'BARBADOS PL': [1.0, [('Ash', [1, 0.5]), ('Mugo Pine', [1, 0.5])]],
#  'BRANDYWINE CT': [1.0,
#   [('Northern Hackberry', [3, 0.5]),
#    ('Western Hackberry', [2, 0.3333333333333333]),
#    ('Ash', [1, 0.16666666666666666])]],
#  'CHINLE AV': [1.0, [('Littleleaf Linden', [1, 0.5]), ('Ash', [1, 0.5])]],
#  'COMANCHE DR': [1.0,
#   [('Flowering Pear', [2, 0.3333333333333333]),
#    ('Mugo Pine', [1, 0.16666666666666666]),
#    ('Flowering Crabapple', [1, 0.16666666666666666]),
#    ('Northern Whitecedar', [1, 0.16666666666666666]),
#    ('Ash', [1, 0.16666666666666666])]],
#  'CORONA TR': [1.0,
#   [('Pinon Pine', [4, 0.5714285714285714]),
#    ('Flowering Crabapple', [2, 0.2857142857142857]),
#    ('Ash', [1, 0.14285714285714285])]],
#  'CRIPPLE CREEK SQ': [1.0,
#   [('Serviceberry species', [4, 0.5]),
#    ('Common Honeylocust', [2, 0.25]),
#    ('Ash', [1, 0.125]),
#    ('Pinon Pine', [1, 0.125])]],
#  'DAKOTA PL': [1.0,
#   [('White Fir', [3, 0.3333333333333333]),
#    ('Chokecherry', [1, 0.1111111111111111]),
#    ('Common Honeylocust', [1, 0.1111111111111111]),
#    ('Freeman Maple', [1, 0.1111111111111111]),
#    ('Ash', [1, 0.1111111111111111]),
#    ('Willow species', [1, 0.1111111111111111]),
#    ('Peach', [1, 0.1111111111111111])]],
#  'DEL ROSA CT': [1.0,
#   [('Siberian Elm', [2, 0.4]),
#    ('Black Walnut', [1, 0.2]),
#    ('Swamp White Oak', [1, 0.2]),
#    ('Ash', [1, 0.2])]],
#  'DREW RANCH LN': [1.0,
#   [('Plum species', [2, 0.2]),
#    ('Norway Maple', [2, 0.2]),
#    ('Littleleaf Linden', [1, 0.1]),
#    ('Flowering Crabapple', [1, 0.1]),
#    ('Thornless Cockspur Hawthorn', [1, 0.1]),
#    ('Freeman Maple', [1, 0.1]),
#    ('Flowering Pear', [1, 0.1]),
#    ('Ash', [1, 0.1])]],
#  'EDISON CT': [1.0,
#   [('Austrian Pine', [3, 0.6]), ('Pinon Pine', [1, 0.2]), ('Ash', [1, 0.2])]],
#  'ELLSWORTH PL': [1.0, [('Chinkapin Oak', [1, 0.5]), ('Ash', [1, 0.5])]],
#  'ERIE DR': [1.0,
#   [('Juniper species', [3, 0.375]),
#    ('Mugo Pine', [2, 0.25]),
#    ('Pine species', [1, 0.125]),
#    ('Eastern Redbud', [1, 0.125]),
#    ('Ash', [1, 0.125])]],
#  'FERN PL': [1.0,
#   [('Siberian Elm', [3, 0.42857142857142855]),
#    ('Pinon Pine', [1, 0.14285714285714285]),
#    ('Arborivitae species', [1, 0.14285714285714285]),
#    ('Flowering Crabapple', [1, 0.14285714285714285]),
#    ('Ash', [1, 0.14285714285714285])]],
#  'FREMONT AV': [1.0,
#   [('Mugo Pine', [1, 0.2]),
#    ('Austrian Pine', [1, 0.2]),
#    ('Blue Spruce', [1, 0.2]),
#    ('Ash', [1, 0.2]),
#    ('Siberian Elm', [1, 0.2])]],
#  'GILPIN DR': [1.0,
#   [('Siberian Elm', [4, 0.5]),
#    ('Quaking Aspen', [1, 0.125]),
#    ('Norway Maple', [1, 0.125]),
#    ('Ash', [1, 0.125]),
#    ('Silver Maple', [1, 0.125])]],
#  'HARVARD LN': [1.0,
#   [('Juniper species', [2, 0.3333333333333333]),
#    ('Ash', [1, 0.16666666666666666]),
#    ('Siberian Elm', [1, 0.16666666666666666]),
#    ('American Elm', [1, 0.16666666666666666]),
#    ('Tree of Heaven', [1, 0.16666666666666666])]],
#  'HAWTHORN PL': [1.0,
#   [('Quaking Aspen', [3, 0.42857142857142855]),
#    ('Ash', [1, 0.14285714285714285]),
#    ('Smoke Tree', [1, 0.14285714285714285]),
#    ('Plum species', [1, 0.14285714285714285]),
#    ('Flowering Pear', [1, 0.14285714285714285])]],
#  'HEIDELBERG DR': [1.0,
#   [('White Oak', [1, 0.25]),
#    ('Common Honeylocust', [1, 0.25]),
#    ('Goldenrain Tree', [1, 0.25]),
#    ('Ash', [1, 0.25])]],
#  'ILIFF ST': [1.0,
#   [('Common Honeylocust', [3, 0.3]),
#    ('Mugo Pine', [1, 0.1]),
#    ('Bur Oak', [1, 0.1]),
#    ('Ash', [1, 0.1]),
#    ('Austrian Pine', [1, 0.1]),
#    ('Ponderosa Pine', [1, 0.1]),
#    ('Boxelder', [1, 0.1]),
#    ('Silver Maple', [1, 0.1])]],
#  'INCA PY': [1.0,
#   [('Thornless Cockspur Hawthorn', [3, 0.2727272727272727]),
#    ('Pinon Pine', [2, 0.18181818181818182]),
#    ('Austrian Pine', [2, 0.18181818181818182]),
#    ('Plum species', [1, 0.09090909090909091]),
#    ('Ash', [1, 0.09090909090909091]),
#    ('Common Honeylocust', [1, 0.09090909090909091]),
#    ('American Linden', [1, 0.09090909090909091])]],
#  'KALMIA CR': [1.0,
#   [('Blue Spruce', [2, 0.2857142857142857]),
#    ('Quaking Aspen', [1, 0.14285714285714285]),
#    ('Eastern Cottonwood', [1, 0.14285714285714285]),
#    ('Austrian Pine', [1, 0.14285714285714285]),
#    ('Apple species', [1, 0.14285714285714285]),
#    ('Ash', [1, 0.14285714285714285])]],
#  'KENNEDY CT': [1.0,
#   [('Common Honeylocust', [4, 0.36363636363636365]),
#    ('Blue Spruce', [2, 0.18181818181818182]),
#    ('Northern Hackberry', [2, 0.18181818181818182]),
#    ('Siberian Elm', [1, 0.09090909090909091]),
#    ('Flowering Crabapple', [1, 0.09090909090909091]),
#    ('Ash', [1, 0.09090909090909091])]],
#  'KENWOOD DR': [1.0,
#   [('Blue Spruce', [6, 0.5]),
#    ('Siberian Elm', [3, 0.25]),
#    ('Ash', [1, 0.08333333333333333]),
#    ('Eastern Redbud', [1, 0.08333333333333333]),
#    ('Boxelder', [1, 0.08333333333333333])]],
#  'KINGSTOWN PL': [1.0, [('Ash', [1, 1.0])]],
#  'KINNIKINIC RD': [1.0, [('Ash', [1, 1.0])]],
#  'LARKWOOD CT': [1.0, [('Ash', [1, 1.0])]],
#  'MACKY WY': [1.0,
#   [('Juniper species', [4, 0.4]),
#    ('Blue Spruce', [3, 0.3]),
#    ('Poplar species', [1, 0.1]),
#    ('Austrian Pine', [1, 0.1]),
#    ('Ash', [1, 0.1])]],
#  'MERRITT DR': [1.0,
#   [('Ash', [1, 0.3333333333333333]),
#    ('Flowering Crabapple', [1, 0.3333333333333333]),
#    ('Common Honeylocust', [1, 0.3333333333333333])]],
#  'MOFFIT CT': [1.0,
#   [('Silver Maple', [5, 0.7142857142857143]),
#    ('Ash', [1, 0.14285714285714285]),
#    ('Ponderosa Pine', [1, 0.14285714285714285])]],
#  'MOSS ROCK PL': [1.0,
#   [('Ash', [1, 0.3333333333333333]),
#    ('Northern Red oak', [1, 0.3333333333333333]),
#    ('Common Honeylocust', [1, 0.3333333333333333])]],
#  'N 55TH ST': [1.0, [('Ash', [1, 1.0])]],
#  'N TERRACE CR': [1.0,
#   [('Ash', [1, 0.14285714285714285]),
#    ('Red Maple', [1, 0.14285714285714285]),
#    ('Japanese Tree Lilac', [1, 0.14285714285714285]),
#    ('Littleleaf Linden', [1, 0.14285714285714285]),
#    ('Blue Spruce', [1, 0.14285714285714285]),
#    ('Mountain Mahogany', [1, 0.14285714285714285]),
#    ('Sugar Maple', [1, 0.14285714285714285])]],
#  'NEHER LN': [1.0,
#   [('Juniper species', [5, 0.5555555555555556]),
#    ('Blue Spruce', [2, 0.2222222222222222]),
#    ('White Fir', [1, 0.1111111111111111]),
#    ('Ash', [1, 0.1111111111111111])]],
#  'NORTON ST': [1.0,
#   [('Common Honeylocust', [2, 0.2857142857142857]),
#    ('Hawthorn species', [1, 0.14285714285714285]),
#    ('Common Horsechestnut', [1, 0.14285714285714285]),
#    ('Ash', [1, 0.14285714285714285]),
#    ('Ponderosa Pine', [1, 0.14285714285714285]),
#    ('Quaking Aspen', [1, 0.14285714285714285])]],
#  'OAKWOOD PL': [1.0,
#   [('Hawthorn species', [3, 0.6]),
#    ('Ash', [1, 0.2]),
#    ('Rocky Mountain Juniper', [1, 0.2])]],
#  'ONTARIO CT': [1.0,
#   [('Flowering Crabapple', [2, 0.2857142857142857]),
#    ('Blue Spruce', [2, 0.2857142857142857]),
#    ('Russian-olive', [1, 0.14285714285714285]),
#    ('Austrian Pine', [1, 0.14285714285714285]),
#    ('Ash', [1, 0.14285714285714285])]],
#  'OUTBACK CT': [1.0,
#   [('Ash', [1, 0.14285714285714285]),
#    ('Flowering Crabapple', [1, 0.14285714285714285]),
#    ('Quaking Aspen', [1, 0.14285714285714285]),
#    ('Ponderosa Pine', [1, 0.14285714285714285]),
#    ('Western Catalpa', [1, 0.14285714285714285]),
#    ('American Linden', [1, 0.14285714285714285]),
#    ('Blue Spruce', [1, 0.14285714285714285])]],
#  'PARK LN': [1.0,
#   [('Pinon Pine', [2, 0.2222222222222222]),
#    ('Austrian Pine', [2, 0.2222222222222222]),
#    ('Ash', [1, 0.1111111111111111]),
#    ('Blue Spruce', [1, 0.1111111111111111]),
#    ('Native Cottonwood', [1, 0.1111111111111111]),
#    ('Plum species', [1, 0.1111111111111111]),
#    ('Black Walnut', [1, 0.1111111111111111])]],
#  'PARK SADDLE CT': [1.0,
#   [('Norway Maple', [3, 0.2727272727272727]),
#    ('Thornless Cockspur Hawthorn', [1, 0.09090909090909091]),
#    ('Freeman Maple', [1, 0.09090909090909091]),
#    ('Mugo Pine', [1, 0.09090909090909091]),
#    ('Ash', [1, 0.09090909090909091]),
#    ('Blue Spruce', [1, 0.09090909090909091]),
#    ('Austrian Pine', [1, 0.09090909090909091]),
#    ('Russian-olive', [1, 0.09090909090909091]),
#    ('Quaking Aspen', [1, 0.09090909090909091])]],
#  'PEMBROKE GARDENS': [1.0,
#   [('Western Catalpa', [3, 0.2727272727272727]),
#    ('English Oak', [3, 0.2727272727272727]),
#    ('Upright English Oak', [2, 0.18181818181818182]),
#    ('Ponderosa Pine', [1, 0.09090909090909091]),
#    ('Silver Maple', [1, 0.09090909090909091]),
#    ('Ash', [1, 0.09090909090909091])]],
#  'RACQUET CT': [1.0, [('Ash', [1, 1.0])]],
#  'REGIS DR': [1.0,
#   [('Tatarian Maple', [2, 0.5]),
#    ('Quaking Aspen', [1, 0.25]),
#    ('Ash', [1, 0.25])]],
#  'S 43RD ST': [1.0,
#   [('Western Catalpa', [1, 0.125]),
#    ('Freeman Maple', [1, 0.125]),
#    ('Juniper species', [1, 0.125]),
#    ('Ponderosa Pine', [1, 0.125]),
#    ('Boxelder', [1, 0.125]),
#    ('Ash', [1, 0.125]),
#    ('Bristlecone Pine', [1, 0.125]),
#    ('Tree of Heaven', [1, 0.125])]],
#  'SENECA PL': [1.0,
#   [('Mugo Pine', [2, 0.6666666666666666]), ('Ash', [1, 0.3333333333333333])]],
#  'SHERWOOD CR': [1.0, [('Ash', [1, 0.5]), ('Silver Maple', [1, 0.5])]],
#  'TINCUP CT': [1.0,
#   [('Austrian Pine', [3, 0.25]),
#    ('Flowering Crabapple', [3, 0.25]),
#    ('Quaking Aspen', [1, 0.08333333333333333]),
#    ('Blue Spruce', [1, 0.08333333333333333]),
#    ('Flowering Pear', [1, 0.08333333333333333]),
#    ('Northern Hackberry', [1, 0.08333333333333333]),
#    ('Norway Maple', [1, 0.08333333333333333]),
#    ('Ash', [1, 0.08333333333333333])]],
#  'WHITE ROCK CR': [1.0,
#   [('Scotch Pine', [2, 0.5]), ('Ash', [1, 0.25]), ('Red Maple', [1, 0.25])]],
#  'WILDWOOD RD': [1.0, [('Ash', [1, 1.0])]],
#  'WINGATE AV': [1.0,
#   [('Flowering Crabapple', [3, 0.6]),
#    ('Blue Spruce', [1, 0.2]),
#    ('Ash', [1, 0.2])]]}

# %%
ash_gb = df.groupby("STREET")
agg_d = {"COMMONNAME":len}
ash_gb.agg(agg_d)
# Out:
#                     COMMONNAME
# STREET
# 10TH ST                    426
# 11TH ST                    338
# 12TH ST                    190
# 13TH ST                    585
# 14TH ST                    482
# 15TH ST                    398
# 16TH CR                      1
# 16TH ST                    377
# 17TH ST                    386
# 18TH ST                    268
# 19TH ST                    759
# 20TH ST                    163
# 21ST ST                     68
# 22ND ST                    141
# 23RD ST                     90
# 24TH ST                     28
# 25TH ST                     12
# 26TH ST                    225
# 27TH  WY                    13
# 27TH ST                      6
# 28TH FRONTAGE RD           156
# 28TH ST                    783
# 29TH ST                     85
# 2ND ST                      23
# 30TH ST                    464
# 31ST ST                     31
# 32ND ST                     15
# 33RD ST                     70
# 34TH ST                    179
# 35TH ST                     72
# ...                        ...
# WHITE PL                    44
# WHITE ROCK CR                4
# WHITNEY PL                   7
# WILD DUNES CT               11
# WILD PLUM CT                45
# WILDERNESS PL               13
# WILDWOOD CT                  1
# WILDWOOD LN                  2
# WILDWOOD RD                  1
# WILLOW LN                    1
# WILLOWBROOK RD              61
# WILSON CT                    8
# WINCHESTER CR              112
# WINDING TRAIL DR            44
# WINDSOR DR                  14
# WINGATE AV                   5
# WINTERCRESS CT               2
# WONDERLAND HILL AV         118
# WOODSTOCK PL                 3
# WRIGHT AV                   45
# WRIGHT CR                    9
# YALE CR                      7
# YALE RD                     15
# YARMOUTH AV                 95
# YARROW CT                    3
# YAUPON AV                   45
# YELLOW PINE AV              73
# YUMA CR                      2
# ZAMIA AV                    87
# ZAMIA CT                    15
#
# [773 rows x 1 columns]

# %%
len(df["COMMONNAME"].unique())
# Out:
# 238
