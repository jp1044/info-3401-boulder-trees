# %%
import pandas as pd
import numpy as np
import operator

# %% [markdown]
# Questions for Christy:
# 1.) EAB column
# 2.) Disease Def column: differences between values
# 3.) What makes a street diverse?

# %%
df = pd.read_csv("Trees_Public.csv")

# %%
#df.columns

# %%
def dic(c):
    d = {}
    for i in c:
        try:
            d[i]+=1
        except:
            d[i]=1
    import operator
    d = sorted(d.items(), key=operator.itemgetter(1),reverse = True)
    return d
def dic2(c):
    a = {}
    for i in c:
        try:
            a[i]+=1
        except:
            a[i]=1
    import operator
    a = sorted(a.items(), key=operator.itemgetter(1),reverse = True)
    t=0
    for i in a:
        t+=i[1]
    d = []
    for i in a:
        d.append([i[0],float(i[1])/t])
    return d
def dic3(c):
    d={}
    for i in c:
        try:
            d[df[df['STREET']==i[0]]['HOOD'].iloc[0]]+=i[1]
        except:
            d[df[df['STREET']==i[0]]['HOOD'].iloc[0]]=i[1]
    for i in df['HOOD']:
        try:
            d[i]
        except:
            if i == i:
                d[i]=0
    d = sorted(d.items(), key=operator.itemgetter(1),reverse = True)
    return d

# %%
ash = df[df['COMMONNAME']=='Green Ash'].append(df[df['COMMONNAME']=='White Ash']) #Subset of tree dataset that only has ash trees
not_ash = df[df['COMMONNAME']!='Green Ash'] #Subset of tree dataset that only has ash trees
not_ash = not_ash[not_ash['COMMONNAME']!='White Ash']

mt_dic = dic(ash['MT'])  #dictionary of sorted values of Maintenance columns
strs = df['STREET'].append(df['TOSTR']).append(df['FROMSTR']).append(df['ONSTR']).unique()

strs_tree_counts={}
for i in df['STREET'].unique():
    e={}
    for j in df[df['STREET']==i]['COMMONNAME']:
        #e['Ash']=0
        if j !="White Ash" and j!="Green Ash":
            try:
                e[j]+=1
            except:
                e[j]=1
        else:
            try:
                e['Ash']+=1
            except:
                e['Ash']=1
    strs_tree_counts[i]=[np.sum([values for key,values in e.items()]),e]
for key,value in strs_tree_counts.items():
    for a,b in value[1].items():
        strs_tree_counts[key][1][a] = [b,float(b)/value[0]]

bad_ash = ash[ash['MT']!='No Specific Maintenance Need']
good_ash = ash[ash['MT']=='No Specific Maintenance Need']

boulder_trees = dic(df['COMMONNAME'])

bad_ash_strs =  [i for i in bad_ash['STREET'].unique()]
bad_ash_strs_counts = sorted([[i,len(bad_ash[bad_ash['STREET'] ==i])] for i in bad_ash_strs], key = lambda num:num[1], reverse = True)
good_ash_strs = [i for i in good_ash['STREET'].unique()]
only_good_ash_strs = [i for i in good_ash['STREET'].unique() if i not in bad_ash_strs]
only_bad_ash_strs = [i for i in bad_ash['STREET'].unique() if i not in good_ash_strs]
both_ash_strs = [i for i in good_ash['STREET'].unique() if i in bad_ash['STREET'].unique()]
both_ash_strs_percent = len(both_ash_strs)/len(strs)

bad_strs_percent = len(bad_ash_strs)/len(strs)
good_strs_percent = len(good_ash_strs)/len(strs)

bad_ash_tofro_strs = bad_ash['TOSTR'].append(bad_ash['FROMSTR']).unique()


at_risk_strs = [i for i in only_good_ash_strs if i in bad_ash_tofro_strs]

at_risk_strs_counts = []
for i in at_risk_strs:
    at_risk_strs_counts.append([i,len(ash[ash['STREET']==i])])
    
at_risk_strs_sorted = sorted(at_risk_strs_counts, key=lambda num:num[1], reverse = True)

at_risk_strs_d = {}
for i in at_risk_strs_sorted:
    at_risk_strs_d[i[0]]=i[1]
    
at_risk_strs_ash_dic = {}
for i in at_risk_strs_sorted:
    at_risk_strs_ash_dic[i[0]]=strs_tree_counts[i[0]][1]['Ash']
    
at_risk_hoods=dic3(at_risk_strs_sorted)
bad_ash_hoods_counts = dic3(bad_ash_strs_counts)


strs_trees_percent_dic = {}
for i in df['COMMONNAME'].unique():
    strs_trees_percent_dic[i]=np.mean([value[1][i][1] for key,value in strs_tree_counts.items() if i in value[1]])
t=[value[1]['Ash'][1] for key,value in strs_tree_counts.items() if 'Ash'in value[1]]
strs_trees_percent_dic['Ash']=np.mean(t)
strs_trees_percent_dic_sorted = sorted(strs_trees_percent_dic.items(), key=operator.itemgetter(1),reverse = True)

strs_trees_percent_dic_2 = {}
for i in df['COMMONNAME'].unique():
    t = []
    for key,value in strs_tree_counts.items():
        if i in value[1]:
            t.append(np.mean(value[1][i][1]))
        else:
            t.append(0)
    strs_trees_percent_dic_2[i]=np.mean(t)
t=[]
for key,value in strs_tree_counts.items():
    if 'Ash' in value[1]:
        t.append(value[1]['Ash'][1])
    else:
        t.append(0)
strs_trees_percent_dic_2['Ash']=np.mean(t)
strs_trees_percent_dic_sorted_2 = sorted(strs_trees_percent_dic_2.items(), key=operator.itemgetter(1),reverse = True)

high_percents=[]
for j in df['COMMONNAME'].unique():
    x = df[df['COMMONNAME']==j]
    for i in strs:
        try:
            if(strs_tree_counts[i][1][j][0]>50 and strs_tree_counts[i][1][j][1]>.2):
                high_percents.append([i,j,strs_tree_counts[i][1][j][0],strs_tree_counts[i][1][j][1]])
        except:
            #print('yo')
            pass
high_percents=sorted(high_percents,key=lambda x:x[3],reverse = True)
percent_ash = []
for i in strs:
    try:
        if(strs_tree_counts[i][1]['Ash'][0]>30):
            percent_ash.append([i,strs_tree_counts[i][1]['Ash'][0],strs_tree_counts[i][1]['Ash'][1]])
    except:
        #print('yo')
        pass
strs_trees_percent_dic_3 = {}
for i in dic(not_ash['COMMONNAME']):
    strs_trees_percent_dic_3[i[0]]=i[1]/len(not_ash)
strs_trees_percent_dic_sorted_3 = sorted(strs_trees_percent_dic_3.items(), key=operator.itemgetter(1),reverse = True)

replacements = {}
num_ash = len(ash)
for key,value in strs_trees_percent_dic_3.items():
    replacements[key]=num_ash*value

sorted(percent_ash,key=lambda x:x[2],reverse = True)
# Out:
# /anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:2909: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# [['WHITE PL', 35, 0.79545454545454541],
#  ['LINDEN PARK DR', 149, 0.63948497854077258],
#  ['CENTRAL AV', 49, 0.51041666666666663],
#  ['LINDEN AV', 49, 0.31612903225806449],
#  ['55TH ST', 58, 0.31182795698924731],
#  ['FRANKLIN DR', 33, 0.30555555555555558],
#  ['JUNIPER AV', 47, 0.26111111111111113],
#  ['KINGS RIDGE BV', 41, 0.24260355029585798],
#  ['9TH ST', 245, 0.22940074906367042],
#  ['PENNSYLVANIA AV', 45, 0.2132701421800948],
#  ['GROVE ST', 35, 0.20000000000000001],
#  ['MOHAWK DR', 40, 0.20000000000000001],
#  ['S BROADWAY', 48, 0.192],
#  ['WALNUT ST', 93, 0.18562874251497005],
#  ['KALMIA AV', 98, 0.17915904936014626],
#  ['34TH ST', 32, 0.1787709497206704],
#  ['75TH ST', 37, 0.16894977168949771],
#  ['BLUFF ST', 49, 0.16723549488054607],
#  ['TABLE MESA DR', 31, 0.16145833333333334],
#  ['PEARL ST', 156, 0.15918367346938775],
#  ['26TH ST', 34, 0.15111111111111111],
#  ['SPRUCE ST', 105, 0.14957264957264957],
#  ['17TH ST', 55, 0.14248704663212436],
#  ['18TH ST', 37, 0.13805970149253732],
#  ['LINCOLN PL', 31, 0.13419913419913421],
#  ['ARAPAHOE  AV', 122, 0.13232104121475055],
#  ['PLEASANT ST', 33, 0.12890625],
#  ['MAPLETON AV', 114, 0.12751677852348994],
#  ['11TH ST', 43, 0.12721893491124261],
#  ['DAKOTA BV', 33, 0.12595419847328243],
#  ['16TH ST', 46, 0.1220159151193634],
#  ['8TH ST', 38, 0.11912225705329153],
#  ['13TH ST', 67, 0.11452991452991453],
#  ['POPLAR AV', 76, 0.11428571428571428],
#  ['IRIS AV', 34, 0.11295681063122924],
#  ['30TH ST', 51, 0.10991379310344827],
#  ['BASELINE RD', 95, 0.1074660633484163],
#  ['SIOUX DR', 51, 0.10472279260780287],
#  ['BROADWAY', 148, 0.10136986301369863],
#  ['PINE ST', 66, 0.099547511312217188],
#  ['CANYON BV', 67, 0.094900849858356937],
#  ['4TH ST', 43, 0.094091903719912467],
#  ['19TH ST', 71, 0.093544137022397889],
#  ['28TH ST', 70, 0.089399744572158366],
#  ['ARAPAHOE AV', 122, 0.085017421602787455],
#  ['6TH ST', 33, 0.063218390804597707],
#  ['VALMONT RD', 56, 0.043076923076923075]]

# %%
help_vars = {'ash': 'filtered Data frame that only includes ash trees',
'not_ash':'self explanatory dataframe',
'mt_dic': 'sorted list of maintenance values for ash trees',
'boulder_trees': 'quantities of each tree in boulder',
'strs': 'list of all streets in boulder',

'bad_ash': 'data frame of all ash trees that need maintenance',
'bad_ash_strs': 'list of streets that have ash trees that need maintenance',
'only_bad_ash_strs': 'list of streets that have ash trees and all of those trees need maintenance',
'bad_ash_strs_counts': 'sorted list of streets and the amounts of bad ash trees they have',
'bad_strs_percent': 'percent of streets in Boulder that have bad trees',
'bad_ash_tofro_strs': 'list of streets that have another street touching it that have bad ash trees on it',
'bad_ash_hoods_counts': 'sorted list of hoods and the amount of bad ash trees that it has',

'good_ash': 'data frame of all ash trees that dont need maintenance',
'good_ash_strs': 'list of all streets that have good ash trees on it',
'only_good_ash_strs': 'list of streets that have ash trees and none of those trees need maintenance',
'good_strs_percent': 'percent of streets in Boulder that have good ash trees',

'both_ash_strs': 'list of streets that have some ash trees that need maintenance and some that dont',
'both_ash_strs_percent': 'percent of streets in boulder that have both good & bad ash trees',

'at_risk_strs': 'streets that have an ajoining street that has a tree that needs maintenance',
'at_risk_strs_d': 'alphabetized dictionary of streets that have no bad trees and the amount of bad trees on ajoining streets',
'at_risk_strs_sorted': 'list of streets that have no bad trees, sorted by how many bad trees are on ajoining streets',
'at_risk_strs_ash_dic': 'dictionary of streets that have neighboring streets with bad ash trees, and the amount of ash trees and the percentage of ash tree makeup of that street',
'at_risk_hoods': 'list of hoods, sorted by the amount of at risk streets they have',

'strs_trees_percent_dic': 'alphabetized dictionary of each tree, and the average percentage that the tree makes up for streets that have that tree',
'strs_trees_percent_dic_sorted': 'list of each tree, sorted by the average percentage that the tree makes up for streets that have that tree',

'strs_trees_percent_dic_2': 'alphabetized dictionary of each tree, and the average percentage of trees that that tree makes up for every street',
'strs_trees_percent_dic_sorted_2': 'list of each tree, sorted by average percentage of trees that that tree makes up for every street',

'strs_trees_percent_dic_3': 'alphabetized dictionary of each tree without ash and the average percentage of trees that that tree makes up for every street',
'strs_trees_percent_dic_sorted_3': 'above, but sorted',

             
'strs_tree_counts': 'Dictionary of each street. values are counts of trees on that street, and another dictionary that has each type of tree on that street, and the count of that tree and the percentage makeup of that tree on that street',
'high_percents':'list of [streets,tree,count of trees on street, percent tree] for streets that have super high percentages of a certain type of tree. filtered for only streets that have a lot of trees',
'percent_ash':'see above, but only for ash trees'}

# %%
ash_weighted_streets = {}
for i in strs:
    try:
        ash_weighted_streets[i]=strs_tree_counts[i][0]*strs_tree_counts[i][1]['Ash'][1]
    except:
        pass
ash_weighted_streets = sorted(ash_weighted_streets.items(),key=operator.itemgetter(1),reverse=True)
ash_weighted_streets #### Artificially weighted streets. Took number of total trees on street * percentage of ash
# Out:
# [('9TH ST', 245.0),
#  ('PEARL ST', 156.0),
#  ('LINDEN PARK DR', 149.0),
#  ('BROADWAY', 148.0),
#  ('ARAPAHOE  AV', 122.00000000000001),
#  ('ARAPAHOE AV', 122.0),
#  ('MAPLETON AV', 114.00000000000001),
#  ('SPRUCE ST', 105.0),
#  ('KALMIA AV', 98.0),
#  ('BASELINE RD', 95.0),
#  ('WALNUT ST', 93.0),
#  ('POPLAR AV', 76.0),
#  ('19TH ST', 71.0),
#  ('28TH ST', 70.0),
#  ('13TH ST', 67.0),
#  ('CANYON BV', 67.0),
#  ('PINE ST', 66.0),
#  ('55TH ST', 58.0),
#  ('VALMONT RD', 56.0),
#  ('17TH ST', 55.0),
#  ('30TH ST', 51.0),
#  ('SIOUX DR', 51.0),
#  ('BLUFF ST', 49.0),
#  ('CENTRAL AV', 49.0),
#  ('LINDEN AV', 48.999999999999993),
#  ('S BROADWAY', 48.0),
#  ('JUNIPER AV', 47.0),
#  ('16TH ST', 46.0),
#  ('PENNSYLVANIA AV', 45.0),
#  ('11TH ST', 43.000000000000007),
#  ('4TH ST', 43.0),
#  ('KINGS RIDGE BV', 41.0),
#  ('MOHAWK DR', 40.0),
#  ('8TH ST', 38.0),
#  ('18TH ST', 37.0),
#  ('75TH ST', 37.0),
#  ('GROVE ST', 35.0),
#  ('WHITE PL', 35.0),
#  ('26TH ST', 34.0),
#  ('IRIS AV', 34.0),
#  ('6TH ST', 33.0),
#  ('DAKOTA BV', 33.0),
#  ('FRANKLIN DR', 33.0),
#  ('PLEASANT ST', 33.0),
#  ('34TH ST', 32.0),
#  ('LINCOLN PL', 31.0),
#  ('TABLE MESA DR', 31.0),
#  ('MARINE ST', 30.000000000000004),
#  ('5TH ST', 29.999999999999996),
#  ('UNIVERSITY AV', 29.0),
#  ('47TH ST', 28.0),
#  ('3RD ST', 27.000000000000004),
#  ('FOLSOM ST', 27.0),
#  ('GREENBRIAR BV', 27.0),
#  ('MOORHEAD AV', 27.0),
#  ('TANTRA PARK CR', 27.0),
#  ('7TH ST', 26.0),
#  ('COLLEGE AV', 26.0),
#  ('FLATIRON PY', 26.0),
#  ('ROXWOOD LN', 26.0),
#  ('10TH ST', 25.0),
#  ('MAXWELL AV', 25.0),
#  ('S 36TH ST', 25.0),
#  ('HAWTHORN AV', 23.0),
#  ('QUINCE AV', 23.0),
#  ('15TH ST', 22.0),
#  ('FOOTHILLS PY', 22.0),
#  ('MEADOW GLEN DR', 22.0),
#  ('NORWOOD AV', 22.0),
#  ('SPINE RD', 22.0),
#  ('14TH ST', 21.0),
#  ('ALPINE AV', 21.0),
#  ('BUTTE MILL RD', 21.0),
#  ('LODGE CT', 21.0),
#  ('LODGE LN', 21.0),
#  ('RESERVOIR RD', 21.0),
#  ('WONDERLAND HILL AV', 21.0),
#  ('CHERRY AV', 20.0),
#  ('GIBBS AV', 20.0),
#  ('22ND ST', 19.0),
#  ('GLENWOOD DR', 19.0),
#  ('POPLAR PL', 19.0),
#  ('WRIGHT AV', 19.0),
#  ('CHAUTAUQUA', 18.0),
#  ('MANHATTAN DR', 18.0),
#  ('WINCHESTER CR', 18.0),
#  ('33RD ST', 17.0),
#  ('BLUEBELL AV', 17.0),
#  ('GILLASPIE DR', 17.0),
#  ('ORCHARD AV', 17.0),
#  ('ST. CROIX ST', 17.0),
#  ('63RD ST', 16.0),
#  ('GUNPARK DR', 16.0),
#  ('LEHIGH ST', 16.0),
#  ('NOBLE CT', 16.0),
#  ('SUMAC AV', 16.0),
#  ('TOPAZ DR', 16.0),
#  ('GAPTOR RD', 15.000000000000002),
#  ('20TH ST', 15.0),
#  ('COLORADO AV', 15.0),
#  ('OLD TALE RD', 14.0),
#  ('RACQUET LN', 14.0),
#  ('STERLING CR W', 14.0),
#  ('COMMERCE ST', 13.0),
#  ('OAKLEAF CR', 13.0),
#  ('PENNSYLVANIA PL', 13.0),
#  ('TAMARACK AV', 13.0),
#  ('23RD ST', 12.0),
#  ('CASCADE AV', 12.0),
#  ('CEDAR AV', 12.0),
#  ('GLENDALE GULCH CR', 12.0),
#  ('GOSS ST', 12.0),
#  ('GRANT PL', 12.0),
#  ('MANHATTAN CR', 12.0),
#  ('MEREDITH WAY', 12.0),
#  ('NAUTILUS CT N', 12.0),
#  ('PORTLAND PL', 12.0),
#  ('S BOULDER CR', 12.0),
#  ('STREAMSIDE LN', 12.0),
#  ('21ST ST', 11.0),
#  ('49TH  ST', 11.0),
#  ('CENTENNIAL TR', 11.0),
#  ('EUCLID AV', 11.0),
#  ('GRAPE AV', 11.0),
#  ('OSAGE DR', 11.0),
#  ('REDWOOD AV', 11.0),
#  ('STERLING DR', 11.0),
#  ('29TH ST', 10.0),
#  ('BRIARWOOD DR', 10.0),
#  ('DIAGONAL HY', 10.0),
#  ('E AURORA AV', 10.0),
#  ('HIGHLAND AV', 10.0),
#  ('PONCA PL', 10.0),
#  ('THUNDERBIRD CT E', 10.0),
#  ('WINDING TRAIL DR', 10.0),
#  ('BEAR MOUNTAIN DR', 9.0),
#  ('BROOKLAWN DR', 9.0),
#  ('CHAMBERS DR', 9.0),
#  ('CONCORD AV', 9.0),
#  ('HARTFORD DR', 9.0),
#  ('IRIS CT', 9.0),
#  ('MOUNTAIN VIEW RD', 9.0),
#  ('QUALLA DR', 9.0),
#  ('RIVERBEND RD', 9.0),
#  ('TABLE MESA CT', 9.0),
#  ('ZAMIA AV', 9.0),
#  ('BEAN MOUNTAIN LN', 8.0),
#  ('BELLEVUE DR', 8.0),
#  ('COLUMBINE AV', 8.0),
#  ('EISENHOWER DR', 8.0),
#  ('FAIRWAY CT', 8.0),
#  ('GALENA WY', 8.0),
#  ('LEFT HAND CR', 8.0),
#  ('MACARTHUR LN', 8.0),
#  ('N 63RD ST', 8.0),
#  ('NEVIS ST', 8.0),
#  ('PERIWINKLE DR', 8.0),
#  ('REDSTONE LN', 8.0),
#  ('AURORA AV', 7.0),
#  ('AURORA PL', 7.0),
#  ('CLOVERLEAF DR', 7.0),
#  ('FLORAL DR', 7.0),
#  ('JEWEL CREEK CT', 7.0),
#  ('LASHLEY LN', 7.0),
#  ('LEE CR', 7.0),
#  ('LONE EAGLE CT', 7.0),
#  ('LOOKOUT RD', 7.0),
#  ('MITCHELL LN', 7.0),
#  ('PAWNEE DR', 7.0),
#  ('PENROSE PL', 7.0),
#  ('VALLEY VIEW DR', 7.0),
#  ('REGENT DR', 6.9999999999999991),
#  ('CLOUD CT', 6.0),
#  ('CORRIENTE DR', 6.0),
#  ('DELLWOOD AV', 6.0),
#  ('EAGLE WY', 6.0),
#  ('FOXTAIL CT', 6.0),
#  ('GILBERT ST', 6.0),
#  ('JORDAN PL', 6.0),
#  ('LAGUNA PL', 6.0),
#  ('LODGE PL', 6.0),
#  ('LONGBOW DR', 6.0),
#  ('OAK AV', 6.0),
#  ('OAKTREE CT', 6.0),
#  ('ORCHARD CT', 6.0),
#  ('TABLE TOP CT', 6.0),
#  ('VISTA DR', 6.0),
#  ('YELLOW PINE AV', 6.0),
#  ('MARIPOSA AV', 5.9999999999999991),
#  ('SUNDOWN LN', 5.9999999999999991),
#  ('APACHE RD', 5.0),
#  ('ARNETT ST', 5.0),
#  ('ARROWWOOD LN', 5.0),
#  ('ASH AV', 5.0),
#  ('BALSAM AV', 5.0),
#  ('CENTER GREEN DR', 5.0),
#  ('EVERGREEN AV', 5.0),
#  ('GARNET LN', 5.0),
#  ('HILLSDALE WY', 5.0),
#  ('INDIAN SUMMER CT', 5.0),
#  ('JUNIPER CT', 5.0),
#  ('KOHLER DR', 5.0),
#  ('LARAMIE BL', 5.0),
#  ('LINDEN DR', 5.0),
#  ('LONGBOW CT', 5.0),
#  ('LUDLOW ST', 5.0),
#  ('MINEOLA CT', 5.0),
#  ('MORGAN DR', 5.0),
#  ('NORTH ST', 5.0),
#  ('NORWOOD CT', 5.0),
#  ('PINE VALLEY CT', 5.0),
#  ('ROSEWOOD AV', 5.0),
#  ('STERLING CT', 5.0),
#  ('UPLAND AV', 5.0),
#  ('UTICA CR', 5.0),
#  ('VINEYARD LN', 5.0),
#  ('WELLINGTON RD', 5.0),
#  ('12TH ST', 4.0),
#  ('57TH CT', 4.0),
#  ('BUCKINGHAM RD', 4.0),
#  ('CAYMAN PL', 4.0),
#  ('CORDRY CT', 4.0),
#  ('GUNBARREL AV', 4.0),
#  ('HARDSCRABBLE DR', 4.0),
#  ('HARRISON AV', 4.0),
#  ('HIGH ST', 4.0),
#  ('HURON CT', 4.0),
#  ('INCA PK', 4.0),
#  ('ISLAND DR', 4.0),
#  ('JAY RD', 4.0),
#  ('MEADOW AV', 4.0),
#  ('MORNING GLORY DR', 4.0),
#  ('MULBERRY CT', 4.0),
#  ('NAUTILUS CT S', 4.0),
#  ('NORTH FORK CT', 4.0),
#  ('NORTHBROOK PL', 4.0),
#  ('ODELL PL', 4.0),
#  ('ONEAL PY', 4.0),
#  ('PIMA CT', 4.0),
#  ('PREMIER PL', 4.0),
#  ('REDSTONE RD', 4.0),
#  ('RIM ROCK CT', 4.0),
#  ('SEMINOLE DR', 4.0),
#  ('SHADOW CREEK DR', 4.0),
#  ('STEPHENS RD', 4.0),
#  ('STERLING CR E', 4.0),
#  ('TANTRA DR', 4.0),
#  ('TELLURIDE CR', 4.0),
#  ('VIVIAN CR', 4.0),
#  ('WILDERNESS PL', 4.0),
#  ('27TH  WY', 3.0),
#  ('35TH ST', 3.0),
#  ('48TH  CT', 3.0),
#  ('AIRPORT RD', 3.0),
#  ('ALPINE DR', 3.0),
#  ('BATES AV', 3.0),
#  ('BERKLEY CT', 3.0),
#  ('BLACK HAWK RD', 3.0),
#  ('BROOKFIELD DR', 3.0),
#  ('CASCADE PL', 3.0),
#  ('CHERRYVALE RD', 3.0),
#  ('CLEMATIS DR', 3.0),
#  ('COLLEGE PL', 3.0),
#  ('CONESTOGA CT', 3.0),
#  ('CRESCENT DR', 3.0),
#  ('CRIPPLE CREEK TR', 3.0),
#  ('DEER VALLEY RD', 3.0),
#  ('EDISON AV', 3.0),
#  ('FOREST AV', 3.0),
#  ('FULTON CR', 3.0),
#  ('FURMAN WY', 3.0),
#  ('GENESEE CT', 3.0),
#  ('GRANDVIEW AV', 3.0),
#  ('ILLINI WY', 3.0),
#  ('ITHACA DR', 3.0),
#  ('KENYON CR', 3.0),
#  ('KING AV', 3.0),
#  ('LARAMIE BV', 3.0),
#  ('LINKS DR', 3.0),
#  ('LONGVIEW LN', 3.0),
#  ('MEADOWBROOK DR', 3.0),
#  ('PAMPAS CT', 3.0),
#  ('S 42ND ST', 3.0),
#  ('S 44TH ST', 3.0),
#  ('SILVER LAKE AV', 3.0),
#  ('SLICK ROCK CT', 3.0),
#  ('SPRING VALLEY DR', 3.0),
#  ('SQUIRES CR', 3.0),
#  ('STONEWALL PL', 3.0),
#  ('SYCAMORE AV', 3.0),
#  ('TABRIZ PL', 3.0),
#  ('TELLURIDE PL', 3.0),
#  ('TESLA CIR', 3.0),
#  ('TINCUP CR', 3.0),
#  ('TWIN LAKES RD', 3.0),
#  ('UTICA AV', 3.0),
#  ('WESTERN AV', 3.0),
#  ('WILD PLUM CT', 3.0),
#  ('YARMOUTH AV', 3.0),
#  ('24TH ST', 2.0),
#  ('25TH ST', 2.0),
#  ('31ST ST', 2.0),
#  ('36TH ST', 2.0),
#  ('48TH ST', 2.0),
#  ('ABBEY PL', 2.0),
#  ('AIKINS WY', 2.0),
#  ('ALBION WY', 2.0),
#  ('ARBOR GLEN PL', 2.0),
#  ('BALSAM DR', 2.0),
#  ('BEAR MOUNTAIN CT', 2.0),
#  ('BLUE SAGE CT', 2.0),
#  ('BRANDON CREEK DR', 2.0),
#  ('BURR PL', 2.0),
#  ('BUTTE ST', 2.0),
#  ('CADDO PY', 2.0),
#  ('CIMMARON WY', 2.0),
#  ('DALLAS PL', 2.0),
#  ('DARLEY AV', 2.0),
#  ('DARTMOUTH AV', 2.0),
#  ('DOVER DR', 2.0),
#  ('EDGEWOOD DR', 2.0),
#  ('EUCLID PL', 2.0),
#  ('FAIR PL', 2.0),
#  ('GODDARD PL', 2.0),
#  ('GUADELOUPE ST', 2.0),
#  ('HAMILTON CT', 2.0),
#  ('HANOVER AV', 2.0),
#  ('HAPGOOD ST', 2.0),
#  ('HERMOSA DR', 2.0),
#  ('HIGH COUNTRY CT', 2.0),
#  ('HOLLYBERRY LN', 2.0),
#  ('JAPONICA WY', 2.0),
#  ('JEFFERSON ST', 2.0),
#  ('JIMSON CT', 2.0),
#  ('JUILLIARD ST', 2.0),
#  ('KNOX DR', 2.0),
#  ('LANDIS CT', 2.0),
#  ('LAUREL AV', 2.0),
#  ('LOCUST AV', 2.0),
#  ('LOCUST PL', 2.0),
#  ('LONETREE CT', 2.0),
#  ('LOVE CT', 2.0),
#  ('MADISON AV', 2.0),
#  ('MARTIN DR', 2.0),
#  ('MCKINLEY DR', 2.0),
#  ('MEADOW PL', 2.0),
#  ('MESA DR', 2.0),
#  ('MESA TOP CT', 2.0),
#  ('NEBRINA PL', 2.0),
#  ('NORTH STAR CT', 2.0),
#  ('OAK CR', 2.0),
#  ('ONEAL CR', 2.0),
#  ('ONEAL CR SW', 2.0),
#  ('OTTAWA PL', 2.0),
#  ('PATTON DR', 2.0),
#  ('PINEHURST DR', 2.0),
#  ('PINON DR', 2.0),
#  ('QUAIL CR', 2.0),
#  ('QUARRY CT', 2.0),
#  ('QUINCE CR', 2.0),
#  ('S 31ST ST', 2.0),
#  ('S 32ND ST', 2.0),
#  ('S ORCHARD CREEK CR', 2.0),
#  ('SIERRA DR', 2.0),
#  ('SILVER PLUME LN', 2.0),
#  ('SMUGGLER CR', 2.0),
#  ('SMUGGLER PL', 2.0),
#  ('SPRINGDALE LN', 2.0),
#  ('UNION AV', 2.0),
#  ('UTICA CT', 2.0),
#  ('VIOLET AV', 2.0),
#  ('YALE RD', 2.0),
#  ('YAUPON AV', 2.0),
#  ('DEWEY AV', 1.9999999999999998),
#  ('38TH ST', 1.0),
#  ('AGATE LN', 1.0),
#  ('AMBER ST', 1.0),
#  ('ARMER AV', 1.0),
#  ('ASTOR LN', 1.0),
#  ('ATHENS ST', 1.0),
#  ('AVACADO RD', 1.0),
#  ('AVOCADO RD', 1.0),
#  ('BARBADOS PL', 1.0),
#  ('BEREA DR', 1.0),
#  ('BRANDYWINE CT', 1.0),
#  ('CHASE CT', 1.0),
#  ('CHINLE AV', 1.0),
#  ('CHRISTMAS TREE DR', 1.0),
#  ('CIRCLE DR', 1.0),
#  ('CLEVELAND PL', 1.0),
#  ('COMANCHE DR', 1.0),
#  ('CORONA TR', 1.0),
#  ('CRAGMOOR RD', 1.0),
#  ('CRIPPLE CREEK SQ', 1.0),
#  ('DAKOTA PL', 1.0),
#  ('DEL ROSA CT', 1.0),
#  ('DREW RANCH LN', 1.0),
#  ('E EUCLID AV', 1.0),
#  ('EDISON CT', 1.0),
#  ('ELLSWORTH PL', 1.0),
#  ('ELM AV', 1.0),
#  ('ERIE DR', 1.0),
#  ('EVANS DR', 1.0),
#  ('FERN PL', 1.0),
#  ('FREMONT AV', 1.0),
#  ('FULLER CT', 1.0),
#  ('GALLATIN PL', 1.0),
#  ('GILPIN DR', 1.0),
#  ('GORDON DR', 1.0),
#  ('GUNBARREL CR', 1.0),
#  ('HANCOCK DR', 1.0),
#  ('HARVARD LN', 1.0),
#  ('HAWTHORN PL', 1.0),
#  ('HAZELWOOD CT', 1.0),
#  ('HEIDELBERG DR', 1.0),
#  ('HOLMES PL', 1.0),
#  ('ILIFF ST', 1.0),
#  ('INCA PY', 1.0),
#  ('IROQUOIS DR', 1.0),
#  ('JASMINE CR', 1.0),
#  ('JONATHAN PL', 1.0),
#  ('JUDSON DR', 1.0),
#  ('KALMIA CR', 1.0),
#  ('KELLOGG CR', 1.0),
#  ('KENNEDY CT', 1.0),
#  ('KENWOOD DR', 1.0),
#  ('KINGSTOWN PL', 1.0),
#  ('KINNIKINIC RD', 1.0),
#  ('LAKEBRIAR DR', 1.0),
#  ('LARKWOOD CT', 1.0),
#  ('MACKY WY', 1.0),
#  ('MERRITT DR', 1.0),
#  ('MOFFIT CT', 1.0),
#  ('MOSS ROCK PL', 1.0),
#  ('MOUNTAIN LAUREL PL', 1.0),
#  ('N 55TH ST', 1.0),
#  ('N TERRACE CR', 1.0),
#  ('NEHER LN', 1.0),
#  ('NORTH RIDGE CT', 1.0),
#  ('NORTON ST', 1.0),
#  ('OAKDALE PL', 1.0),
#  ('OAKWOOD PL', 1.0),
#  ('ONEIDA ST', 1.0),
#  ('ONTARIO CT', 1.0),
#  ('OUTBACK CT', 1.0),
#  ('PARK LN', 1.0),
#  ('PARK SADDLE CT', 1.0),
#  ('PAWNEE PL', 1.0),
#  ('PEMBROKE GARDENS', 1.0),
#  ('POPLAR LN', 1.0),
#  ('PROMINTORY CT', 1.0),
#  ('RACQUET CT', 1.0),
#  ('RALSTON ST', 1.0),
#  ('RAMP', 1.0),
#  ('REGIS DR', 1.0),
#  ('ROSE HILL DR', 1.0),
#  ('S 43RD ST', 1.0),
#  ('SCRUB OAK CR', 1.0),
#  ('SENECA PL', 1.0),
#  ('SHERWOOD CR', 1.0),
#  ('SNOWBERRY CT', 1.0),
#  ('SOUTH ST', 1.0),
#  ('SUNNYSIDE LN', 1.0),
#  ('SUNSET BV', 1.0),
#  ('TESLA CT', 1.0),
#  ('TINCUP CT', 1.0),
#  ('TOEDTLI DR', 1.0),
#  ('WHITE ROCK CR', 1.0),
#  ('WILDWOOD RD', 1.0),
#  ('WINGATE AV', 1.0),
#  ('SUNSHINE CANYON DR', 0.99999999999999989)]

# %%
ash_weighted_streets_trees = {}
for i in ash_weighted_streets:
    if strs_tree_counts[i[0]][1]['Ash'][1]>.08: #### grab all streets that have ash percentages of over .08
        ash_weighted_streets_trees[i[0]]=[i[1],sorted(strs_tree_counts[i[0]][1].items(),key=operator.itemgetter(1),reverse=True)[:10]]
ash_weighted_streets_trees #this is a dictionary that has the grabbed streets, weighted value calculated above, and top 10 tree percentages on that street
# Out:
# {'11TH ST': [43.000000000000007,
#   [('Ash', [43, 0.12721893491124261]),
#    ('Common Honeylocust', [41, 0.12130177514792899]),
#    ('Silver Maple', [40, 0.11834319526627218]),
#    ('Sugar Maple', [19, 0.056213017751479293]),
#    ('American Linden', [15, 0.044378698224852069]),
#    ('Siberian Elm', [14, 0.04142011834319527]),
#    ('Norway Maple', [11, 0.032544378698224852]),
#    ('Flowering Crabapple', [11, 0.032544378698224852]),
#    ('Freeman Maple', [9, 0.026627218934911243]),
#    ('Northern Hackberry', [8, 0.023668639053254437])]],
#  '13TH ST': [67.0,
#   [('Ash', [67, 0.11452991452991453]),
#    ('Amur Maple', [67, 0.11452991452991453]),
#    ('Siberian Elm', [61, 0.10427350427350428]),
#    ('Common Honeylocust', [52, 0.088888888888888892]),
#    ('Littleleaf Linden', [31, 0.052991452991452991]),
#    ('Red Maple', [22, 0.037606837606837605]),
#    ('Silver Maple', [17, 0.029059829059829061]),
#    ('Flowering Crabapple', [16, 0.02735042735042735]),
#    ('Swamp White Oak', [16, 0.02735042735042735]),
#    ('Freeman Maple', [14, 0.023931623931623933])]],
#  '16TH ST': [46.0,
#   [('Ash', [46, 0.1220159151193634]),
#    ('Flowering Crabapple', [32, 0.084880636604774531]),
#    ('Siberian Elm', [30, 0.079575596816976124]),
#    ('Common Honeylocust', [29, 0.076923076923076927]),
#    ('Silver Maple', [24, 0.063660477453580902]),
#    ('Flowering Pear', [17, 0.045092838196286469]),
#    ('Swamp White Oak', [17, 0.045092838196286469]),
#    ('Austrian Pine', [14, 0.037135278514588858]),
#    ('Norway Maple', [13, 0.034482758620689655]),
#    ('Northern Red oak', [13, 0.034482758620689655])]],
#  '17TH ST': [55.0,
#   [('Ash', [55, 0.14248704663212436]),
#    ('Siberian Elm', [32, 0.082901554404145081]),
#    ('Crack Willow', [32, 0.082901554404145081]),
#    ('Common Honeylocust', [23, 0.059585492227979271]),
#    ('Flowering Crabapple', [22, 0.056994818652849742]),
#    ('Boxelder', [19, 0.049222797927461141]),
#    ('Blue Spruce', [14, 0.036269430051813469]),
#    ('Bur Oak', [14, 0.036269430051813469]),
#    ('Austrian Pine', [12, 0.031088082901554404]),
#    ('Quaking Aspen', [9, 0.023316062176165803])]],
#  '18TH ST': [37.0,
#   [('Ash', [37, 0.13805970149253732]),
#    ('Siberian Elm', [22, 0.082089552238805971]),
#    ('Silver Maple', [17, 0.063432835820895525]),
#    ('Tree of Heaven', [17, 0.063432835820895525]),
#    ('Flowering Crabapple', [16, 0.059701492537313432]),
#    ('Common Honeylocust', [14, 0.052238805970149252]),
#    ('Blue Spruce', [13, 0.048507462686567165]),
#    ('Boxelder', [11, 0.041044776119402986]),
#    ('Quaking Aspen', [9, 0.033582089552238806]),
#    ('Northern Red oak', [7, 0.026119402985074626])]],
#  '19TH ST': [71.0,
#   [('Siberian Elm', [204, 0.26877470355731226]),
#    ('Plains Cottonwood', [104, 0.1370223978919631]),
#    ('Ash', [71, 0.093544137022397889]),
#    ('Blue Spruce', [31, 0.040843214756258232]),
#    ('Austrian Pine', [29, 0.038208168642951248]),
#    ('Common Honeylocust', [27, 0.035573122529644272]),
#    ('Silver Maple', [27, 0.035573122529644272]),
#    ('Flowering Crabapple', [19, 0.025032938076416336]),
#    ('Western Catalpa', [17, 0.022397891963109356]),
#    ('Boxelder', [14, 0.01844532279314888])]],
#  '20TH ST': [15.0,
#   [('Siberian Elm', [63, 0.38650306748466257]),
#    ('Ash', [15, 0.09202453987730061]),
#    ('Common Honeylocust', [12, 0.073619631901840496]),
#    ('Northern Hackberry', [9, 0.055214723926380369]),
#    ('Flowering Crabapple', [7, 0.042944785276073622]),
#    ('Amur Maple', [6, 0.036809815950920248]),
#    ('Blue Spruce', [4, 0.024539877300613498]),
#    ('Ponderosa Pine', [4, 0.024539877300613498]),
#    ('English Oak', [4, 0.024539877300613498]),
#    ('Black Walnut', [3, 0.018404907975460124])]],
#  '21ST ST': [11.0,
#   [('Ash', [11, 0.16176470588235295]),
#    ('Siberian Elm', [10, 0.14705882352941177]),
#    ('Blue Spruce', [10, 0.14705882352941177]),
#    ('Boxelder', [8, 0.11764705882352941]),
#    ('Goldenrain Tree', [4, 0.058823529411764705]),
#    ('Common Honeylocust', [3, 0.044117647058823532]),
#    ('Silver Maple', [3, 0.044117647058823532]),
#    ('Norway Maple', [2, 0.029411764705882353]),
#    ('Flowering Crabapple', [2, 0.029411764705882353]),
#    ('Tree of Heaven', [2, 0.029411764705882353])]],
#  '22ND ST': [19.0,
#   [('Ash', [19, 0.13475177304964539]),
#    ('Blue Spruce', [12, 0.085106382978723402]),
#    ('Flowering Crabapple', [12, 0.085106382978723402]),
#    ('Common Honeylocust', [11, 0.078014184397163122]),
#    ('Silver Maple', [9, 0.063829787234042548]),
#    ('Thornless Cockspur Hawthorn', [6, 0.042553191489361701]),
#    ('Quaking Aspen', [6, 0.042553191489361701]),
#    ('Plum species', [5, 0.035460992907801421]),
#    ('Norway Maple', [5, 0.035460992907801421]),
#    ('Flowering Pear', [4, 0.028368794326241134])]],
#  '23RD ST': [12.0,
#   [('Siberian Elm', [13, 0.14444444444444443]),
#    ('Ash', [12, 0.13333333333333333]),
#    ('Boxelder', [11, 0.12222222222222222]),
#    ('Western Catalpa', [7, 0.077777777777777779]),
#    ('Douglas-fir', [6, 0.066666666666666666]),
#    ('Blue Spruce', [5, 0.055555555555555552]),
#    ('Silver Maple', [5, 0.055555555555555552]),
#    ('Common Honeylocust', [5, 0.055555555555555552]),
#    ('Rocky Mountain Juniper', [4, 0.044444444444444446]),
#    ('Russian-olive', [3, 0.033333333333333333])]],
#  '25TH ST': [2.0,
#   [('Siberian Elm', [3, 0.25]),
#    ('Mugo Pine', [2, 0.16666666666666666]),
#    ('Ash', [2, 0.16666666666666666]),
#    ('Silver Maple', [1, 0.083333333333333329]),
#    ('Freeman Maple', [1, 0.083333333333333329]),
#    ('Douglas-fir', [1, 0.083333333333333329]),
#    ('Ponderosa Pine', [1, 0.083333333333333329]),
#    ('Flowering Crabapple', [1, 0.083333333333333329])]],
#  '26TH ST': [34.0,
#   [('Siberian Elm', [99, 0.44]),
#    ('Ash', [34, 0.15111111111111111]),
#    ('Tree of Heaven', [12, 0.053333333333333337]),
#    ('Flowering Crabapple', [9, 0.040000000000000001]),
#    ('Common Honeylocust', [8, 0.035555555555555556]),
#    ('Blue Spruce', [7, 0.03111111111111111]),
#    ('Austrian Pine', [6, 0.026666666666666668]),
#    ('Mugo Pine', [6, 0.026666666666666668]),
#    ('Native Cottonwood', [5, 0.022222222222222223]),
#    ('Boxelder', [4, 0.017777777777777778])]],
#  '27TH  WY': [3.0,
#   [('English Oak', [7, 0.53846153846153844]),
#    ('Ash', [3, 0.23076923076923078]),
#    ('American Linden', [2, 0.15384615384615385]),
#    ('Littleleaf Linden', [1, 0.076923076923076927])]],
#  '28TH ST': [70.0,
#   [('Common Honeylocust', [75, 0.095785440613026823]),
#    ('Northern Hackberry', [71, 0.090676883780332063]),
#    ('Ash', [70, 0.089399744572158366]),
#    ('American Linden', [47, 0.060025542784163471]),
#    ('Swamp White Oak', [43, 0.054916985951468711]),
#    ('Sumac species', [42, 0.053639846743295021]),
#    ('Siberian Elm', [37, 0.047254150702426563]),
#    ('Willow species', [37, 0.047254150702426563]),
#    ('Flowering Crabapple', [37, 0.047254150702426563]),
#    ('Native Cottonwood', [34, 0.043422733077905493])]],
#  '29TH ST': [10.0,
#   [('Ash', [10, 0.11764705882352941]),
#    ('Littleleaf Linden', [10, 0.11764705882352941]),
#    ('Siberian Elm', [9, 0.10588235294117647]),
#    ('Hybrid Elm', [8, 0.094117647058823528]),
#    ('Northern Red oak', [7, 0.082352941176470587]),
#    ('Northern Hackberry', [6, 0.070588235294117646]),
#    ('Bur Oak', [5, 0.058823529411764705]),
#    ('Boxelder', [4, 0.047058823529411764]),
#    ('American Linden', [4, 0.047058823529411764]),
#    ('Austrian Pine', [2, 0.023529411764705882])]],
#  '30TH ST': [51.0,
#   [('Ash', [51, 0.10991379310344827]),
#    ('Common Honeylocust', [46, 0.099137931034482762]),
#    ('Flowering Crabapple', [35, 0.075431034482758619]),
#    ('Plains Cottonwood', [32, 0.068965517241379309]),
#    ('Swamp White Oak', [26, 0.056034482758620691]),
#    ('Boxelder', [21, 0.045258620689655173]),
#    ('Littleleaf Linden', [21, 0.045258620689655173]),
#    ('Willow species', [16, 0.034482758620689655]),
#    ('Hawthorn species', [12, 0.025862068965517241]),
#    ('Northern Red oak', [12, 0.025862068965517241])]],
#  '33RD ST': [17.0,
#   [('Ash', [17, 0.24285714285714285]),
#    ('Austrian Pine', [15, 0.21428571428571427]),
#    ('Swamp White Oak', [6, 0.085714285714285715]),
#    ('Common Honeylocust', [4, 0.057142857142857141]),
#    ('Flowering Pear', [4, 0.057142857142857141]),
#    ('Ponderosa Pine', [4, 0.057142857142857141]),
#    ('Pinon Pine', [3, 0.042857142857142858]),
#    ('Amur Maple', [3, 0.042857142857142858]),
#    ('Serviceberry species', [2, 0.028571428571428571]),
#    ('Northern Hackberry', [2, 0.028571428571428571])]],
#  '34TH ST': [32.0,
#   [('Ash', [32, 0.1787709497206704]),
#    ('Siberian Elm', [25, 0.13966480446927373]),
#    ('Boxelder', [17, 0.094972067039106142]),
#    ('Willow species', [17, 0.094972067039106142]),
#    ('Flowering Crabapple', [12, 0.067039106145251395]),
#    ('Native Cottonwood', [10, 0.055865921787709494]),
#    ('Littleleaf Linden', [7, 0.039106145251396648]),
#    ('Common Honeylocust', [6, 0.033519553072625698]),
#    ('Plains Cottonwood', [5, 0.027932960893854747]),
#    ('Bur Oak', [4, 0.0223463687150838])]],
#  '36TH ST': [2.0,
#   [('Siberian Elm', [3, 0.14285714285714285]),
#    ('Quaking Aspen', [2, 0.095238095238095233]),
#    ('Russian-olive', [2, 0.095238095238095233]),
#    ('Native Cottonwood', [2, 0.095238095238095233]),
#    ('Ash', [2, 0.095238095238095233]),
#    ('Juniper species', [2, 0.095238095238095233]),
#    ('Silver Maple', [1, 0.047619047619047616]),
#    ('Bur Oak', [1, 0.047619047619047616]),
#    ('Oak species', [1, 0.047619047619047616]),
#    ('Western Catalpa', [1, 0.047619047619047616])]],
#  '3RD ST': [27.000000000000004,
#   [('Ash', [27, 0.12558139534883722]),
#    ('Siberian Elm', [26, 0.12093023255813953]),
#    ('Blue Spruce', [23, 0.10697674418604651]),
#    ('Juniper species', [18, 0.083720930232558138]),
#    ('Native Cottonwood', [14, 0.065116279069767441]),
#    ('Pinon Pine', [13, 0.060465116279069767]),
#    ('Ponderosa Pine', [13, 0.060465116279069767]),
#    ('Common Honeylocust', [9, 0.041860465116279069]),
#    ('Black Walnut', [9, 0.041860465116279069]),
#    ('Russian-olive', [6, 0.027906976744186046])]],
#  '47TH ST': [28.0,
#   [('Crack Willow', [32, 0.1693121693121693]),
#    ('Ash', [28, 0.14814814814814814]),
#    ('Flowering Crabapple', [17, 0.089947089947089942]),
#    ('American Linden', [12, 0.063492063492063489]),
#    ('Siberian Elm', [12, 0.063492063492063489]),
#    ('Accolade Elm', [10, 0.052910052910052907]),
#    ('Northern Hackberry', [8, 0.042328042328042326]),
#    ('Boxelder', [7, 0.037037037037037035]),
#    ('Chinkapin Oak', [7, 0.037037037037037035]),
#    ('Kentucky Coffeetree', [6, 0.031746031746031744])]],
#  '48TH  CT': [3.0,
#   [('Common Honeylocust', [6, 0.40000000000000002]),
#    ('Norway Maple', [6, 0.40000000000000002]),
#    ('Ash', [3, 0.20000000000000001])]],
#  '48TH ST': [2.0,
#   [('Swamp White Oak', [4, 0.44444444444444442]),
#    ('Flowering Crabapple', [3, 0.33333333333333331]),
#    ('Ash', [2, 0.22222222222222221])]],
#  '49TH  ST': [11.0,
#   [('Ash', [11, 0.6875]),
#    ('Red Maple', [4, 0.25]),
#    ('Common Honeylocust', [1, 0.0625])]],
#  '4TH ST': [43.0,
#   [('Ash', [43, 0.094091903719912467]),
#    ('Flowering Crabapple', [38, 0.083150984682713341]),
#    ('Siberian Elm', [37, 0.080962800875273522]),
#    ('Blue Spruce', [32, 0.070021881838074396]),
#    ('Common Honeylocust', [28, 0.061269146608315096]),
#    ('Norway Maple', [25, 0.054704595185995623]),
#    ('Silver Maple', [24, 0.052516411378555797]),
#    ('Plum species', [17, 0.037199124726477024]),
#    ('Sugar Maple', [13, 0.028446389496717725]),
#    ('Native Cottonwood', [12, 0.026258205689277898])]],
#  '55TH ST': [58.0,
#   [('Ash', [58, 0.31182795698924731]),
#    ('Siberian Elm', [14, 0.075268817204301078]),
#    ('Austrian Pine', [12, 0.064516129032258063]),
#    ('Hawthorn species', [11, 0.059139784946236562]),
#    ('Washington Hawthorn', [11, 0.059139784946236562]),
#    ('Littleleaf Linden', [11, 0.059139784946236562]),
#    ('Russian-olive', [8, 0.043010752688172046]),
#    ('Thornless Cockspur Hawthorn', [6, 0.032258064516129031]),
#    ('Chokecherry', [5, 0.026881720430107527]),
#    ('Blue Spruce', [5, 0.026881720430107527])]],
#  '57TH CT': [4.0,
#   [('London Planetree', [7, 0.5]),
#    ('Ash', [4, 0.2857142857142857]),
#    ('Flowering Crabapple', [3, 0.21428571428571427])]],
#  '75TH ST': [37.0,
#   [('Austrian Pine', [51, 0.23287671232876711]),
#    ('Ash', [37, 0.16894977168949771]),
#    ('Blue Spruce', [23, 0.1050228310502283]),
#    ('Pinon Pine', [17, 0.077625570776255703]),
#    ('Northern Hackberry', [15, 0.068493150684931503]),
#    ('Common Honeylocust', [10, 0.045662100456621002]),
#    ('Ponderosa Pine', [9, 0.041095890410958902]),
#    ('Cockspur hawthorn', [7, 0.031963470319634701]),
#    ('Flowering Crabapple', [7, 0.031963470319634701]),
#    ('English Oak', [5, 0.022831050228310501])]],
#  '7TH ST': [26.0,
#   [('Silver Maple', [28, 0.092715231788079472]),
#    ('Flowering Crabapple', [27, 0.089403973509933773]),
#    ('Ash', [26, 0.086092715231788075]),
#    ('Siberian Elm', [16, 0.052980132450331126]),
#    ('Blue Spruce', [16, 0.052980132450331126]),
#    ('Northern Hackberry', [16, 0.052980132450331126]),
#    ('Flowering Pear', [14, 0.046357615894039736]),
#    ('Plum species', [12, 0.039735099337748346]),
#    ('Sugar Maple', [11, 0.036423841059602648]),
#    ('Norway Maple', [11, 0.036423841059602648])]],
#  '8TH ST': [38.0,
#   [('Ash', [38, 0.11912225705329153]),
#    ('Silver Maple', [27, 0.084639498432601878]),
#    ('Siberian Elm', [19, 0.059561128526645767]),
#    ('Flowering Crabapple', [17, 0.05329153605015674]),
#    ('Austrian Pine', [14, 0.043887147335423198]),
#    ('Sugar Maple', [13, 0.040752351097178681]),
#    ('Common Honeylocust', [13, 0.040752351097178681]),
#    ('Blue Spruce', [13, 0.040752351097178681]),
#    ('Northern Hackberry', [10, 0.031347962382445138]),
#    ('Northern Red oak', [9, 0.028213166144200628])]],
#  '9TH ST': [245.0,
#   [('Ash', [245, 0.22940074906367042]),
#    ('Willow species', [79, 0.073970037453183521]),
#    ('Flowering Crabapple', [60, 0.056179775280898875]),
#    ('Common Honeylocust', [43, 0.040262172284644196]),
#    ('Boxelder', [43, 0.040262172284644196]),
#    ('Siberian Elm', [38, 0.035580524344569285]),
#    ('Native Cottonwood', [33, 0.030898876404494381]),
#    ('Eastern Redcedar', [30, 0.028089887640449437]),
#    ('Western Catalpa', [29, 0.027153558052434457]),
#    ('Blue Spruce', [29, 0.027153558052434457])]],
#  'ABBEY PL': [2.0,
#   [('Ash', [2, 0.20000000000000001]),
#    ('Native Cottonwood', [2, 0.20000000000000001]),
#    ('Juniper species', [1, 0.10000000000000001]),
#    ('Eastern Redbud', [1, 0.10000000000000001]),
#    ('European Mountainash', [1, 0.10000000000000001]),
#    ('Lodgepole Pine', [1, 0.10000000000000001]),
#    ('Serviceberry species', [1, 0.10000000000000001]),
#    ('Blue Spruce', [1, 0.10000000000000001])]],
#  'AGATE LN': [1.0,
#   [('Shumard Oak', [4, 0.33333333333333331]),
#    ('Siberian Elm', [4, 0.33333333333333331]),
#    ('Flowering Plum', [1, 0.083333333333333329]),
#    ('Ash', [1, 0.083333333333333329]),
#    ('Mugo Pine', [1, 0.083333333333333329]),
#    ('Russian-olive', [1, 0.083333333333333329])]],
#  'AIKINS WY': [2.0,
#   [('Littleleaf Linden', [3, 0.16666666666666666]),
#    ('Ash', [2, 0.1111111111111111]),
#    ('Gambel Oak', [2, 0.1111111111111111]),
#    ('Mugo Pine', [2, 0.1111111111111111]),
#    ('Quaking Aspen', [1, 0.055555555555555552]),
#    ('Eastern Cottonwood', [1, 0.055555555555555552]),
#    ('Flowering Plum', [1, 0.055555555555555552]),
#    ('American Elm', [1, 0.055555555555555552]),
#    ('Siberian Elm', [1, 0.055555555555555552]),
#    ('Plum species', [1, 0.055555555555555552])]],
#  'AIRPORT RD': [3.0,
#   [('Silver Maple', [12, 0.40000000000000002]),
#    ('Siberian Elm', [7, 0.23333333333333334]),
#    ('Eastern Cottonwood', [4, 0.13333333333333333]),
#    ('American Linden', [3, 0.10000000000000001]),
#    ('Ash', [3, 0.10000000000000001]),
#    ('Tree of Heaven', [1, 0.033333333333333333])]],
#  'ALBION WY': [2.0,
#   [('Common Honeylocust', [2, 0.15384615384615385]),
#    ('Flowering Crabapple', [2, 0.15384615384615385]),
#    ('Mugo Pine', [2, 0.15384615384615385]),
#    ('Ash', [2, 0.15384615384615385]),
#    ('Bristlecone Pine', [1, 0.076923076923076927]),
#    ('Quaking Aspen', [1, 0.076923076923076927]),
#    ('Douglas-fir', [1, 0.076923076923076927]),
#    ('Swamp White Oak', [1, 0.076923076923076927]),
#    ('Black Locust', [1, 0.076923076923076927])]],
#  'ALPINE AV': [21.0,
#   [('Ash', [21, 0.14685314685314685]),
#    ('Common Honeylocust', [13, 0.090909090909090912]),
#    ('Siberian Elm', [9, 0.062937062937062943]),
#    ('Silver Maple', [8, 0.055944055944055944]),
#    ('Flowering Crabapple', [8, 0.055944055944055944]),
#    ('Blue Spruce', [7, 0.048951048951048952]),
#    ('Sugar Maple', [7, 0.048951048951048952]),
#    ('Boxelder', [6, 0.04195804195804196]),
#    ('Flowering Pear', [5, 0.034965034965034968]),
#    ('Pinon Pine', [5, 0.034965034965034968])]],
#  'AMBER ST': [1.0,
#   [('Austrian Pine', [1, 0.1111111111111111]),
#    ('Siberian Elm', [1, 0.1111111111111111]),
#    ('Freeman Maple', [1, 0.1111111111111111]),
#    ('Red Maple', [1, 0.1111111111111111]),
#    ('Northern Red oak', [1, 0.1111111111111111]),
#    ('Ash', [1, 0.1111111111111111]),
#    ('Pine species', [1, 0.1111111111111111]),
#    ('Chokecherry', [1, 0.1111111111111111]),
#    ('English Oak', [1, 0.1111111111111111])]],
#  'ARAPAHOE  AV': [122.00000000000001,
#   [('Ash', [122, 0.13232104121475055]),
#    ('Crack Willow', [62, 0.067245119305856832]),
#    ('Boxelder', [53, 0.057483731019522775]),
#    ('Common Honeylocust', [52, 0.056399132321041212]),
#    ('Siberian Elm', [50, 0.054229934924078092]),
#    ('Silver Maple', [45, 0.048806941431670282]),
#    ('Swamp White Oak', [45, 0.048806941431670282]),
#    ('Plains Cottonwood', [39, 0.042299349240780909]),
#    ('Flowering Crabapple', [27, 0.029284164859002169]),
#    ('Norway Maple', [26, 0.028199566160520606])]],
#  'ARAPAHOE AV': [122.0,
#   [('Native Cottonwood', [287, 0.20000000000000001]),
#    ('Blue Spruce', [166, 0.1156794425087108]),
#    ('Austrian Pine', [138, 0.09616724738675958]),
#    ('Ash', [122, 0.085017421602787455]),
#    ('Siberian Elm', [96, 0.066898954703832753]),
#    ('Common Honeylocust', [59, 0.041114982578397213]),
#    ('White Poplar', [58, 0.040418118466898953]),
#    ('Willow species', [54, 0.037630662020905925]),
#    ('White Fir', [38, 0.0264808362369338]),
#    ('Flowering Crabapple', [36, 0.025087108013937282])]],
#  'ARMER AV': [1.0, [('Ash', [1, 1.0])]],
#  'ARNETT ST': [5.0,
#   [('Siberian Elm', [16, 0.2711864406779661]),
#    ('Flowering Crabapple', [5, 0.084745762711864403]),
#    ('Ash', [5, 0.084745762711864403]),
#    ('Staghorn Sumac', [5, 0.084745762711864403]),
#    ('Flowering Pear', [4, 0.067796610169491525]),
#    ('American Linden', [3, 0.050847457627118647]),
#    ('Common Honeylocust', [3, 0.050847457627118647]),
#    ('Boxelder', [3, 0.050847457627118647]),
#    ('Chokecherry', [3, 0.050847457627118647]),
#    ('Western Catalpa', [2, 0.033898305084745763])]],
#  'ASH AV': [5.0,
#   [('Boxelder', [5, 0.1111111111111111]),
#    ('Ash', [5, 0.1111111111111111]),
#    ('Common Honeylocust', [4, 0.088888888888888892]),
#    ('Norway Maple', [3, 0.066666666666666666]),
#    ('Flowering Crabapple', [3, 0.066666666666666666]),
#    ('Austrian Pine', [3, 0.066666666666666666]),
#    ('Ponderosa Pine', [2, 0.044444444444444446]),
#    ('Silver Maple', [2, 0.044444444444444446]),
#    ('Juniper species', [2, 0.044444444444444446]),
#    ('Japanese Pagoda Tree', [2, 0.044444444444444446])]],
#  'ASTOR LN': [1.0, [('Ash', [1, 1.0])]],
#  'AURORA PL': [7.0,
#   [('Ash', [7, 0.69999999999999996]),
#    ('Sugar Maple', [1, 0.10000000000000001]),
#    ('Blue Spruce', [1, 0.10000000000000001]),
#    ('White Oak', [1, 0.10000000000000001])]],
#  'AVACADO RD': [1.0,
#   [('Common Honeylocust', [2, 0.5]),
#    ('Ash', [1, 0.25]),
#    ('Silver Maple', [1, 0.25])]],
#  'AVOCADO RD': [1.0, [('Ash', [1, 0.5]), ('Common Honeylocust', [1, 0.5])]],
#  'BARBADOS PL': [1.0, [('Ash', [1, 0.5]), ('Mugo Pine', [1, 0.5])]],
#  'BASELINE RD': [95.0,
#   [('Ash', [95, 0.1074660633484163]),
#    ('Siberian Elm', [72, 0.081447963800904979]),
#    ('Common Honeylocust', [59, 0.0667420814479638]),
#    ('Blue Spruce', [45, 0.05090497737556561]),
#    ('Flowering Crabapple', [45, 0.05090497737556561]),
#    ('Norway Maple', [37, 0.041855203619909499]),
#    ('Pinon Pine', [32, 0.036199095022624438]),
#    ('Goldenrain Tree', [30, 0.033936651583710405]),
#    ('American Elm', [29, 0.032805429864253395]),
#    ('Russian-olive', [25, 0.02828054298642534])]],
#  'BATES AV': [3.0,
#   [('Ash', [3, 0.59999999999999998]),
#    ('Juniper species', [1, 0.20000000000000001]),
#    ('Rocky Mountain Juniper', [1, 0.20000000000000001])]],
#  'BEAN MOUNTAIN LN': [8.0,
#   [('Ash', [8, 0.47058823529411764]),
#    ('Freeman Maple', [2, 0.11764705882352941]),
#    ('Norway Maple', [2, 0.11764705882352941]),
#    ('Plum species', [1, 0.058823529411764705]),
#    ('Flowering Pear', [1, 0.058823529411764705]),
#    ('Chokecherry', [1, 0.058823529411764705]),
#    ('Flowering Crabapple', [1, 0.058823529411764705]),
#    ('Common Honeylocust', [1, 0.058823529411764705])]],
#  'BEAR MOUNTAIN CT': [2.0,
#   [('Western Catalpa', [2, 0.25]),
#    ('Ash', [2, 0.25]),
#    ('Northern Hackberry', [1, 0.125]),
#    ('Common Honeylocust', [1, 0.125]),
#    ('Quaking Aspen', [1, 0.125]),
#    ('Russian-olive', [1, 0.125])]],
#  'BEAR MOUNTAIN DR': [9.0,
#   [('Flowering Crabapple', [15, 0.22388059701492538]),
#    ('Ash', [9, 0.13432835820895522]),
#    ('Eastern Redbud', [8, 0.11940298507462686]),
#    ('Amur Maple', [6, 0.089552238805970144]),
#    ('Norway Maple', [5, 0.074626865671641784]),
#    ('Common Honeylocust', [5, 0.074626865671641784]),
#    ('Pinon Pine', [4, 0.059701492537313432]),
#    ('Austrian Pine', [4, 0.059701492537313432]),
#    ('Pine species', [4, 0.059701492537313432]),
#    ('American Linden', [3, 0.044776119402985072])]],
#  'BELLEVUE DR': [8.0,
#   [('Ash', [8, 0.12903225806451613]),
#    ('Austrian Pine', [8, 0.12903225806451613]),
#    ('Blue Spruce', [6, 0.096774193548387094]),
#    ('Siberian Elm', [5, 0.080645161290322578]),
#    ('Thornless Cockspur Hawthorn', [5, 0.080645161290322578]),
#    ('Native Cottonwood', [4, 0.064516129032258063]),
#    ('Boxelder', [4, 0.064516129032258063]),
#    ('Common Honeylocust', [3, 0.048387096774193547]),
#    ('Pinon Pine', [3, 0.048387096774193547]),
#    ('Quaking Aspen', [2, 0.032258064516129031])]],
#  'BERKLEY CT': [3.0,
#   [('Hawthorn species', [3, 0.23076923076923078]),
#    ('Ash', [3, 0.23076923076923078]),
#    ('Flowering Crabapple', [2, 0.15384615384615385]),
#    ('Common Honeylocust', [1, 0.076923076923076927]),
#    ('Silver Maple', [1, 0.076923076923076927]),
#    ('Sugar Maple', [1, 0.076923076923076927]),
#    ('Peach', [1, 0.076923076923076927]),
#    ('Austrian Pine', [1, 0.076923076923076927])]],
#  'BLACK HAWK RD': [3.0,
#   [('Rocky Mountain Juniper', [7, 0.20000000000000001]),
#    ('Mugo Pine', [6, 0.17142857142857143]),
#    ('Tree of Heaven', [4, 0.11428571428571428]),
#    ('White Spruce', [3, 0.085714285714285715]),
#    ('Ash', [3, 0.085714285714285715]),
#    ('Quaking Aspen', [2, 0.057142857142857141]),
#    ('Common Honeylocust', [2, 0.057142857142857141]),
#    ('Austrian Pine', [2, 0.057142857142857141]),
#    ('Blue Spruce', [2, 0.057142857142857141]),
#    ('Pine species', [1, 0.028571428571428571])]],
#  'BLUE SAGE CT': [2.0,
#   [('Juniper species', [4, 0.5]),
#    ('Ponderosa Pine', [2, 0.25]),
#    ('Ash', [2, 0.25])]],
#  'BLUEBELL AV': [17.0,
#   [('Ash', [17, 0.096045197740112997]),
#    ('Blue Spruce', [14, 0.07909604519774012]),
#    ('Flowering Crabapple', [12, 0.067796610169491525]),
#    ('Norway Maple', [12, 0.067796610169491525]),
#    ('Plum species', [10, 0.056497175141242938]),
#    ('Quaking Aspen', [9, 0.050847457627118647]),
#    ('Common Honeylocust', [7, 0.03954802259887006]),
#    ('Siberian Elm', [7, 0.03954802259887006]),
#    ('Northern Red oak', [6, 0.033898305084745763]),
#    ('Pinon Pine', [5, 0.028248587570621469])]],
#  'BLUFF ST': [49.0,
#   [('Ash', [49, 0.16723549488054607]),
#    ('Siberian Elm', [35, 0.11945392491467577]),
#    ('Flowering Crabapple', [24, 0.08191126279863481]),
#    ('Common Honeylocust', [17, 0.058020477815699661]),
#    ('Boxelder', [13, 0.044368600682593858]),
#    ('Rocky Mountain Juniper', [12, 0.040955631399317405]),
#    ('Norway Maple', [10, 0.034129692832764506]),
#    ('Staghorn Sumac', [8, 0.027303754266211604]),
#    ('Prairie Crabapple', [7, 0.023890784982935155]),
#    ('Silver Maple', [7, 0.023890784982935155])]],
#  'BRANDON CREEK DR': [2.0,
#   [('Common Honeylocust', [2, 0.22222222222222221]),
#    ('Ash', [2, 0.22222222222222221]),
#    ('American Linden', [1, 0.1111111111111111]),
#    ('Chokecherry', [1, 0.1111111111111111]),
#    ('Black Locust', [1, 0.1111111111111111]),
#    ('Native Cottonwood', [1, 0.1111111111111111]),
#    ('Red Maple', [1, 0.1111111111111111])]],
#  'BRANDYWINE CT': [1.0,
#   [('Northern Hackberry', [3, 0.5]),
#    ('Western Hackberry', [2, 0.33333333333333331]),
#    ('Ash', [1, 0.16666666666666666])]],
#  'BRIARWOOD DR': [10.0,
#   [('Flowering Crabapple', [20, 0.43478260869565216]),
#    ('Ash', [10, 0.21739130434782608]),
#    ('Ponderosa Pine', [4, 0.086956521739130432]),
#    ('Common Honeylocust', [3, 0.065217391304347824]),
#    ('Pinon Pine', [3, 0.065217391304347824]),
#    ('Pine species', [1, 0.021739130434782608]),
#    ('Boxelder', [1, 0.021739130434782608]),
#    ('Austrian Pine', [1, 0.021739130434782608]),
#    ('Quaking Aspen', [1, 0.021739130434782608]),
#    ('Silver Maple', [1, 0.021739130434782608])]],
#  'BROADWAY': [148.0,
#   [('Common Honeylocust', [153, 0.10479452054794521]),
#    ('Ash', [148, 0.10136986301369863]),
#    ('Flowering Crabapple', [91, 0.062328767123287672]),
#    ('American Linden', [68, 0.046575342465753428]),
#    ('Swamp White Oak', [60, 0.041095890410958902]),
#    ('Siberian Elm', [52, 0.035616438356164383]),
#    ('Northern Hackberry', [49, 0.033561643835616439]),
#    ('Native Cottonwood', [47, 0.032191780821917808]),
#    ('Willow species', [43, 0.029452054794520548]),
#    ('Flowering Pear', [41, 0.028082191780821917])]],
#  'BROOKFIELD DR': [3.0,
#   [('Ash', [3, 0.23076923076923078]),
#    ('Littleleaf Linden', [3, 0.23076923076923078]),
#    ('American plum', [2, 0.15384615384615385]),
#    ('Quaking Aspen', [2, 0.15384615384615385]),
#    ('Siberian Elm', [1, 0.076923076923076927]),
#    ('Austrian Pine', [1, 0.076923076923076927]),
#    ('Cottonwood species', [1, 0.076923076923076927])]],
#  'BUCKINGHAM RD': [4.0,
#   [('Common Honeylocust', [5, 0.38461538461538464]),
#    ('Ash', [4, 0.30769230769230771]),
#    ('Northern Red oak', [1, 0.076923076923076927]),
#    ('Austrian Pine', [1, 0.076923076923076927]),
#    ('Freeman Maple', [1, 0.076923076923076927]),
#    ('Amur Maple', [1, 0.076923076923076927])]],
#  'BURR PL': [2.0,
#   [('Mugo Pine', [3, 0.25]),
#    ('Chokecherry', [2, 0.16666666666666666]),
#    ('Ash', [2, 0.16666666666666666]),
#    ('Native Cottonwood', [1, 0.083333333333333329]),
#    ('Tree of Heaven', [1, 0.083333333333333329]),
#    ('Pear species', [1, 0.083333333333333329]),
#    ('Plum species', [1, 0.083333333333333329]),
#    ('Pinon Pine', [1, 0.083333333333333329])]],
#  'BUTTE MILL RD': [21.0,
#   [('Native Cottonwood', [42, 0.28187919463087246]),
#    ('Ash', [21, 0.14093959731543623]),
#    ('White Poplar', [11, 0.073825503355704702]),
#    ('Siberian Elm', [8, 0.053691275167785234]),
#    ('Willow species', [7, 0.046979865771812082]),
#    ('Oak species', [6, 0.040268456375838924]),
#    ('Black Locust', [4, 0.026845637583892617]),
#    ('Boxelder', [4, 0.026845637583892617]),
#    ('Western Catalpa', [3, 0.020134228187919462]),
#    ('English Oak', [3, 0.020134228187919462])]],
#  'CANYON BV': [67.0,
#   [('Native Cottonwood', [71, 0.10056657223796034]),
#    ('Ash', [67, 0.094900849858356937]),
#    ('Common Honeylocust', [67, 0.094900849858356937]),
#    ('Black Locust', [59, 0.083569405099150146]),
#    ('Siberian Elm', [59, 0.083569405099150146]),
#    ('Boxelder', [53, 0.075070821529745049]),
#    ('Willow species', [29, 0.041076487252124649]),
#    ('Swamp White Oak', [20, 0.028328611898016998]),
#    ('Northern Red oak', [17, 0.024079320113314446]),
#    ('Rocky Mountain Juniper', [17, 0.024079320113314446])]],
#  'CASCADE PL': [3.0,
#   [('Siberian Elm', [10, 0.5]),
#    ('Ash', [3, 0.14999999999999999]),
#    ('Flowering Pear', [2, 0.10000000000000001]),
#    ('Catalpa species', [1, 0.050000000000000003]),
#    ('Swamp White Oak', [1, 0.050000000000000003]),
#    ('European Mountainash', [1, 0.050000000000000003]),
#    ('Turkish Filbert', [1, 0.050000000000000003]),
#    ('Black Walnut', [1, 0.050000000000000003])]],
#  'CAYMAN PL': [4.0,
#   [('Ash', [4, 0.66666666666666663]),
#    ('Mugo Pine', [1, 0.16666666666666666]),
#    ('White Spruce', [1, 0.16666666666666666])]],
#  'CEDAR AV': [12.0,
#   [('Blue Spruce', [13, 0.11607142857142858]),
#    ('Ash', [12, 0.10714285714285714]),
#    ('Flowering Crabapple', [8, 0.071428571428571425]),
#    ('White Spruce', [7, 0.0625]),
#    ('Common Honeylocust', [5, 0.044642857142857144]),
#    ('Littleleaf Linden', [5, 0.044642857142857144]),
#    ('Silver Maple', [5, 0.044642857142857144]),
#    ('Accolade Elm', [5, 0.044642857142857144]),
#    ('Serviceberry species', [5, 0.044642857142857144]),
#    ('Plum species', [4, 0.035714285714285712])]],
#  'CENTENNIAL TR': [11.0,
#   [('Ash', [11, 0.2558139534883721]),
#    ('Common Honeylocust', [6, 0.13953488372093023]),
#    ('Littleleaf Linden', [3, 0.069767441860465115]),
#    ('Pinon Pine', [3, 0.069767441860465115]),
#    ('Staghorn Sumac', [3, 0.069767441860465115]),
#    ('Silver Maple', [3, 0.069767441860465115]),
#    ('Bur Oak', [3, 0.069767441860465115]),
#    ('Chokecherry', [2, 0.046511627906976744]),
#    ('Mugo Pine', [2, 0.046511627906976744]),
#    ('Flowering Pear', [2, 0.046511627906976744])]],
#  'CENTER GREEN DR': [5.0,
#   [('Ash', [5, 0.38461538461538464]),
#    ('Flowering Pear', [4, 0.30769230769230771]),
#    ('Flowering Crabapple', [2, 0.15384615384615385]),
#    ('Austrian Pine', [1, 0.076923076923076927]),
#    ('Mugo Pine', [1, 0.076923076923076927])]],
#  'CENTRAL AV': [49.0,
#   [('Ash', [49, 0.51041666666666663]),
#    ('Swamp White Oak', [10, 0.10416666666666667]),
#    ('Common Honeylocust', [8, 0.083333333333333329]),
#    ('Austrian Pine', [8, 0.083333333333333329]),
#    ('Flowering Crabapple', [7, 0.072916666666666671]),
#    ('Ponderosa Pine', [3, 0.03125]),
#    ('Blue Spruce', [3, 0.03125]),
#    ('Northern Hackberry', [3, 0.03125]),
#    ('Flowering Pear', [2, 0.020833333333333332]),
#    ('Plains Cottonwood', [2, 0.020833333333333332])]],
#  'CHAMBERS DR': [9.0,
#   [('Ash', [9, 0.25]),
#    ('Norway Maple', [4, 0.1111111111111111]),
#    ('Flowering Crabapple', [4, 0.1111111111111111]),
#    ('Russian-olive', [3, 0.083333333333333329]),
#    ('Common Honeylocust', [2, 0.055555555555555552]),
#    ('Austrian Pine', [2, 0.055555555555555552]),
#    ('Ussurian Pear', [2, 0.055555555555555552]),
#    ('Tree of Heaven', [1, 0.027777777777777776]),
#    ('Juniper species', [1, 0.027777777777777776]),
#    ('Plum species', [1, 0.027777777777777776])]],
#  'CHAUTAUQUA': [18.0, [('Ash', [18, 1.0])]],
#  'CHERRYVALE RD': [3.0,
#   [('Eastern Cottonwood', [13, 0.52000000000000002]),
#    ('Siberian Elm', [4, 0.16]),
#    ('Native Cottonwood', [3, 0.12]),
#    ('Ash', [3, 0.12]),
#    ('Willow species', [1, 0.040000000000000001]),
#    ('Blue Spruce', [1, 0.040000000000000001])]],
#  'CHINLE AV': [1.0, [('Littleleaf Linden', [1, 0.5]), ('Ash', [1, 0.5])]],
#  'CIMMARON WY': [2.0,
#   [('Ash', [2, 0.20000000000000001]),
#    ('Norway Spruce', [1, 0.10000000000000001]),
#    ('European Beech', [1, 0.10000000000000001]),
#    ('Quaking Aspen', [1, 0.10000000000000001]),
#    ('Pin Oak', [1, 0.10000000000000001]),
#    ('Fruiting Pear', [1, 0.10000000000000001]),
#    ('Peach', [1, 0.10000000000000001]),
#    ('Fruiting Plum', [1, 0.10000000000000001]),
#    ('Apple species', [1, 0.10000000000000001])]],
#  'CLEMATIS DR': [3.0, [('Ash', [3, 1.0])]],
#  'CLOUD CT': [6.0,
#   [('Ash', [6, 0.42857142857142855]),
#    ('Flowering Pear', [3, 0.21428571428571427]),
#    ('Thornless Cockspur Hawthorn', [2, 0.14285714285714285]),
#    ('Western Catalpa', [2, 0.14285714285714285]),
#    ('Flowering Crabapple', [1, 0.071428571428571425])]],
#  'CLOVERLEAF DR': [7.0,
#   [('Flowering Crabapple', [11, 0.24444444444444444]),
#    ('Ash', [7, 0.15555555555555556]),
#    ('Austrian Pine', [6, 0.13333333333333333]),
#    ('American Linden', [3, 0.066666666666666666]),
#    ('Juniper species', [3, 0.066666666666666666]),
#    ('White Fir', [3, 0.066666666666666666]),
#    ('Common Honeylocust', [3, 0.066666666666666666]),
#    ('Giant Sequoia', [2, 0.044444444444444446]),
#    ('Swamp White Oak', [2, 0.044444444444444446]),
#    ('Scotch Pine', [1, 0.022222222222222223])]],
#  'COLLEGE AV': [26.0,
#   [('Ash', [26, 0.12206572769953052]),
#    ('Rocky Mountain Juniper', [22, 0.10328638497652583]),
#    ('Siberian Elm', [20, 0.093896713615023469]),
#    ('Flowering Crabapple', [19, 0.089201877934272297]),
#    ('Blue Spruce', [16, 0.075117370892018781]),
#    ('Common Honeylocust', [12, 0.056338028169014086]),
#    ('Austrian Pine', [11, 0.051643192488262914]),
#    ('Silver Maple', [9, 0.042253521126760563]),
#    ('Ponderosa Pine', [9, 0.042253521126760563]),
#    ('Pinon Pine', [6, 0.028169014084507043])]],
#  'COLLEGE PL': [3.0,
#   [('Ash', [3, 0.27272727272727271]),
#    ('Littleleaf Linden', [3, 0.27272727272727271]),
#    ('Norway Maple', [1, 0.090909090909090912]),
#    ('Flowering Crabapple', [1, 0.090909090909090912]),
#    ('Blue Spruce', [1, 0.090909090909090912]),
#    ('Quaking Aspen', [1, 0.090909090909090912]),
#    ('Bristlecone Pine', [1, 0.090909090909090912])]],
#  'COLORADO AV': [15.0,
#   [('Ash', [15, 0.22388059701492538]),
#    ('Siberian Elm', [9, 0.13432835820895522]),
#    ('Swamp White Oak', [7, 0.1044776119402985]),
#    ('Lodgepole Pine', [5, 0.074626865671641784]),
#    ('Freeman Maple', [5, 0.074626865671641784]),
#    ('Red Maple', [3, 0.044776119402985072]),
#    ('Northern Hackberry', [3, 0.044776119402985072]),
#    (nan, [3, 0.044776119402985072]),
#    ('Amur Maple', [2, 0.029850746268656716]),
#    ('Native Cottonwood', [1, 0.014925373134328358])]],
#  'COMANCHE DR': [1.0,
#   [('Flowering Pear', [2, 0.33333333333333331]),
#    ('Mugo Pine', [1, 0.16666666666666666]),
#    ('Flowering Crabapple', [1, 0.16666666666666666]),
#    ('Northern Whitecedar', [1, 0.16666666666666666]),
#    ('Ash', [1, 0.16666666666666666])]],
#  'COMMERCE ST': [13.0,
#   [('Flowering Pear', [23, 0.47916666666666669]),
#    ('Ash', [13, 0.27083333333333331]),
#    ('Common Honeylocust', [4, 0.083333333333333329]),
#    ('Plains Cottonwood', [3, 0.0625]),
#    ('Northern Hackberry', [2, 0.041666666666666664]),
#    ('Silver Maple', [1, 0.020833333333333332]),
#    ('Freeman Maple', [1, 0.020833333333333332]),
#    ('Siberian Elm', [1, 0.020833333333333332])]],
#  'CONCORD AV': [9.0,
#   [('Silver Maple', [15, 0.14018691588785046]),
#    ('Norway Maple', [13, 0.12149532710280374]),
#    ('Ash', [9, 0.084112149532710276]),
#    ('Native Cottonwood', [9, 0.084112149532710276]),
#    ('Common Honeylocust', [8, 0.07476635514018691]),
#    ('Blue Spruce', [5, 0.046728971962616821]),
#    ('American Linden', [5, 0.046728971962616821]),
#    ('Sugar Maple', [5, 0.046728971962616821]),
#    ('Amur Maple', [5, 0.046728971962616821]),
#    ('Northern Hackberry', [4, 0.037383177570093455])]],
#  'CONESTOGA CT': [3.0, [('Ash', [3, 1.0])]],
#  'CORDRY CT': [4.0,
#   [('Siberian Elm', [8, 0.21052631578947367]),
#    ('Crack Willow', [7, 0.18421052631578946]),
#    ('Ash', [4, 0.10526315789473684]),
#    ('Boxelder', [3, 0.078947368421052627]),
#    ('Peachleaf Willow', [3, 0.078947368421052627]),
#    ('Plains Cottonwood', [3, 0.078947368421052627]),
#    ('Black Locust', [2, 0.052631578947368418]),
#    ('Western Catalpa', [1, 0.026315789473684209]),
#    ('Tree of Heaven', [1, 0.026315789473684209]),
#    ('Lodgepole Pine', [1, 0.026315789473684209])]],
#  'CORONA TR': [1.0,
#   [('Pinon Pine', [4, 0.5714285714285714]),
#    ('Flowering Crabapple', [2, 0.2857142857142857]),
#    ('Ash', [1, 0.14285714285714285])]],
#  'CORRIENTE DR': [6.0,
#   [('Ash', [6, 0.13636363636363635]),
#    ('Native Cottonwood', [6, 0.13636363636363635]),
#    ('Kentucky Coffeetree', [5, 0.11363636363636363]),
#    ('Western Catalpa', [5, 0.11363636363636363]),
#    ('Flowering Crabapple', [5, 0.11363636363636363]),
#    ('Blue Spruce', [3, 0.068181818181818177]),
#    ('Hybrid Cottonwood', [3, 0.068181818181818177]),
#    ('Russian-olive', [3, 0.068181818181818177]),
#    ('Bur Oak', [3, 0.068181818181818177]),
#    ('Northern Hackberry', [2, 0.045454545454545456])]],
#  'CRIPPLE CREEK SQ': [1.0,
#   [('Serviceberry species', [4, 0.5]),
#    ('Common Honeylocust', [2, 0.25]),
#    ('Ash', [1, 0.125]),
#    ('Pinon Pine', [1, 0.125])]],
#  'CRIPPLE CREEK TR': [3.0,
#   [('Common Honeylocust', [4, 0.5]),
#    ('Ash', [3, 0.375]),
#    ('Chokecherry', [1, 0.125])]],
#  'DAKOTA BV': [33.0,
#   [('Flowering Crabapple', [35, 0.13358778625954199]),
#    ('Ash', [33, 0.12595419847328243]),
#    ('Northern Hackberry', [19, 0.072519083969465645]),
#    ('Pinon Pine', [18, 0.068702290076335881]),
#    ('Flowering Pear', [17, 0.064885496183206104]),
#    ('Bur Oak', [16, 0.061068702290076333]),
#    ('Western Catalpa', [14, 0.053435114503816793]),
#    ('Kentucky Coffeetree', [14, 0.053435114503816793]),
#    ('American Linden', [12, 0.045801526717557252]),
#    ('Common Honeylocust', [11, 0.041984732824427481])]],
#  'DAKOTA PL': [1.0,
#   [('White Fir', [3, 0.33333333333333331]),
#    ('Chokecherry', [1, 0.1111111111111111]),
#    ('Common Honeylocust', [1, 0.1111111111111111]),
#    ('Freeman Maple', [1, 0.1111111111111111]),
#    ('Ash', [1, 0.1111111111111111]),
#    ('Willow species', [1, 0.1111111111111111]),
#    ('Peach', [1, 0.1111111111111111])]],
#  'DALLAS PL': [2.0,
#   [('Blue Spruce', [3, 0.27272727272727271]),
#    ('Ash', [2, 0.18181818181818182]),
#    ('Pinon Pine', [2, 0.18181818181818182]),
#    ('Russian-olive', [1, 0.090909090909090912]),
#    ('Chokecherry', [1, 0.090909090909090912]),
#    ('Austrian Pine', [1, 0.090909090909090912]),
#    ('White Spruce', [1, 0.090909090909090912])]],
#  'DEER VALLEY RD': [3.0,
#   [('Ponderosa Pine', [9, 0.34615384615384615]),
#    ('Russian-olive', [5, 0.19230769230769232]),
#    ('Ash', [3, 0.11538461538461539]),
#    ('Juniper species', [2, 0.076923076923076927]),
#    ('Austrian Pine', [2, 0.076923076923076927]),
#    ('Pinon Pine', [2, 0.076923076923076927]),
#    ('Common Honeylocust', [1, 0.038461538461538464]),
#    ('Flowering Crabapple', [1, 0.038461538461538464]),
#    ('Russian Hawthorn', [1, 0.038461538461538464])]],
#  'DEL ROSA CT': [1.0,
#   [('Siberian Elm', [2, 0.40000000000000002]),
#    ('Black Walnut', [1, 0.20000000000000001]),
#    ('Swamp White Oak', [1, 0.20000000000000001]),
#    ('Ash', [1, 0.20000000000000001])]],
#  'DIAGONAL HY': [10.0,
#   [('Ash', [10, 0.41666666666666669]),
#    ('Siberian Elm', [5, 0.20833333333333334]),
#    ('Native Cottonwood', [4, 0.16666666666666666]),
#    ('American Elm', [2, 0.083333333333333329]),
#    ('Russian-olive', [1, 0.041666666666666664]),
#    ('Common Honeylocust', [1, 0.041666666666666664]),
#    ('Silver Maple', [1, 0.041666666666666664])]],
#  'DOVER DR': [2.0,
#   [('Ash', [2, 0.16666666666666666]),
#    ('Siberian Elm', [2, 0.16666666666666666]),
#    ('Quaking Aspen', [1, 0.083333333333333329]),
#    ('Pin Oak', [1, 0.083333333333333329]),
#    ('Flowering Crabapple', [1, 0.083333333333333329]),
#    ('Eastern Redbud', [1, 0.083333333333333329]),
#    ('Poplar species', [1, 0.083333333333333329]),
#    ('Juniper species', [1, 0.083333333333333329]),
#    ('Pinon Pine', [1, 0.083333333333333329]),
#    ('Boxelder', [1, 0.083333333333333329])]],
#  'DREW RANCH LN': [1.0,
#   [('Plum species', [2, 0.20000000000000001]),
#    ('Norway Maple', [2, 0.20000000000000001]),
#    ('Littleleaf Linden', [1, 0.10000000000000001]),
#    ('Flowering Crabapple', [1, 0.10000000000000001]),
#    ('Thornless Cockspur Hawthorn', [1, 0.10000000000000001]),
#    ('Freeman Maple', [1, 0.10000000000000001]),
#    ('Flowering Pear', [1, 0.10000000000000001]),
#    ('Ash', [1, 0.10000000000000001])]],
#  'E AURORA AV': [10.0,
#   [('Common Honeylocust', [12, 0.11428571428571428]),
#    ('Native Cottonwood', [11, 0.10476190476190476]),
#    ('Northern Hackberry', [10, 0.095238095238095233]),
#    ('Ash', [10, 0.095238095238095233]),
#    ('Crack Willow', [8, 0.076190476190476197]),
#    ('Bur Oak', [6, 0.057142857142857141]),
#    ('Flowering Crabapple', [6, 0.057142857142857141]),
#    ('Plains Cottonwood', [6, 0.057142857142857141]),
#    ('Kentucky Coffeetree', [4, 0.038095238095238099]),
#    ('Austrian Pine', [3, 0.028571428571428571])]],
#  'EAGLE WY': [6.0,
#   [('Ash', [6, 0.5]),
#    ('Littleleaf Linden', [4, 0.33333333333333331]),
#    ('Norway Maple', [1, 0.083333333333333329]),
#    ('Common Honeylocust', [1, 0.083333333333333329])]],
#  'EDGEWOOD DR': [2.0,
#   [('Siberian Elm', [3, 0.25]),
#    ('Eastern Redcedar', [2, 0.16666666666666666]),
#    ('Ash', [2, 0.16666666666666666]),
#    ('Engelmann Spruce', [1, 0.083333333333333329]),
#    ('Juniper species', [1, 0.083333333333333329]),
#    ('Russian-olive', [1, 0.083333333333333329]),
#    ('Quaking Aspen', [1, 0.083333333333333329]),
#    ('Flowering Crabapple', [1, 0.083333333333333329])]],
#  'EDISON AV': [3.0,
#   [('Ash', [3, 0.375]),
#    ('Western Catalpa', [2, 0.25]),
#    ('Siberian Elm', [1, 0.125]),
#    ('Black Walnut', [1, 0.125]),
#    ('Kentucky Coffeetree', [1, 0.125])]],
#  'EDISON CT': [1.0,
#   [('Austrian Pine', [3, 0.59999999999999998]),
#    ('Pinon Pine', [1, 0.20000000000000001]),
#    ('Ash', [1, 0.20000000000000001])]],
#  'ELLSWORTH PL': [1.0, [('Chinkapin Oak', [1, 0.5]), ('Ash', [1, 0.5])]],
#  'ERIE DR': [1.0,
#   [('Juniper species', [3, 0.375]),
#    ('Mugo Pine', [2, 0.25]),
#    ('Pine species', [1, 0.125]),
#    ('Eastern Redbud', [1, 0.125]),
#    ('Ash', [1, 0.125])]],
#  'EUCLID PL': [2.0,
#   [('Ash', [2, 0.25]),
#    ('Sugar Maple', [2, 0.25]),
#    ('Goldenrain Tree', [2, 0.25]),
#    ('Japanese Pagoda Tree', [1, 0.125]),
#    ('Japanese Tree Lilac', [1, 0.125])]],
#  'FAIR PL': [2.0,
#   [('Ash', [2, 0.66666666666666663]),
#    ('Douglas-fir', [1, 0.33333333333333331])]],
#  'FAIRWAY CT': [8.0,
#   [('Ash', [8, 0.53333333333333333]),
#    ('Common Honeylocust', [4, 0.26666666666666666]),
#    ('Sugar Maple', [1, 0.066666666666666666]),
#    ('Poplar species', [1, 0.066666666666666666]),
#    ('Bur Oak', [1, 0.066666666666666666])]],
#  'FERN PL': [1.0,
#   [('Siberian Elm', [3, 0.42857142857142855]),
#    ('Pinon Pine', [1, 0.14285714285714285]),
#    ('Arborivitae species', [1, 0.14285714285714285]),
#    ('Flowering Crabapple', [1, 0.14285714285714285]),
#    ('Ash', [1, 0.14285714285714285])]],
#  'FLATIRON PY': [26.0,
#   [('Ash', [26, 0.63414634146341464]),
#    ('Pin Oak', [8, 0.1951219512195122]),
#    ('Littleleaf Linden', [4, 0.097560975609756101]),
#    ('Red Maple', [2, 0.04878048780487805]),
#    ('Common Honeylocust', [1, 0.024390243902439025])]],
#  'FLORAL DR': [7.0,
#   [('Siberian Elm', [11, 0.28205128205128205]),
#    ('Ash', [7, 0.17948717948717949]),
#    ('Boxelder', [6, 0.15384615384615385]),
#    ('Blue Spruce', [3, 0.076923076923076927]),
#    ('Western Catalpa', [2, 0.05128205128205128]),
#    ('Turkish Filbert', [1, 0.02564102564102564]),
#    ('Russian-olive', [1, 0.02564102564102564]),
#    ('Flowering Pear', [1, 0.02564102564102564]),
#    ('Austrian Pine', [1, 0.02564102564102564]),
#    ('Silver Maple', [1, 0.02564102564102564])]],
#  'FOLSOM ST': [27.0,
#   [('Ash', [27, 0.26213592233009708]),
#    ('Siberian Elm', [19, 0.18446601941747573]),
#    ('Common Honeylocust', [10, 0.097087378640776698]),
#    ('Flowering Crabapple', [8, 0.077669902912621352]),
#    ('American Linden', [8, 0.077669902912621352]),
#    ('Western Catalpa', [4, 0.038834951456310676]),
#    ('Northern Hackberry', [3, 0.029126213592233011]),
#    ('American Elm', [2, 0.019417475728155338]),
#    ('Pinon Pine', [2, 0.019417475728155338]),
#    ('Silver Maple', [2, 0.019417475728155338])]],
#  'FOXTAIL CT': [6.0,
#   [('Common Honeylocust', [10, 0.19607843137254902]),
#    ('Blue Spruce', [7, 0.13725490196078433]),
#    ('Juniper species', [7, 0.13725490196078433]),
#    ('Ash', [6, 0.11764705882352941]),
#    ('Russian-olive', [6, 0.11764705882352941]),
#    ('Silver Maple', [3, 0.058823529411764705]),
#    ('Flowering Crabapple', [2, 0.039215686274509803]),
#    ('Austrian Pine', [2, 0.039215686274509803]),
#    ('Boxelder', [2, 0.039215686274509803]),
#    ('Chokecherry', [1, 0.019607843137254902])]],
#  'FRANKLIN DR': [33.0,
#   [('Ash', [33, 0.30555555555555558]),
#    ('Common Honeylocust', [22, 0.20370370370370369]),
#    ('Red Tatarian Maple', [8, 0.07407407407407407]),
#    ('Kentucky Coffeetree', [6, 0.055555555555555552]),
#    ('Sugar Maple', [5, 0.046296296296296294]),
#    ('Swamp White Oak', [4, 0.037037037037037035]),
#    ('Upright English Oak', [4, 0.037037037037037035]),
#    ('English Oak', [3, 0.027777777777777776]),
#    ('Western Catalpa', [2, 0.018518518518518517]),
#    ('Red Maple', [2, 0.018518518518518517])]],
#  'FREMONT AV': [1.0,
#   [('Mugo Pine', [1, 0.20000000000000001]),
#    ('Austrian Pine', [1, 0.20000000000000001]),
#    ('Blue Spruce', [1, 0.20000000000000001]),
#    ('Ash', [1, 0.20000000000000001]),
#    ('Siberian Elm', [1, 0.20000000000000001])]],
#  'FULTON CR': [3.0,
#   [('Siberian Elm', [8, 0.5714285714285714]),
#    ('Ash', [3, 0.21428571428571427]),
#    ('Russian-olive', [1, 0.071428571428571425]),
#    ('Boxelder', [1, 0.071428571428571425]),
#    ('Black Locust', [1, 0.071428571428571425])]],
#  'FURMAN WY': [3.0,
#   [('Ash', [3, 0.375]),
#    ('Western Catalpa', [1, 0.125]),
#    ('Littleleaf Linden', [1, 0.125]),
#    ('Flowering Pear', [1, 0.125]),
#    ('Flowering Crabapple', [1, 0.125]),
#    ('Swamp White Oak', [1, 0.125])]],
#  'GALENA WY': [8.0,
#   [('Ash', [8, 0.33333333333333331]),
#    ('Northern Hackberry', [5, 0.20833333333333334]),
#    ('Ponderosa Pine', [4, 0.16666666666666666]),
#    ('White Spruce', [3, 0.125]),
#    ('Common Honeylocust', [2, 0.083333333333333329]),
#    ('Quaking Aspen', [1, 0.041666666666666664]),
#    ('Austrian Pine', [1, 0.041666666666666664])]],
#  'GAPTOR RD': [15.000000000000002,
#   [('Eastern Cottonwood', [37, 0.21764705882352942]),
#    ('Siberian Elm', [24, 0.14117647058823529]),
#    ('Ash', [15, 0.088235294117647065]),
#    ('Apple species', [15, 0.088235294117647065]),
#    ('Spruce species', [15, 0.088235294117647065]),
#    ('Willow species', [13, 0.076470588235294124]),
#    ('Ponderosa Pine', [12, 0.070588235294117646]),
#    ('Boxelder', [6, 0.035294117647058823]),
#    ('Limber Pine', [4, 0.023529411764705882]),
#    ('Autumn Blaze Maple', [3, 0.017647058823529412])]],
#  'GARNET LN': [5.0,
#   [('Siberian Elm', [39, 0.8666666666666667]),
#    ('Ash', [5, 0.1111111111111111]),
#    ('Plum species', [1, 0.022222222222222223])]],
#  'GENESEE CT': [3.0,
#   [('Austrian Pine', [3, 0.23076923076923078]),
#    ('Ash', [3, 0.23076923076923078]),
#    ('Blue Spruce', [3, 0.23076923076923078]),
#    ('Autumn Blaze Maple', [1, 0.076923076923076927]),
#    ('Boxelder', [1, 0.076923076923076927]),
#    ('Common Honeylocust', [1, 0.076923076923076927]),
#    ('Russian-olive', [1, 0.076923076923076927])]],
#  'GIBBS AV': [20.0,
#   [('Ash', [20, 0.42553191489361702]),
#    ('Common Honeylocust', [11, 0.23404255319148937]),
#    ('Flowering Pear', [2, 0.042553191489361701]),
#    ('Kentucky Coffeetree', [2, 0.042553191489361701]),
#    ('Sugar Maple', [2, 0.042553191489361701]),
#    ('Freeman Maple', [1, 0.021276595744680851]),
#    ('Silver Maple', [1, 0.021276595744680851]),
#    ('Northern Red oak', [1, 0.021276595744680851]),
#    ('Red Maple', [1, 0.021276595744680851]),
#    ('Yellow Buckeye', [1, 0.021276595744680851])]],
#  'GILPIN DR': [1.0,
#   [('Siberian Elm', [4, 0.5]),
#    ('Quaking Aspen', [1, 0.125]),
#    ('Norway Maple', [1, 0.125]),
#    ('Ash', [1, 0.125]),
#    ('Silver Maple', [1, 0.125])]],
#  'GLENDALE GULCH CR': [12.0,
#   [('Ash', [12, 0.30769230769230771]),
#    ('Willow species', [8, 0.20512820512820512]),
#    ('Austrian Pine', [7, 0.17948717948717949]),
#    ('Littleleaf Linden', [5, 0.12820512820512819]),
#    ('Common Honeylocust', [3, 0.076923076923076927]),
#    ('Native Cottonwood', [3, 0.076923076923076927]),
#    ('Quaking Aspen', [1, 0.02564102564102564])]],
#  'GLENWOOD DR': [19.0,
#   [('Ash', [19, 0.16379310344827586]),
#    ('Common Honeylocust', [13, 0.11206896551724138]),
#    ('Silver Maple', [12, 0.10344827586206896]),
#    ('Littleleaf Linden', [10, 0.086206896551724144]),
#    ('Flowering Crabapple', [7, 0.060344827586206899]),
#    ('American Linden', [6, 0.051724137931034482]),
#    ('Blue Spruce', [5, 0.043103448275862072]),
#    ('Juniper species', [5, 0.043103448275862072]),
#    ('English Oak', [5, 0.043103448275862072]),
#    ('Plum species', [4, 0.034482758620689655])]],
#  'GODDARD PL': [2.0,
#   [('Flowering Crabapple', [3, 0.29999999999999999]),
#    ('American Linden', [2, 0.20000000000000001]),
#    ('Ash', [2, 0.20000000000000001]),
# ...
#    ('Ash', [17, 0.36170212765957449]),
#    ('Quaking Aspen', [1, 0.021276595744680851]),
#    ('Freeman Maple', [1, 0.021276595744680851]),
#    ('Austrian Pine', [1, 0.021276595744680851]),
#    ('Chokecherry', [1, 0.021276595744680851]),
#    ('Crape Myrtle', [1, 0.021276595744680851])]],
#  'STEPHENS RD': [4.0,
#   [('Ash', [4, 0.21052631578947367]),
#    ('Flowering Crabapple', [4, 0.21052631578947367]),
#    ('Blue Spruce', [2, 0.10526315789473684]),
#    ('Common Honeylocust', [2, 0.10526315789473684]),
#    ('Littleleaf Linden', [1, 0.052631578947368418]),
#    ('Flowering Pear', [1, 0.052631578947368418]),
#    ('American Linden', [1, 0.052631578947368418]),
#    ('Siberian Elm', [1, 0.052631578947368418]),
#    ('Silver Maple', [1, 0.052631578947368418]),
#    ('Black Walnut', [1, 0.052631578947368418])]],
#  'STERLING CR E': [4.0,
#   [('Common Honeylocust', [4, 0.36363636363636365]),
#    ('Ash', [4, 0.36363636363636365]),
#    ('Freeman Maple', [2, 0.18181818181818182]),
#    ('Siberian Elm', [1, 0.090909090909090912])]],
#  'STERLING CR W': [14.0,
#   [('Ash', [14, 0.4375]),
#    ('Swamp White Oak', [6, 0.1875]),
#    ('Littleleaf Linden', [5, 0.15625]),
#    ('Bur Oak', [2, 0.0625]),
#    ('Red Maple', [2, 0.0625]),
#    ('Boxelder', [1, 0.03125]),
#    ('Mugo Pine', [1, 0.03125]),
#    ('Flowering Crabapple', [1, 0.03125])]],
#  'STERLING CT': [5.0,
#   [('Ash', [5, 0.83333333333333337]),
#    ('Native Cottonwood', [1, 0.16666666666666666])]],
#  'STERLING DR': [11.0,
#   [('Ash', [11, 0.29729729729729731]),
#    ('Common Honeylocust', [9, 0.24324324324324326]),
#    ('Thornless Cockspur Hawthorn', [7, 0.1891891891891892]),
#    ('Russian-olive', [2, 0.054054054054054057]),
#    ('Freeman Maple', [2, 0.054054054054054057]),
#    ('Norway Maple', [2, 0.054054054054054057]),
#    (nan, [1, 0.027027027027027029]),
#    ('Littleleaf Linden', [1, 0.027027027027027029]),
#    ('Scotch Pine', [1, 0.027027027027027029]),
#    ('Siberian Elm', [1, 0.027027027027027029])]],
#  'STONEWALL PL': [3.0,
#   [('Ash', [3, 0.29999999999999999]),
#    ('Willow species', [2, 0.20000000000000001]),
#    ('Turkish Filbert', [1, 0.10000000000000001]),
#    ('Hackberry species', [1, 0.10000000000000001]),
#    ('English Oak', [1, 0.10000000000000001]),
#    ('Littleleaf Linden', [1, 0.10000000000000001]),
#    ('Austrian Pine', [1, 0.10000000000000001])]],
#  'STREAMSIDE LN': [12.0,
#   [('Boxelder', [14, 0.25]),
#    ('Ash', [12, 0.21428571428571427]),
#    ('Willow species', [12, 0.21428571428571427]),
#    ('Common Honeylocust', [4, 0.071428571428571425]),
#    ('Flowering Pear', [2, 0.035714285714285712]),
#    ('Native Cottonwood', [2, 0.035714285714285712]),
#    ('Elm species', [2, 0.035714285714285712]),
#    ('Siberian Elm', [2, 0.035714285714285712]),
#    ('Black Locust', [2, 0.035714285714285712]),
#    ('Kwanzan Cherry', [1, 0.017857142857142856])]],
#  'SUNDOWN LN': [5.9999999999999991,
#   [('Black Locust', [8, 0.1702127659574468]),
#    ('Blue Spruce', [6, 0.1276595744680851]),
#    ('Ash', [6, 0.1276595744680851]),
#    ('Ponderosa Pine', [6, 0.1276595744680851]),
#    ('American Linden', [5, 0.10638297872340426]),
#    ('Austrian Pine', [4, 0.085106382978723402]),
#    ('Hawthorn species', [3, 0.063829787234042548]),
#    ('Eastern Redcedar', [2, 0.042553191489361701]),
#    ('Boxelder', [2, 0.042553191489361701]),
#    ('Magnolia species', [1, 0.021276595744680851])]],
#  'TABLE MESA CT': [9.0,
#   [('Ash', [9, 0.47368421052631576]),
#    ('Blue Spruce', [3, 0.15789473684210525]),
#    ('Pinon Pine', [2, 0.10526315789473684]),
#    ('Plains Cottonwood', [1, 0.052631578947368418]),
#    ('Austrian Pine', [1, 0.052631578947368418]),
#    ('Chokecherry', [1, 0.052631578947368418]),
#    ('Goldenrain Tree', [1, 0.052631578947368418]),
#    ('Mugo Pine', [1, 0.052631578947368418])]],
#  'TABLE MESA DR': [31.0,
#   [('Ash', [31, 0.16145833333333334]),
#    ('Common Honeylocust', [21, 0.109375]),
#    ('Flowering Crabapple', [16, 0.083333333333333329]),
#    ('Flowering Pear', [14, 0.072916666666666671]),
#    ('Swamp White Oak', [10, 0.052083333333333336]),
#    ('Blue Spruce', [8, 0.041666666666666664]),
#    ('Tatarian Maple', [8, 0.041666666666666664]),
#    ('Siberian Elm', [7, 0.036458333333333336]),
#    ('Native Cottonwood', [7, 0.036458333333333336]),
#    ('Common Hawthorn', [6, 0.03125])]],
#  'TABLE TOP CT': [6.0,
#   [('Ash', [6, 0.5]),
#    ('Common Honeylocust', [2, 0.16666666666666666]),
#    ('Norway Maple', [1, 0.083333333333333329]),
#    ('Western Catalpa', [1, 0.083333333333333329]),
#    ('Juniper species', [1, 0.083333333333333329]),
#    ('Smoke Tree', [1, 0.083333333333333329])]],
#  'TABRIZ PL': [3.0, [('Ash', [3, 0.75]), ('Norway Maple', [1, 0.25])]],
#  'TANTRA DR': [4.0,
#   [('Littleleaf Linden', [7, 0.22580645161290322]),
#    ('Common Honeylocust', [5, 0.16129032258064516]),
#    ('Ash', [4, 0.12903225806451613]),
#    ('Southwestern White Pine', [3, 0.096774193548387094]),
#    ('Juniper species', [2, 0.064516129032258063]),
#    ('Rocky Mountain Juniper', [2, 0.064516129032258063]),
#    ('Norway Maple', [1, 0.032258064516129031]),
#    ('Western Catalpa', [1, 0.032258064516129031]),
#    ('Flowering Crabapple', [1, 0.032258064516129031]),
#    ('Peachleaf Willow', [1, 0.032258064516129031])]],
#  'TANTRA PARK CR': [27.0,
#   [('Ash', [27, 0.11297071129707113]),
#    ('Austrian Pine', [25, 0.10460251046025104]),
#    ('Blue Spruce', [24, 0.100418410041841]),
#    ('Common Honeylocust', [23, 0.096234309623430964]),
#    ('Plains Cottonwood', [19, 0.079497907949790794]),
#    ('Hawthorn species', [15, 0.062761506276150625]),
#    ('Pinon Pine', [13, 0.054393305439330547]),
#    ('Crack Willow', [11, 0.046025104602510462]),
#    ('Flowering Crabapple', [8, 0.033472803347280332]),
#    ('Ponderosa Pine', [8, 0.033472803347280332])]],
#  'TELLURIDE CR': [4.0,
#   [('Ash', [4, 0.33333333333333331]),
#    ('Austrian Pine', [3, 0.25]),
#    ('Gambel Oak', [2, 0.16666666666666666]),
#    ('Flowering Crabapple', [2, 0.16666666666666666]),
#    ('Common Honeylocust', [1, 0.083333333333333329])]],
#  'TELLURIDE PL': [3.0,
#   [('Ash', [3, 0.27272727272727271]),
#    ('Flowering Crabapple', [2, 0.18181818181818182]),
#    ('Juniper species', [1, 0.090909090909090912]),
#    ('White Spruce', [1, 0.090909090909090912]),
#    ('Ponderosa Pine', [1, 0.090909090909090912]),
#    ('Littleleaf Linden', [1, 0.090909090909090912]),
#    ('Quaking Aspen', [1, 0.090909090909090912]),
#    ('Sumac species', [1, 0.090909090909090912])]],
#  'TESLA CIR': [3.0,
#   [('Amur Maple', [5, 0.35714285714285715]),
#    ('Ash', [3, 0.21428571428571427]),
#    ('Common Honeylocust', [2, 0.14285714285714285]),
#    ('Upright English Oak', [1, 0.071428571428571425]),
#    ('Freeman Maple', [1, 0.071428571428571425]),
#    ('Blue Spruce', [1, 0.071428571428571425]),
#    ('Silver Maple', [1, 0.071428571428571425])]],
#  'THUNDERBIRD CT E': [10.0,
#   [('Ash', [10, 0.66666666666666663]),
#    ('Flowering Crabapple', [2, 0.13333333333333333]),
#    ('Pinon Pine', [1, 0.066666666666666666]),
#    ('Ponderosa Pine', [1, 0.066666666666666666]),
#    ('Common Honeylocust', [1, 0.066666666666666666])]],
#  'TINCUP CR': [3.0,
#   [('Ash', [3, 0.33333333333333331]),
#    ('Norway Maple', [2, 0.22222222222222221]),
#    ('Ponderosa Pine', [1, 0.1111111111111111]),
#    ('Pine species', [1, 0.1111111111111111]),
#    ('Native Cottonwood', [1, 0.1111111111111111]),
#    ('Hawthorn species', [1, 0.1111111111111111])]],
#  'TINCUP CT': [1.0,
#   [('Austrian Pine', [3, 0.25]),
#    ('Flowering Crabapple', [3, 0.25]),
#    ('Quaking Aspen', [1, 0.083333333333333329]),
#    ('Blue Spruce', [1, 0.083333333333333329]),
#    ('Flowering Pear', [1, 0.083333333333333329]),
#    ('Northern Hackberry', [1, 0.083333333333333329]),
#    ('Norway Maple', [1, 0.083333333333333329]),
#    ('Ash', [1, 0.083333333333333329])]],
#  'TOPAZ DR': [16.0,
#   [('Siberian Elm', [49, 0.63636363636363635]),
#    ('Ash', [16, 0.20779220779220781]),
#    ('Staghorn Sumac', [6, 0.07792207792207792]),
#    ('Chokecherry', [4, 0.051948051948051951]),
#    ('Oak species', [1, 0.012987012987012988]),
#    ('Bur Oak', [1, 0.012987012987012988])]],
#  'TWIN LAKES RD': [3.0,
#   [('Plum species', [5, 0.1388888888888889]),
#    ('Bur Oak', [4, 0.1111111111111111]),
#    ('Pinon Pine', [4, 0.1111111111111111]),
#    ('Ash', [3, 0.083333333333333329]),
#    ('Common Honeylocust', [3, 0.083333333333333329]),
#    ('Thornless Cockspur Hawthorn', [3, 0.083333333333333329]),
#    ('Austrian Pine', [3, 0.083333333333333329]),
#    ('Russian Hawthorn', [2, 0.055555555555555552]),
#    ('Kentucky Coffeetree', [1, 0.027777777777777776]),
#    ('Chokecherry', [1, 0.027777777777777776])]],
#  'UNIVERSITY AV': [29.0,
#   [('Ash', [29, 0.11788617886178862]),
#    ('American Elm', [29, 0.11788617886178862]),
#    ('Silver Maple', [20, 0.081300813008130079]),
#    ('Flowering Crabapple', [16, 0.065040650406504072]),
#    ('Siberian Elm', [14, 0.056910569105691054]),
#    ('Common Honeylocust', [12, 0.04878048780487805]),
#    ('Pin Oak', [8, 0.032520325203252036]),
#    ('Boxelder', [7, 0.028455284552845527]),
#    ('Northern Hackberry', [7, 0.028455284552845527]),
#    ('Black Locust', [6, 0.024390243902439025])]],
#  'UTICA CR': [5.0,
#   [('Flowering Crabapple', [11, 0.23404255319148937]),
#    ('Ash', [5, 0.10638297872340426]),
#    ('Siberian Elm', [4, 0.085106382978723402]),
#    ('Blue Spruce', [4, 0.085106382978723402]),
#    ('Mugo Pine', [3, 0.063829787234042548]),
#    ('Austrian Pine', [3, 0.063829787234042548]),
#    ('Silver Maple', [3, 0.063829787234042548]),
#    ('Maple species', [2, 0.042553191489361701]),
#    ('Red Maple', [2, 0.042553191489361701]),
#    ('Mesquite species', [2, 0.042553191489361701])]],
#  'UTICA CT': [2.0,
#   [('Littleleaf Linden', [5, 0.33333333333333331]),
#    ('Pinon Pine', [4, 0.26666666666666666]),
#    ('Ash', [2, 0.13333333333333333]),
#    ('Lanceleaf Cottonwood', [1, 0.066666666666666666]),
#    ('Native Cottonwood', [1, 0.066666666666666666]),
#    ('Hybrid Elm', [1, 0.066666666666666666]),
#    ('Blue Spruce', [1, 0.066666666666666666])]],
#  'VALLEY VIEW DR': [7.0,
#   [('Ash', [7, 0.14285714285714285]),
#    ('Siberian Elm', [7, 0.14285714285714285]),
#    ('Blue Spruce', [4, 0.081632653061224483]),
#    ('Flowering Crabapple', [3, 0.061224489795918366]),
#    ('Russian Hawthorn', [3, 0.061224489795918366]),
#    ('Quaking Aspen', [3, 0.061224489795918366]),
#    ('Pinon Pine', [3, 0.061224489795918366]),
#    ('Plum species', [2, 0.040816326530612242]),
#    ('Thornless Cockspur Hawthorn', [2, 0.040816326530612242]),
#    ('Eastern Redbud', [2, 0.040816326530612242])]],
#  'VINEYARD LN': [5.0,
#   [('Ash', [5, 0.83333333333333337]),
#    ('Siberian Elm', [1, 0.16666666666666666])]],
#  'VISTA DR': [6.0,
#   [('Russian-olive', [8, 0.16326530612244897]),
#    ('Ash', [6, 0.12244897959183673]),
#    ('Siberian Elm', [6, 0.12244897959183673]),
#    ('Common Honeylocust', [5, 0.10204081632653061]),
#    ('Northern Hackberry', [5, 0.10204081632653061]),
#    ('Flowering Crabapple', [5, 0.10204081632653061]),
#    ('Blue Spruce', [4, 0.081632653061224483]),
#    ('Plum species', [3, 0.061224489795918366]),
#    ('Black Walnut', [3, 0.061224489795918366]),
#    ('Sugarberry', [1, 0.020408163265306121])]],
#  'VIVIAN CR': [4.0, [('Ash', [4, 1.0])]],
#  'WALNUT ST': [93.0,
#   [('Ash', [93, 0.18562874251497005]),
#    ('Common Honeylocust', [60, 0.11976047904191617]),
#    ('Northern Hackberry', [32, 0.063872255489021951]),
#    ('American Linden', [29, 0.057884231536926151]),
#    ('Flowering Crabapple', [21, 0.041916167664670656]),
#    ('Kentucky Coffeetree', [19, 0.037924151696606789]),
#    ('Silver Maple', [18, 0.035928143712574849]),
#    ('Littleleaf Linden', [15, 0.029940119760479042]),
#    ('Bur Oak', [15, 0.029940119760479042]),
#    ('Western Catalpa', [14, 0.027944111776447105])]],
#  'WELLINGTON RD': [5.0,
#   [('Ash', [5, 0.45454545454545453]),
#    ('Ponderosa Pine', [4, 0.36363636363636365]),
#    ('Western Catalpa', [1, 0.090909090909090912]),
#    ('Flowering Crabapple', [1, 0.090909090909090912])]],
#  'WESTERN AV': [3.0,
#   [('Plains Cottonwood', [7, 0.58333333333333337]),
#    ('Ash', [3, 0.25]),
#    ('Native Cottonwood', [2, 0.16666666666666666])]],
#  'WHITE PL': [35.0,
#   [('Ash', [35, 0.79545454545454541]),
#    ('Flowering Crabapple', [2, 0.045454545454545456]),
#    ('White Fir', [2, 0.045454545454545456]),
#    ('Common Honeylocust', [2, 0.045454545454545456]),
#    ('Red Tatarian Maple', [2, 0.045454545454545456]),
#    ('Blue Spruce', [1, 0.022727272727272728])]],
#  'WHITE ROCK CR': [1.0,
#   [('Scotch Pine', [2, 0.5]), ('Ash', [1, 0.25]), ('Red Maple', [1, 0.25])]],
#  'WILDERNESS PL': [4.0,
#   [('Common Honeylocust', [5, 0.38461538461538464]),
#    ('Ash', [4, 0.30769230769230771]),
#    ('Silver Maple', [2, 0.15384615384615385]),
#    ('Chokecherry', [2, 0.15384615384615385])]],
#  'WILDWOOD RD': [1.0, [('Ash', [1, 1.0])]],
#  'WINCHESTER CR': [18.0,
#   [('American Linden', [60, 0.5357142857142857]),
#    ('Ash', [18, 0.16071428571428573]),
#    ('Common Honeylocust', [11, 0.098214285714285712]),
#    ('Pinon Pine', [9, 0.080357142857142863]),
#    ('Bur Oak', [4, 0.035714285714285712]),
#    ('Red Maple', [4, 0.035714285714285712]),
#    ('Littleleaf Linden', [3, 0.026785714285714284]),
#    ('Austrian Pine', [1, 0.0089285714285714281]),
#    ('Norway Maple', [1, 0.0089285714285714281]),
#    ('Siberian Elm', [1, 0.0089285714285714281])]],
#  'WINDING TRAIL DR': [10.0,
#   [('Austrian Pine', [12, 0.27272727272727271]),
#    ('Blue Spruce', [11, 0.25]),
#    ('Ash', [10, 0.22727272727272727]),
#    ('Scotch Pine', [4, 0.090909090909090912]),
#    ('Chokecherry', [3, 0.068181818181818177]),
#    ('Western Catalpa', [2, 0.045454545454545456]),
#    ('Pin Oak', [1, 0.022727272727272728]),
#    ('Common Honeylocust', [1, 0.022727272727272728])]],
#  'WINGATE AV': [1.0,
#   [('Flowering Crabapple', [3, 0.59999999999999998]),
#    ('Blue Spruce', [1, 0.20000000000000001]),
#    ('Ash', [1, 0.20000000000000001])]],
#  'WONDERLAND HILL AV': [21.0,
#   [('Ash', [21, 0.17796610169491525]),
#    ('Austrian Pine', [21, 0.17796610169491525]),
#    ('American Linden', [9, 0.076271186440677971]),
#    ('Silver Maple', [8, 0.067796610169491525]),
#    ('Flowering Crabapple', [8, 0.067796610169491525]),
#    ('Hawthorn species', [7, 0.059322033898305086]),
#    ('Blue Spruce', [5, 0.042372881355932202]),
#    ('Pinon Pine', [5, 0.042372881355932202]),
#    ('Rocky Mountain Juniper', [4, 0.033898305084745763]),
#    ('Siberian Elm', [3, 0.025423728813559324])]],
#  'WRIGHT AV': [19.0,
#   [('Ash', [19, 0.42222222222222222]),
#    ('Common Honeylocust', [5, 0.1111111111111111]),
#    ('Flowering Pear', [3, 0.066666666666666666]),
#    ('English Oak', [3, 0.066666666666666666]),
#    ('Western Catalpa', [2, 0.044444444444444446]),
#    ('Turkish Filbert', [2, 0.044444444444444446]),
#    ('Red Maple', [2, 0.044444444444444446]),
#    ('Upright English Oak', [2, 0.044444444444444446]),
#    ('Sugar Maple', [2, 0.044444444444444446]),
#    ('Northern Hackberry', [1, 0.022222222222222223])]],
#  'YALE RD': [2.0,
#   [('Flowering Crabapple', [6, 0.40000000000000002]),
#    ('Siberian Elm', [3, 0.20000000000000001]),
#    ('Ash', [2, 0.13333333333333333]),
#    ('Northern Hackberry', [2, 0.13333333333333333]),
#    ('Black Walnut', [1, 0.066666666666666666]),
#    ('Apple species', [1, 0.066666666666666666])]],
#  'YELLOW PINE AV': [6.0,
#   [('Common Honeylocust', [30, 0.41095890410958902]),
#    ('Northern Hackberry', [6, 0.082191780821917804]),
#    ('Ash', [6, 0.082191780821917804]),
#    ('Austrian Pine', [5, 0.068493150684931503]),
#    ('American Linden', [4, 0.054794520547945202]),
#    ('Swamp White Oak', [4, 0.054794520547945202]),
#    ('Chokecherry', [3, 0.041095890410958902]),
#    ('Juniper species', [2, 0.027397260273972601]),
#    ('Hawthorn species', [2, 0.027397260273972601]),
#    ('Plum species', [2, 0.027397260273972601])]],
#  'ZAMIA AV': [9.0,
#   [('Red Maple', [43, 0.4942528735632184]),
#    ('Common Honeylocust', [14, 0.16091954022988506]),
#    ('Ash', [9, 0.10344827586206896]),
#    ('Swamp White Oak', [5, 0.057471264367816091]),
#    ('Littleleaf Linden', [5, 0.057471264367816091]),
#    ('Thornless Cockspur Hawthorn', [4, 0.045977011494252873]),
#    ('Maple species', [2, 0.022988505747126436]),
#    ('Dogwood species', [1, 0.011494252873563218]),
#    ('Western Catalpa', [1, 0.011494252873563218]),
#    ('Plum species', [1, 0.011494252873563218])]]}

# %%
np.mean(ash['DBH'])+np.std(ash['DBH'])+np.std(ash['DBH'])
dic(ash[ash['DBH']>25]['STREET'])[:15]
# Out:
# [('9TH ST', 26),
#  ('ARAPAHOE AV', 14),
#  ('MAPLETON AV', 11),
#  ('BLUFF ST', 8),
#  ('LINCOLN PL', 7),
#  ('MARINE ST', 7),
#  ('PINE ST', 7),
#  ('11TH ST', 6),
#  ('4TH ST', 6),
#  ('13TH ST', 5),
#  ('GROVE ST', 5),
#  ('MANHATTAN DR', 5),
#  ('BROADWAY', 4),
#  ('JUNIPER AV', 4),
#  ('14TH ST', 3)]
